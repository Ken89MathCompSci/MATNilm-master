# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/MATNilm-master/blob/kengoh-just-add-kl-loss-only/MATNilm_add-kl-loss-only_12_November_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
cd MATNilm-master/
# Out:
# /content/MATNilm-master

# %%
# !python main.py --dataAug
# Out:
#   File "/tmp/ipython-input-2035039281.py", line 1
#     python main.py --dataAug
#            ^
# SyntaxError: invalid syntax
