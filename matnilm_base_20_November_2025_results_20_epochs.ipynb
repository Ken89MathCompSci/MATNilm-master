# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/MATNilm-master/blob/kengoh-just-add-kl-loss-only/matnilm_base_20_November_2025_results_20_epochs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
cd MATNilm-master/
# Out:
# /content/MATNilm-master

# %%
# !python main.py --dataAug --patience 20 --subName run25epochs
# Out:
# 2025-11-20 12:23:24,332 - root - INFO - Using computation device: cuda:0
# 2025-11-20 12:23:24,332 - root - INFO - Namespace(batch=32, lr=0.001, dropout=0.1, hidden=32, logname='root', subName='run25epochs', inputLength=864, outputLength=864, debug=False, dataAug=True, prob0=0.3, prob1=0.6, prob2=0.3, prob3=0.3, epochs=200, patience=20, resume=False, checkpoint='All_best_onoff.ckpt')
# 2025-11-20 12:23:24,332 - root - INFO - loading data
# 2025-11-20 12:23:24,369 - root - INFO - loading data finished
# 2025-11-20 12:23:24,372 - root - INFO - Training size: 27937.
# 2025-11-20 12:23:24,373 - root - INFO - Initialize model
# 2025-11-20 12:23:24,717 - root - INFO - Model MAT
# 2025-11-20 12:23:29,084 - root - INFO - Training start
# 2025-11-20 12:23:29,093 - root - INFO - # of epoches: 0
# ...
