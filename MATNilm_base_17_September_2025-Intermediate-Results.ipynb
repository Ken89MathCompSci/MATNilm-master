# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/MATNilm-master/blob/master/MATNilm_base_17_September_2025-Intermediate-Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content/MATNilm-master'

# %%
cd MATNilm-master/
# Out:
# /content/MATNilm-master

# %%
# Write the content of cell 95b50e1b to main.py
with open("main.py", "w") as f:
    f.write("""
import copy
import os
import utils
import argparse
import joblib
from tqdm import tqdm
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from custom_types import Basic, TrainConfig
from modules import MATconv as MAT
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"


def get_args():

    parser = argparse.ArgumentParser()

    parser.add_argument("--batch", type=int, default=32, help="batch size")
    parser.add_argument("--lr", type=float, default=0.001, help="learning rate")
    parser.add_argument("--dropout", type=float, default=0.1, help="dropout")
    parser.add_argument("--hidden", type=int, default=32, help="encoder decoder hidden size")
    parser.add_argument("--logname", action="store", default='root', help="name for log")
    parser.add_argument("--subName", action="store", type=str, default='test', help="name of the directory of current run")
    parser.add_argument("--inputLength", type=int, default=864, help="input length for the model")
    parser.add_argument("--outputLength", type=int, default=864, help="output length for the model")
    parser.add_argument("--debug", action="store_true", help="debug mode")
    parser.add_argument("--dataAug", action="store_true", help="data augmentation mode")
    parser.add_argument("--prob0", type=float, default=0.3, help="augment probability for Dishwasher")
    parser.add_argument("--prob1", type=float, default=0.6, help="weight")
    parser.add_argument("--prob2", type=float, default=0.3, help="weight")
    parser.add_argument("--prob3", type=float, default=0.3, help="weight")
    parser.add_argument("--resume", action="store_true", help="resume training from checkpoint")
    parser.add_argument("--checkpoint", type=str, default="All_best_onoff.ckpt", help="checkpoint file name to resume from")
    parser.add_argument("--save_dir", type=str, default="./", help="directory to save checkpoints")
    return parser.parse_args()


def train(t_net, train_Dataloader, vali_Dataloader, config, criterion, modelDir, epo=200):
    iter_loss = []
    vali_loss = []
    early_stopping_all = utils.EarlyStopping(logger, patience=30, verbose=True)

    if config.dataAug:
        sigClass = utils.sigGen(config)

    path_all = os.path.join(modelDir, "All_best_onoff.ckpt")

    for e_i in range(epo):

        logger.info(f"# of epoches: {e_i}")
        for t_i, (_, _, X_scaled, Y_scaled, Y_of) in enumerate(tqdm(train_Dataloader)):
            if config.dataAug:
                X_scaled, Y_scaled, Y_of = utils.dataAug(X_scaled.clone(), Y_scaled.clone(), Y_of.clone(), sigClass, config)

            t_net.model_opt.zero_grad(set_to_none=True)

            X_scaled = X_scaled.type(torch.FloatTensor).to(device, non_blocking=True)
            Y_scaled = Y_scaled.type(torch.FloatTensor).to(device, non_blocking=True)
            Y_of = Y_of.type(torch.FloatTensor).to(device, non_blocking=True)

            y_pred_dish_r, y_pred_dish_c = t_net.model(X_scaled)

            loss_r = criterion[0](y_pred_dish_r,Y_scaled)
            loss_c = criterion[1](y_pred_dish_c, Y_of)

            loss=loss_r+loss_c
            loss.backward()

            t_net.model_opt.step()
            iter_loss.append(loss.item())

        epoch_losses = np.average(iter_loss)

        logger.info(f"Validation: ")
        maeScore, y_vali_ori, y_vali_pred_d_update, _, _, _ = utils.evaluateResult(net, config, vali_Dataloader, logger)
        val_loss = criterion[0](y_vali_ori, y_vali_pred_d_update)
        logger.info(f"Epoch {e_i:d}, train loss: {epoch_losses:3.3f}, val loss: {val_loss:3.3f}.")
        vali_loss.append(val_loss)

        if e_i % 10 == 0:
            checkpointName = os.path.join(config.save_dir, "checkpoint_" + str(e_i) + '.ckpt')
            utils.saveModel(logger, net, checkpointName)

        logger.info(f"Early stopping overall: ")
        early_stopping_all(np.mean(maeScore), net, path_all)
        if early_stopping_all.early_stop:
            print("Early stopping")
            break

    net_all = copy.deepcopy(net)
    checkpoint_all = torch.load(path_all, map_location=device)
    utils.loadModel(logger, net_all, checkpoint_all)
    net_all.model.eval()

    return net_all

if __name__ == '__main__':
    args = get_args()
    utils.mkdir("log/" + args.subName)
    logger = utils.setup_log(args.subName, args.logname)
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using computation device: {device}")
    logger.info(args)
    if args.debug:
        epo = 2
    else:
        epo = 200

    # splitLoss = False
    # trainFull = True

    # Dataloder
    logger.info(f"loading data")
    train_data, val_data, test_data = utils.data_loader(args)

    logger.info(f"loading data finished")

    config_dict = {
        "input_size": 1,
        "batch_size": args.batch,
        "hidden": args.hidden,
        "lr": args.lr,
        "dropout": args.dropout,
        "logname": args.logname,
        "outputLength": args.outputLength,
        "inputLength" : args.inputLength,
        "subName": args.subName,
        "dataAug": args.dataAug,
        "prob0": args.prob0,
        "prob1": args.prob1,
        "prob2": args.prob2,
        "prob3": args.prob3,
        "save_dir": args.save_dir,
    }

    config = TrainConfig.from_dict(config_dict)
    modelDir = utils.mkdirectory(config.subName, saveModel=True)
    joblib.dump(config, os.path.join(modelDir, "config.pkl"))


    logger.info(f"Training size: {train_data.cumulative_sizes[-1]:d}.")

    index = np.arange(0,train_data.cumulative_sizes[-1])
    train_subsampler = torch.utils.data.SubsetRandomSampler(index)
    train_Dataloader = DataLoader(
        train_data,
        batch_size=config.batch_size,
        sampler=train_subsampler,
        num_workers=1,
        pin_memory=True)

    sampler = utils.testSampler(val_data.cumulative_sizes[-1], config.outputLength)
    sampler_test = utils.testSampler(test_data.cumulative_sizes[-1], config.outputLength)

    vali_Dataloader = DataLoader(
        val_data,
        batch_size=config.batch_size,
        sampler=sampler,
        num_workers=1,
        pin_memory=True)

    test_Dataloader = DataLoader(
        test_data,
        batch_size=config.batch_size,
        sampler=sampler_test,
        num_workers=1,
        pin_memory=True)

    logger.info("Initialize model")
    model = MAT(config).to(device)
    logger.info("Model MAT")

    optim = optim.Adam(params=[p for p in model.parameters() if p.requires_grad], lr=config.lr)
    net = Basic(model, optim)

    # Resume from checkpoint if specified
    if args.resume:
        checkpoint_path = os.path.join(modelDir, args.checkpoint)
        if os.path.exists(checkpoint_path):
            logger.info(f"Resuming training from checkpoint: {checkpoint_path}")
            checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=False)
            net = utils.loadModel(logger, net, checkpoint)
        else:
            logger.error(f"Checkpoint file not found: {checkpoint_path}")
            logger.info("Starting training from scratch")

    criterion_r = nn.MSELoss()
    criterion_c = nn.BCELoss()
    criterion = [criterion_r, criterion_c]

    logger.info("Training start")
    net_all = train(net, train_Dataloader, vali_Dataloader, config, criterion, modelDir, epo=epo)
    logger.info("Training end")

    logger.info("validation start")
    utils.evaluateResult(net_all, config, vali_Dataloader, logger)
    logger.info("test start")
    utils.evaluateResult(net_all, config, test_Dataloader, logger)
""")
# !python main.py --dataAug --save_dir "/content/drive/MyDrive/MATNilm_checkpoints"
# Out:
# 2025-09-18 12:51:20,234 - root - INFO - Using computation device: cuda:0
# 2025-09-18 12:51:20,234 - root - INFO - Namespace(batch=32, lr=0.001, dropout=0.1, hidden=32, logname='root', subName='test', inputLength=864, outputLength=864, debug=False, dataAug=True, prob0=0.3, prob1=0.6, prob2=0.3, prob3=0.3, resume=False, checkpoint='All_best_onoff.ckpt', save_dir='/content/drive/MyDrive/MATNilm_checkpoints')
# 2025-09-18 12:51:20,234 - root - INFO - loading data
# 2025-09-18 12:51:20,267 - root - INFO - loading data finished
# 2025-09-18 12:51:20,267 - root - INFO - Training size: 27937.
# 2025-09-18 12:51:20,268 - root - INFO - Initialize model
# 2025-09-18 12:51:20,542 - root - INFO - Model MAT
# 2025-09-18 12:51:21,815 - root - INFO - Training start
# 2025-09-18 12:51:21,839 - root - INFO - # of epoches: 0
#   0% 0/874 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:366: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1027.)
#   return F.conv1d(
# 100% 874/874 [17:27<00:00,  1.20s/it]
# 2025-09-18 13:08:49,574 - root - INFO - Validation:
# 2025-09-18 13:08:49,906 - root - INFO - Evaluate dish washer:
# 2025-09-18 13:08:49,907 - root - INFO - MAE: 32.2737922668457
# 2025-09-18 13:08:49,907 - root - INFO - SAE: 32.675716400146484
# 2025-09-18 13:08:49,913 - root - INFO - F1: 0.8533933258342707
# 2025-09-18 13:08:49,913 - root - INFO - Evaluate fridge:
# 2025-09-18 13:08:49,913 - root - INFO - MAE: 31.749267578125
# 2025-09-18 13:08:49,914 - root - INFO - SAE: 9.605527877807617
# 2025-09-18 13:08:49,917 - root - INFO - F1: 0.7521244548356638
# 2025-09-18 13:08:49,918 - root - INFO - Evaluate microwave:
# 2025-09-18 13:08:49,918 - root - INFO - MAE: 18.752843856811523
# 2025-09-18 13:08:49,918 - root - INFO - SAE: 17.28926658630371
# 2025-09-18 13:08:49,922 - root - INFO - F1: 0.11320754716981132
# 2025-09-18 13:08:49,922 - root - INFO - Evaluate wash:
# 2025-09-18 13:08:49,922 - root - INFO - MAE: 30.10370445251465
# 2025-09-18 13:08:49,922 - root - INFO - SAE: 27.50710105895996
# 2025-09-18 13:08:49,926 - root - INFO - F1: 0.9021170610211706
# 2025-09-18 13:08:49,927 - root - INFO - Epoch 0, train loss: 0.370, val loss: 10713.451.
# 2025-09-18 13:08:50,124 - root - INFO - Model saved
# 2025-09-18 13:08:50,124 - root - INFO - Early stopping overall:
# 2025-09-18 13:08:50,124 - root - INFO - Validation loss decreased (inf --> 28.219902).  Saving model ...
# 2025-09-18 13:08:50,219 - root - INFO - Model saved
# 2025-09-18 13:08:50,219 - root - INFO - # of epoches: 1
# 100% 874/874 [17:29<00:00,  1.20s/it]
# 2025-09-18 13:26:19,675 - root - INFO - Validation:
# 2025-09-18 13:26:20,007 - root - INFO - Evaluate dish washer:
# 2025-09-18 13:26:20,008 - root - INFO - MAE: 44.914981842041016
# 2025-09-18 13:26:20,008 - root - INFO - SAE: 44.184112548828125
# 2025-09-18 13:26:20,014 - root - INFO - F1: 0.6144285328289651
# 2025-09-18 13:26:20,014 - root - INFO - Evaluate fridge:
# 2025-09-18 13:26:20,014 - root - INFO - MAE: 33.18710708618164
# 2025-09-18 13:26:20,014 - root - INFO - SAE: 11.260588645935059
# 2025-09-18 13:26:20,018 - root - INFO - F1: 0.745839636913767
# 2025-09-18 13:26:20,018 - root - INFO - Evaluate microwave:
# 2025-09-18 13:26:20,019 - root - INFO - MAE: 15.102553367614746
# 2025-09-18 13:26:20,019 - root - INFO - SAE: 12.249341011047363
# 2025-09-18 13:26:20,023 - root - INFO - F1: 0.5563139931740614
# 2025-09-18 13:26:20,023 - root - INFO - Evaluate wash:
# 2025-09-18 13:26:20,023 - root - INFO - MAE: 23.169023513793945
# 2025-09-18 13:26:20,023 - root - INFO - SAE: 21.382797241210938
# 2025-09-18 13:26:20,027 - root - INFO - F1: 0.8733850129198967
# 2025-09-18 13:26:20,027 - root - INFO - Epoch 1, train loss: 0.325, val loss: 8940.689.
# 2025-09-18 13:26:20,028 - root - INFO - Early stopping overall:
# 2025-09-18 13:26:20,028 - root - INFO - EarlyStopping counter: 1 out of 30
# 2025-09-18 13:26:20,028 - root - INFO - # of epoches: 2
# 100% 874/874 [17:31<00:00,  1.20s/it]
# 2025-09-18 13:43:51,777 - root - INFO - Validation:
# 2025-09-18 13:43:52,111 - root - INFO - Evaluate dish washer:
# 2025-09-18 13:43:52,112 - root - INFO - MAE: 62.83766174316406
# 2025-09-18 13:43:52,112 - root - INFO - SAE: 62.86749267578125
# 2025-09-18 13:43:52,117 - root - INFO - F1: 0.47575250836120403
# 2025-09-18 13:43:52,117 - root - INFO - Evaluate fridge:
# 2025-09-18 13:43:52,118 - root - INFO - MAE: 31.83902359008789
# 2025-09-18 13:43:52,118 - root - INFO - SAE: 8.590810775756836
# 2025-09-18 13:43:52,122 - root - INFO - F1: 0.7519142419601837
# 2025-09-18 13:43:52,122 - root - INFO - Evaluate microwave:
# 2025-09-18 13:43:52,122 - root - INFO - MAE: 15.941710472106934
# 2025-09-18 13:43:52,123 - root - INFO - SAE: 11.76379108428955
# 2025-09-18 13:43:52,126 - root - INFO - F1: 0.555765595463138
# 2025-09-18 13:43:52,126 - root - INFO - Evaluate wash:
# 2025-09-18 13:43:52,127 - root - INFO - MAE: 17.844722747802734
# 2025-09-18 13:43:52,127 - root - INFO - SAE: 14.249120712280273
# 2025-09-18 13:43:52,131 - root - INFO - F1: 0.8682764788552446
# 2025-09-18 13:43:52,132 - root - INFO - Epoch 2, train loss: 0.305, val loss: 12430.293.
# 2025-09-18 13:43:52,132 - root - INFO - Early stopping overall:
# 2025-09-18 13:43:52,132 - root - INFO - EarlyStopping counter: 2 out of 30
# 2025-09-18 13:43:52,132 - root - INFO - # of epoches: 3
# 100% 874/874 [17:30<00:00,  1.20s/it]
# 2025-09-18 14:01:22,539 - root - INFO - Validation:
# 2025-09-18 14:01:22,872 - root - INFO - Evaluate dish washer:
# 2025-09-18 14:01:22,872 - root - INFO - MAE: 28.007272720336914
# 2025-09-18 14:01:22,873 - root - INFO - SAE: 22.694591522216797
# 2025-09-18 14:01:22,878 - root - INFO - F1: 0.7555705604321404
# 2025-09-18 14:01:22,878 - root - INFO - Evaluate fridge:
# 2025-09-18 14:01:22,879 - root - INFO - MAE: 31.97490882873535
# 2025-09-18 14:01:22,879 - root - INFO - SAE: 10.15185832977295
# 2025-09-18 14:01:22,883 - root - INFO - F1: 0.7636264037250069
# 2025-09-18 14:01:22,883 - root - INFO - Evaluate microwave:
# 2025-09-18 14:01:22,883 - root - INFO - MAE: 13.195996284484863
# 2025-09-18 14:01:22,883 - root - INFO - SAE: 11.016605377197266
# 2025-09-18 14:01:22,887 - root - INFO - F1: 0.6371681415929203
# 2025-09-18 14:01:22,887 - root - INFO - Evaluate wash:
# 2025-09-18 14:01:22,887 - root - INFO - MAE: 15.55582332611084
# 2025-09-18 14:01:22,888 - root - INFO - SAE: 10.09241771697998
# 2025-09-18 14:01:22,891 - root - INFO - F1: 0.9322175732217574
# 2025-09-18 14:01:22,892 - root - INFO - Epoch 3, train loss: 0.286, val loss: 6353.382.
# 2025-09-18 14:01:22,892 - root - INFO - Early stopping overall:
# 2025-09-18 14:01:22,892 - root - INFO - Validation loss decreased (28.219902 --> 22.183500).  Saving model ...
# 2025-09-18 14:01:23,010 - root - INFO - Model saved
# 2025-09-18 14:01:23,010 - root - INFO - # of epoches: 4
# 100% 874/874 [17:28<00:00,  1.20s/it]
# 2025-09-18 14:18:51,954 - root - INFO - Validation:
# 2025-09-18 14:18:52,317 - root - INFO - Evaluate dish washer:
# 2025-09-18 14:18:52,317 - root - INFO - MAE: 46.360198974609375
# 2025-09-18 14:18:52,318 - root - INFO - SAE: 41.527767181396484
# 2025-09-18 14:18:52,324 - root - INFO - F1: 0.5581512182868626
# 2025-09-18 14:18:52,324 - root - INFO - Evaluate fridge:
# 2025-09-18 14:18:52,325 - root - INFO - MAE: 29.806724548339844
# 2025-09-18 14:18:52,325 - root - INFO - SAE: 9.61841869354248
# 2025-09-18 14:18:52,330 - root - INFO - F1: 0.7917475937675342
# 2025-09-18 14:18:52,330 - root - INFO - Evaluate microwave:
# 2025-09-18 14:18:52,331 - root - INFO - MAE: 13.749628067016602
# 2025-09-18 14:18:52,331 - root - INFO - SAE: 11.440585136413574
# 2025-09-18 14:18:52,336 - root - INFO - F1: 0.6189624329159212
# 2025-09-18 14:18:52,336 - root - INFO - Evaluate wash:
# 2025-09-18 14:18:52,337 - root - INFO - MAE: 15.168441772460938
# 2025-09-18 14:18:52,337 - root - INFO - SAE: 11.71166706085205
# 2025-09-18 14:18:52,342 - root - INFO - F1: 0.923973767306291
# 2025-09-18 14:18:52,343 - root - INFO - Epoch 4, train loss: 0.273, val loss: 8132.797.
# 2025-09-18 14:18:52,343 - root - INFO - Early stopping overall:
# 2025-09-18 14:18:52,343 - root - INFO - EarlyStopping counter: 1 out of 30
# 2025-09-18 14:18:52,343 - root - INFO - # of epoches: 5
# 100% 874/874 [17:24<00:00,  1.19s/it]
# 2025-09-18 14:36:16,678 - root - INFO - Validation:
# 2025-09-18 14:36:17,012 - root - INFO - Evaluate dish washer:
# 2025-09-18 14:36:17,013 - root - INFO - MAE: 36.103240966796875
# 2025-09-18 14:36:17,013 - root - INFO - SAE: 28.59016990661621
# 2025-09-18 14:36:17,018 - root - INFO - F1: 0.6940378436272759
# 2025-09-18 14:36:17,018 - root - INFO - Evaluate fridge:
# 2025-09-18 14:36:17,018 - root - INFO - MAE: 29.18973731994629
# 2025-09-18 14:36:17,018 - root - INFO - SAE: 11.263089179992676
# 2025-09-18 14:36:17,023 - root - INFO - F1: 0.7897382107425375
# 2025-09-18 14:36:17,023 - root - INFO - Evaluate microwave:
# 2025-09-18 14:36:17,023 - root - INFO - MAE: 14.008033752441406
# 2025-09-18 14:36:17,023 - root - INFO - SAE: 10.623395919799805
# 2025-09-18 14:36:17,027 - root - INFO - F1: 0.6091205211726385
# 2025-09-18 14:36:17,027 - root - INFO - Evaluate wash:
# 2025-09-18 14:36:17,027 - root - INFO - MAE: 14.24300765991211
# 2025-09-18 14:36:17,028 - root - INFO - SAE: 10.395089149475098
# 2025-09-18 14:36:17,032 - root - INFO - F1: 0.8745325596389426
# 2025-09-18 14:36:17,032 - root - INFO - Epoch 5, train loss: 0.264, val loss: 6439.656.
# 2025-09-18 14:36:17,033 - root - INFO - Early stopping overall:
# 2025-09-18 14:36:17,033 - root - INFO - EarlyStopping counter: 2 out of 30
# 2025-09-18 14:36:17,033 - root - INFO - # of epoches: 6
# 100% 874/874 [17:29<00:00,  1.20s/it]
# 2025-09-18 14:53:46,430 - root - INFO - Validation:
# 2025-09-18 14:53:46,764 - root - INFO - Evaluate dish washer:
# 2025-09-18 14:53:46,765 - root - INFO - MAE: 72.59458923339844
# 2025-09-18 14:53:46,765 - root - INFO - SAE: 67.3197021484375
# 2025-09-18 14:53:46,771 - root - INFO - F1: 0.4216979379528144
# 2025-09-18 14:53:46,771 - root - INFO - Evaluate fridge:
# 2025-09-18 14:53:46,771 - root - INFO - MAE: 28.107440948486328
# 2025-09-18 14:53:46,771 - root - INFO - SAE: 6.75240421295166
# 2025-09-18 14:53:46,775 - root - INFO - F1: 0.7686874062605835
# 2025-09-18 14:53:46,775 - root - INFO - Evaluate microwave:
# 2025-09-18 14:53:46,776 - root - INFO - MAE: 13.951416015625
# 2025-09-18 14:53:46,776 - root - INFO - SAE: 10.255035400390625
# 2025-09-18 14:53:46,780 - root - INFO - F1: 0.6156583629893239
# 2025-09-18 14:53:46,780 - root - INFO - Evaluate wash:
# 2025-09-18 14:53:46,781 - root - INFO - MAE: 34.1270751953125
# 2025-09-18 14:53:46,781 - root - INFO - SAE: 25.728633880615234
# 2025-09-18 14:53:46,785 - root - INFO - F1: 0.9110585893767882
# 2025-09-18 14:53:46,785 - root - INFO - Epoch 6, train loss: 0.255, val loss: 14794.027.
# 2025-09-18 14:53:46,785 - root - INFO - Early stopping overall:
# 2025-09-18 14:53:46,786 - root - INFO - EarlyStopping counter: 3 out of 30
# 2025-09-18 14:53:46,786 - root - INFO - # of epoches: 7
# 100% 874/874 [17:31<00:00,  1.20s/it]
# 2025-09-18 15:11:18,526 - root - INFO - Validation:
# 2025-09-18 15:11:18,863 - root - INFO - Evaluate dish washer:
# 2025-09-18 15:11:18,864 - root - INFO - MAE: 23.90414047241211
# 2025-09-18 15:11:18,864 - root - INFO - SAE: 16.16253662109375
# 2025-09-18 15:11:18,870 - root - INFO - F1: 0.7838400666389005
# 2025-09-18 15:11:18,870 - root - INFO - Evaluate fridge:
# 2025-09-18 15:11:18,870 - root - INFO - MAE: 29.391767501831055
# 2025-09-18 15:11:18,870 - root - INFO - SAE: 11.35314655303955
# 2025-09-18 15:11:18,875 - root - INFO - F1: 0.7827309921581997
# 2025-09-18 15:11:18,875 - root - INFO - Evaluate microwave:
# 2025-09-18 15:11:18,875 - root - INFO - MAE: 16.07867431640625
# 2025-09-18 15:11:18,875 - root - INFO - SAE: 14.740708351135254
# 2025-09-18 15:11:18,880 - root - INFO - F1: 0.40898876404494383
# 2025-09-18 15:11:18,880 - root - INFO - Evaluate wash:
# 2025-09-18 15:11:18,880 - root - INFO - MAE: 11.956355094909668
# 2025-09-18 15:11:18,880 - root - INFO - SAE: 6.760802268981934
# 2025-09-18 15:11:18,884 - root - INFO - F1: 0.958076740881099
# 2025-09-18 15:11:18,886 - root - INFO - Epoch 7, train loss: 0.248, val loss: 7544.672.
# 2025-09-18 15:11:18,886 - root - INFO - Early stopping overall:
# 2025-09-18 15:11:18,886 - root - INFO - Validation loss decreased (22.183500 --> 20.332733).  Saving model ...
# 2025-09-18 15:11:19,013 - root - INFO - Model saved
# 2025-09-18 15:11:19,014 - root - INFO - # of epoches: 8
# 100% 874/874 [17:28<00:00,  1.20s/it]
# 2025-09-18 15:28:47,951 - root - INFO - Validation:
# 2025-09-18 15:28:48,289 - root - INFO - Evaluate dish washer:
# 2025-09-18 15:28:48,290 - root - INFO - MAE: 25.590572357177734
# 2025-09-18 15:28:48,290 - root - INFO - SAE: 22.700912475585938
# 2025-09-18 15:28:48,296 - root - INFO - F1: 0.7253544345532477
# 2025-09-18 15:28:48,296 - root - INFO - Evaluate fridge:
# 2025-09-18 15:28:48,296 - root - INFO - MAE: 28.705595016479492
# 2025-09-18 15:28:48,296 - root - INFO - SAE: 9.02016830444336
# 2025-09-18 15:28:48,300 - root - INFO - F1: 0.7889744845705126
# 2025-09-18 15:28:48,300 - root - INFO - Evaluate microwave:
# 2025-09-18 15:28:48,301 - root - INFO - MAE: 8.670355796813965
# 2025-09-18 15:28:48,301 - root - INFO - SAE: 6.893816947937012
# 2025-09-18 15:28:48,305 - root - INFO - F1: 0.7678832116788321
# 2025-09-18 15:28:48,305 - root - INFO - Evaluate wash:
# 2025-09-18 15:28:48,305 - root - INFO - MAE: 16.71173667907715
# 2025-09-18 15:28:48,305 - root - INFO - SAE: 9.28383731842041
# 2025-09-18 15:28:48,309 - root - INFO - F1: 0.9548682703321879
# 2025-09-18 15:28:48,309 - root - INFO - Epoch 8, train loss: 0.241, val loss: 4670.920.
# 2025-09-18 15:28:48,309 - root - INFO - Early stopping overall:
# 2025-09-18 15:28:48,310 - root - INFO - Validation loss decreased (20.332733 --> 19.919565).  Saving model ...
# 2025-09-18 15:28:48,429 - root - INFO - Model saved
# 2025-09-18 15:28:48,429 - root - INFO - # of epoches: 9
# 100% 874/874 [17:29<00:00,  1.20s/it]
# 2025-09-18 15:46:17,435 - root - INFO - Validation:
# 2025-09-18 15:46:17,764 - root - INFO - Evaluate dish washer:
# 2025-09-18 15:46:17,765 - root - INFO - MAE: 17.18337631225586
# 2025-09-18 15:46:17,765 - root - INFO - SAE: 10.114913940429688
# 2025-09-18 15:46:17,770 - root - INFO - F1: 0.8185465893892109
# 2025-09-18 15:46:17,770 - root - INFO - Evaluate fridge:
# 2025-09-18 15:46:17,770 - root - INFO - MAE: 27.86039924621582
# 2025-09-18 15:46:17,770 - root - INFO - SAE: 8.026521682739258
# 2025-09-18 15:46:17,774 - root - INFO - F1: 0.7871671597633136
# 2025-09-18 15:46:17,774 - root - INFO - Evaluate microwave:
# 2025-09-18 15:46:17,774 - root - INFO - MAE: 8.434829711914062
# 2025-09-18 15:46:17,775 - root - INFO - SAE: 6.4766058921813965
# 2025-09-18 15:46:17,778 - root - INFO - F1: 0.8024316109422492
# 2025-09-18 15:46:17,778 - root - INFO - Evaluate wash:
# 2025-09-18 15:46:17,779 - root - INFO - MAE: 13.722886085510254
# 2025-09-18 15:46:17,779 - root - INFO - SAE: 11.651860237121582
# 2025-09-18 15:46:17,782 - root - INFO - F1: 0.935861819060273
# 2025-09-18 15:46:17,783 - root - INFO - Epoch 9, train loss: 0.236, val loss: 3276.019.
# 2025-09-18 15:46:17,783 - root - INFO - Early stopping overall:
# 2025-09-18 15:46:17,783 - root - INFO - Validation loss decreased (19.919565 --> 16.800373).  Saving model ...
# 2025-09-18 15:46:17,905 - root - INFO - Model saved
# 2025-09-18 15:46:17,905 - root - INFO - # of epoches: 10
# 100% 874/874 [17:23<00:00,  1.19s/it]
# 2025-09-18 16:03:41,433 - root - INFO - Validation:
# 2025-09-18 16:03:41,766 - root - INFO - Evaluate dish washer:
# 2025-09-18 16:03:41,766 - root - INFO - MAE: 22.35712432861328
# 2025-09-18 16:03:41,767 - root - INFO - SAE: 12.885846138000488
# 2025-09-18 16:03:41,772 - root - INFO - F1: 0.7274969173859432
# 2025-09-18 16:03:41,772 - root - INFO - Evaluate fridge:
# 2025-09-18 16:03:41,772 - root - INFO - MAE: 29.23832893371582
# 2025-09-18 16:03:41,772 - root - INFO - SAE: 12.545242309570312
# 2025-09-18 16:03:41,777 - root - INFO - F1: 0.815967694443276
# 2025-09-18 16:03:41,777 - root - INFO - Evaluate microwave:
# 2025-09-18 16:03:41,777 - root - INFO - MAE: 13.040460586547852
# 2025-09-18 16:03:41,777 - root - INFO - SAE: 11.459094047546387
# 2025-09-18 16:03:41,781 - root - INFO - F1: 0.6199021207177814
# 2025-09-18 16:03:41,782 - root - INFO - Evaluate wash:
# 2025-09-18 16:03:41,782 - root - INFO - MAE: 18.4574031829834
# 2025-09-18 16:03:41,782 - root - INFO - SAE: 11.74722671508789
# 2025-09-18 16:03:41,786 - root - INFO - F1: 0.9516148397166526
# 2025-09-18 16:03:41,786 - root - INFO - Epoch 10, train loss: 0.231, val loss: 6626.583.
# 2025-09-18 16:03:41,968 - root - INFO - Model saved
# 2025-09-18 16:03:41,968 - root - INFO - Early stopping overall:
# 2025-09-18 16:03:41,969 - root - INFO - EarlyStopping counter: 1 out of 30
# 2025-09-18 16:03:41,969 - root - INFO - # of epoches: 11
# 100% 874/874 [17:19<00:00,  1.19s/it]
# 2025-09-18 16:21:01,355 - root - INFO - Validation:
# 2025-09-18 16:21:01,697 - root - INFO - Evaluate dish washer:
# 2025-09-18 16:21:01,697 - root - INFO - MAE: 22.905691146850586
# 2025-09-18 16:21:01,697 - root - INFO - SAE: 21.66779899597168
# 2025-09-18 16:21:01,702 - root - INFO - F1: 0.8606985146527499
# 2025-09-18 16:21:01,702 - root - INFO - Evaluate fridge:
# 2025-09-18 16:21:01,703 - root - INFO - MAE: 28.683719635009766
# 2025-09-18 16:21:01,703 - root - INFO - SAE: 9.537224769592285
# 2025-09-18 16:21:01,706 - root - INFO - F1: 0.795551753635586
# 2025-09-18 16:21:01,706 - root - INFO - Evaluate microwave:
# 2025-09-18 16:21:01,707 - root - INFO - MAE: 11.488349914550781
# 2025-09-18 16:21:01,707 - root - INFO - SAE: 8.675664901733398
# 2025-09-18 16:21:01,710 - root - INFO - F1: 0.6486486486486487
# 2025-09-18 16:21:01,710 - root - INFO - Evaluate wash:
# 2025-09-18 16:21:01,711 - root - INFO - MAE: 16.4537410736084
# 2025-09-18 16:21:01,711 - root - INFO - SAE: 10.56485652923584
# 2025-09-18 16:21:01,715 - root - INFO - F1: 0.9442353746151214
# 2025-09-18 16:21:01,715 - root - INFO - Epoch 11, train loss: 0.226, val loss: 5648.578.
# 2025-09-18 16:21:01,715 - root - INFO - Early stopping overall:
# 2025-09-18 16:21:01,715 - root - INFO - EarlyStopping counter: 2 out of 30
# 2025-09-18 16:21:01,715 - root - INFO - # of epoches: 12
# 100% 874/874 [17:20<00:00,  1.19s/it]
# 2025-09-18 16:38:21,842 - root - INFO - Validation:
# 2025-09-18 16:38:22,171 - root - INFO - Evaluate dish washer:
# 2025-09-18 16:38:22,172 - root - INFO - MAE: 24.04877281188965
# 2025-09-18 16:38:22,172 - root - INFO - SAE: 13.957087516784668
# 2025-09-18 16:38:22,177 - root - INFO - F1: 0.7519500780031201
# 2025-09-18 16:38:22,178 - root - INFO - Evaluate fridge:
# 2025-09-18 16:38:22,178 - root - INFO - MAE: 28.84538459777832
# 2025-09-18 16:38:22,178 - root - INFO - SAE: 7.469037055969238
# 2025-09-18 16:38:22,182 - root - INFO - F1: 0.7583789493901854
# 2025-09-18 16:38:22,182 - root - INFO - Evaluate microwave:
# 2025-09-18 16:38:22,182 - root - INFO - MAE: 7.915225505828857
# 2025-09-18 16:38:22,182 - root - INFO - SAE: 5.305977821350098
# 2025-09-18 16:38:22,186 - root - INFO - F1: 0.8422712933753943
# 2025-09-18 16:38:22,186 - root - INFO - Evaluate wash:
# 2025-09-18 16:38:22,186 - root - INFO - MAE: 16.753395080566406
# 2025-09-18 16:38:22,187 - root - INFO - SAE: 12.17625904083252
# 2025-09-18 16:38:22,190 - root - INFO - F1: 0.9384213029006182
# 2025-09-18 16:38:22,191 - root - INFO - Epoch 12, train loss: 0.222, val loss: 3631.479.
# 2025-09-18 16:38:22,191 - root - INFO - Early stopping overall:
# 2025-09-18 16:38:22,191 - root - INFO - EarlyStopping counter: 3 out of 30
# 2025-09-18 16:38:22,191 - root - INFO - # of epoches: 13
# 100% 874/874 [17:20<00:00,  1.19s/it]
# 2025-09-18 16:55:43,098 - root - INFO - Validation:
# 2025-09-18 16:55:43,429 - root - INFO - Evaluate dish washer:
# 2025-09-18 16:55:43,430 - root - INFO - MAE: 26.651805877685547
# 2025-09-18 16:55:43,430 - root - INFO - SAE: 25.534238815307617
# 2025-09-18 16:55:43,435 - root - INFO - F1: 0.8585513841486537
# 2025-09-18 16:55:43,435 - root - INFO - Evaluate fridge:
# 2025-09-18 16:55:43,436 - root - INFO - MAE: 28.51666831970215
# 2025-09-18 16:55:43,436 - root - INFO - SAE: 9.668767929077148
# 2025-09-18 16:55:43,439 - root - INFO - F1: 0.791466427127779
# 2025-09-18 16:55:43,440 - root - INFO - Evaluate microwave:
# 2025-09-18 16:55:43,440 - root - INFO - MAE: 13.16275405883789
# 2025-09-18 16:55:43,440 - root - INFO - SAE: 9.925090789794922
# 2025-09-18 16:55:43,444 - root - INFO - F1: 0.660436137071651
# 2025-09-18 16:55:43,444 - root - INFO - Evaluate wash:
# 2025-09-18 16:55:43,444 - root - INFO - MAE: 15.642165184020996
# 2025-09-18 16:55:43,444 - root - INFO - SAE: 13.193321228027344
# 2025-09-18 16:55:43,448 - root - INFO - F1: 0.9627094642435685
# 2025-09-18 16:55:43,449 - root - INFO - Epoch 13, train loss: 0.218, val loss: 5353.195.
# 2025-09-18 16:55:43,449 - root - INFO - Early stopping overall:
# 2025-09-18 16:55:43,449 - root - INFO - EarlyStopping counter: 4 out of 30
# 2025-09-18 16:55:43,449 - root - INFO - # of epoches: 14
# 100% 874/874 [17:25<00:00,  1.20s/it]
# 2025-09-18 17:13:08,651 - root - INFO - Validation:
# 2025-09-18 17:13:08,984 - root - INFO - Evaluate dish washer:
# 2025-09-18 17:13:08,985 - root - INFO - MAE: 24.30099105834961
# 2025-09-18 17:13:08,985 - root - INFO - SAE: 18.49546241760254
# 2025-09-18 17:13:08,990 - root - INFO - F1: 0.6550218340611353
# 2025-09-18 17:13:08,991 - root - INFO - Evaluate fridge:
# 2025-09-18 17:13:08,991 - root - INFO - MAE: 29.29524040222168
# 2025-09-18 17:13:08,991 - root - INFO - SAE: 14.190938949584961
# 2025-09-18 17:13:08,995 - root - INFO - F1: 0.8062253579580826
# 2025-09-18 17:13:08,995 - root - INFO - Evaluate microwave:
# 2025-09-18 17:13:08,996 - root - INFO - MAE: 9.27060317993164
# 2025-09-18 17:13:08,996 - root - INFO - SAE: 7.328256130218506
# 2025-09-18 17:13:09,000 - root - INFO - F1: 0.7566765578635015
# 2025-09-18 17:13:09,000 - root - INFO - Evaluate wash:
# 2025-09-18 17:13:09,000 - root - INFO - MAE: 26.53019142150879
# 2025-09-18 17:13:09,000 - root - INFO - SAE: 25.45585060119629
# 2025-09-18 17:13:09,004 - root - INFO - F1: 0.9557248274220423
# 2025-09-18 17:13:09,004 - root - INFO - Epoch 14, train loss: 0.215, val loss: 6063.755.
# 2025-09-18 17:13:09,004 - root - INFO - Early stopping overall:
# 2025-09-18 17:13:09,004 - root - INFO - EarlyStopping counter: 5 out of 30
# 2025-09-18 17:13:09,005 - root - INFO - # of epoches: 15
# 100% 874/874 [17:23<00:00,  1.19s/it]
# 2025-09-18 17:30:32,103 - root - INFO - Validation:
# 2025-09-18 17:30:32,449 - root - INFO - Evaluate dish washer:
# 2025-09-18 17:30:32,449 - root - INFO - MAE: 19.819347381591797
# 2025-09-18 17:30:32,450 - root - INFO - SAE: 14.44002628326416
# 2025-09-18 17:30:32,454 - root - INFO - F1: 0.8045649072753209
# 2025-09-18 17:30:32,454 - root - INFO - Evaluate fridge:
# 2025-09-18 17:30:32,455 - root - INFO - MAE: 26.985721588134766
# 2025-09-18 17:30:32,455 - root - INFO - SAE: 13.909395217895508
# 2025-09-18 17:30:32,459 - root - INFO - F1: 0.8120993589743589
# 2025-09-18 17:30:32,459 - root - INFO - Evaluate microwave:
# 2025-09-18 17:30:32,459 - root - INFO - MAE: 10.854572296142578
# 2025-09-18 17:30:32,459 - root - INFO - SAE: 8.174766540527344
# 2025-09-18 17:30:32,463 - root - INFO - F1: 0.6629001883239172
# 2025-09-18 17:30:32,463 - root - INFO - Evaluate wash:
# 2025-09-18 17:30:32,463 - root - INFO - MAE: 10.915766716003418
# 2025-09-18 17:30:32,463 - root - INFO - SAE: 8.661554336547852
# 2025-09-18 17:30:32,467 - root - INFO - F1: 0.9435096153846154
# 2025-09-18 17:30:32,467 - root - INFO - Epoch 15, train loss: 0.212, val loss: 4247.608.
# 2025-09-18 17:30:32,467 - root - INFO - Early stopping overall:
# 2025-09-18 17:30:32,468 - root - INFO - EarlyStopping counter: 6 out of 30
# 2025-09-18 17:30:32,468 - root - INFO - # of epoches: 16
# 100% 874/874 [17:23<00:00,  1.19s/it]
# 2025-09-18 17:47:56,412 - root - INFO - Validation:
# 2025-09-18 17:47:56,750 - root - INFO - Evaluate dish washer:
# 2025-09-18 17:47:56,751 - root - INFO - MAE: 16.811565399169922
# 2025-09-18 17:47:56,751 - root - INFO - SAE: 16.641740798950195
# 2025-09-18 17:47:56,756 - root - INFO - F1: 0.7683997299122215
# 2025-09-18 17:47:56,756 - root - INFO - Evaluate fridge:
# 2025-09-18 17:47:56,756 - root - INFO - MAE: 29.959009170532227
# 2025-09-18 17:47:56,757 - root - INFO - SAE: 12.802191734313965
# 2025-09-18 17:47:56,761 - root - INFO - F1: 0.7903858317520557
# 2025-09-18 17:47:56,761 - root - INFO - Evaluate microwave:
# 2025-09-18 17:47:56,761 - root - INFO - MAE: 7.406191349029541
# 2025-09-18 17:47:56,761 - root - INFO - SAE: 5.377230167388916
# 2025-09-18 17:47:56,765 - root - INFO - F1: 0.8685015290519877
# 2025-09-18 17:47:56,765 - root - INFO - Evaluate wash:
# 2025-09-18 17:47:56,765 - root - INFO - MAE: 11.21933650970459
# 2025-09-18 17:47:56,765 - root - INFO - SAE: 9.673943519592285
# 2025-09-18 17:47:56,769 - root - INFO - F1: 0.9264651902606142
# 2025-09-18 17:47:56,770 - root - INFO - Epoch 16, train loss: 0.209, val loss: 2993.392.
# 2025-09-18 17:47:56,770 - root - INFO - Early stopping overall:
# 2025-09-18 17:47:56,770 - root - INFO - Validation loss decreased (16.800373 --> 16.349026).  Saving model ...
# 2025-09-18 17:47:56,891 - root - INFO - Model saved
# 2025-09-18 17:47:56,891 - root - INFO - # of epoches: 17
# 100% 874/874 [17:28<00:00,  1.20s/it]
# 2025-09-18 18:05:25,244 - root - INFO - Validation:
# 2025-09-18 18:05:25,585 - root - INFO - Evaluate dish washer:
# 2025-09-18 18:05:25,586 - root - INFO - MAE: 16.087705612182617
# 2025-09-18 18:05:25,586 - root - INFO - SAE: 12.070165634155273
# 2025-09-18 18:05:25,591 - root - INFO - F1: 0.8664546899841018
# 2025-09-18 18:05:25,591 - root - INFO - Evaluate fridge:
# 2025-09-18 18:05:25,591 - root - INFO - MAE: 27.231653213500977
# 2025-09-18 18:05:25,592 - root - INFO - SAE: 10.382359504699707
# 2025-09-18 18:05:25,595 - root - INFO - F1: 0.7967514983062625
# 2025-09-18 18:05:25,595 - root - INFO - Evaluate microwave:
# 2025-09-18 18:05:25,596 - root - INFO - MAE: 8.143177032470703
# 2025-09-18 18:05:25,596 - root - INFO - SAE: 6.350882530212402
# 2025-09-18 18:05:25,600 - root - INFO - F1: 0.8421052631578947
# 2025-09-18 18:05:25,600 - root - INFO - Evaluate wash:
# 2025-09-18 18:05:25,600 - root - INFO - MAE: 13.587517738342285
# 2025-09-18 18:05:25,600 - root - INFO - SAE: 12.251791000366211
# 2025-09-18 18:05:25,604 - root - INFO - F1: 0.9439071566731141
# 2025-09-18 18:05:25,604 - root - INFO - Epoch 17, train loss: 0.206, val loss: 2614.089.
# 2025-09-18 18:05:25,605 - root - INFO - Early stopping overall:
# 2025-09-18 18:05:25,605 - root - INFO - Validation loss decreased (16.349026 --> 16.262514).  Saving model ...
# 2025-09-18 18:05:25,879 - root - INFO - Model saved
# 2025-09-18 18:05:25,879 - root - INFO - # of epoches: 18
# 100% 874/874 [17:29<00:00,  1.20s/it]
# 2025-09-18 18:22:55,850 - root - INFO - Validation:
# 2025-09-18 18:22:56,247 - root - INFO - Evaluate dish washer:
# 2025-09-18 18:22:56,248 - root - INFO - MAE: 10.257524490356445
# 2025-09-18 18:22:56,249 - root - INFO - SAE: 7.188234806060791
# 2025-09-18 18:22:56,258 - root - INFO - F1: 0.8929859719438877
# 2025-09-18 18:22:56,258 - root - INFO - Evaluate fridge:
# 2025-09-18 18:22:56,259 - root - INFO - MAE: 26.91977882385254
# 2025-09-18 18:22:56,259 - root - INFO - SAE: 10.249444961547852
# 2025-09-18 18:22:56,265 - root - INFO - F1: 0.7983095433179525
# 2025-09-18 18:22:56,265 - root - INFO - Evaluate microwave:
# 2025-09-18 18:22:56,265 - root - INFO - MAE: 8.814674377441406
# 2025-09-18 18:22:56,266 - root - INFO - SAE: 6.93492317199707
# 2025-09-18 18:22:56,272 - root - INFO - F1: 0.8089260808926081
# 2025-09-18 18:22:56,272 - root - INFO - Evaluate wash:
# 2025-09-18 18:22:56,272 - root - INFO - MAE: 11.57357406616211
# 2025-09-18 18:22:56,272 - root - INFO - SAE: 9.24065113067627
# 2025-09-18 18:22:56,279 - root - INFO - F1: 0.955982345222474
# 2025-09-18 18:22:56,279 - root - INFO - Epoch 18, train loss: 0.204, val loss: 2626.586.
# 2025-09-18 18:22:56,280 - root - INFO - Early stopping overall:
# 2025-09-18 18:22:56,280 - root - INFO - Validation loss decreased (16.262514 --> 14.391388).  Saving model ...
# 2025-09-18 18:22:56,478 - root - INFO - Model saved
# 2025-09-18 18:22:56,478 - root - INFO - # of epoches: 19
# 100% 874/874 [17:30<00:00,  1.20s/it]
# 2025-09-18 18:40:27,195 - root - INFO - Validation:
# 2025-09-18 18:40:27,555 - root - INFO - Evaluate dish washer:
# 2025-09-18 18:40:27,556 - root - INFO - MAE: 13.552035331726074
# 2025-09-18 18:40:27,556 - root - INFO - SAE: 5.453728675842285
# 2025-09-18 18:40:27,565 - root - INFO - F1: 0.8469551282051282
# 2025-09-18 18:40:27,565 - root - INFO - Evaluate fridge:
# 2025-09-18 18:40:27,566 - root - INFO - MAE: 26.755090713500977
# 2025-09-18 18:40:27,566 - root - INFO - SAE: 8.117682456970215
# 2025-09-18 18:40:27,571 - root - INFO - F1: 0.8020636122680803
# 2025-09-18 18:40:27,571 - root - INFO - Evaluate microwave:
# 2025-09-18 18:40:27,572 - root - INFO - MAE: 8.860158920288086
# 2025-09-18 18:40:27,572 - root - INFO - SAE: 6.726078510284424
# 2025-09-18 18:40:27,576 - root - INFO - F1: 0.7129798903107861
# 2025-09-18 18:40:27,576 - root - INFO - Evaluate wash:
# 2025-09-18 18:40:27,576 - root - INFO - MAE: 9.682690620422363
# 2025-09-18 18:40:27,577 - root - INFO - SAE: 6.606114864349365
# 2025-09-18 18:40:27,581 - root - INFO - F1: 0.9344903446590076
# 2025-09-18 18:40:27,581 - root - INFO - Epoch 19, train loss: 0.201, val loss: 3322.801.
# 2025-09-18 18:40:27,582 - root - INFO - Early stopping overall:
# 2025-09-18 18:40:27,582 - root - INFO - EarlyStopping counter: 1 out of 30
# 2025-09-18 18:40:27,582 - root - INFO - # of epoches: 20
# 100% 874/874 [17:43<00:00,  1.22s/it]
# 2025-09-18 18:58:11,303 - root - INFO - Validation:
# 2025-09-18 18:58:11,683 - root - INFO - Evaluate dish washer:
# 2025-09-18 18:58:11,683 - root - INFO - MAE: 11.581145286560059
# 2025-09-18 18:58:11,684 - root - INFO - SAE: 5.995029449462891
# 2025-09-18 18:58:11,691 - root - INFO - F1: 0.851083448593822
# 2025-09-18 18:58:11,691 - root - INFO - Evaluate fridge:
# 2025-09-18 18:58:11,691 - root - INFO - MAE: 24.3974552154541
# 2025-09-18 18:58:11,691 - root - INFO - SAE: 11.82359790802002
# 2025-09-18 18:58:11,697 - root - INFO - F1: 0.8052467207995003
# 2025-09-18 18:58:11,697 - root - INFO - Evaluate microwave:
# 2025-09-18 18:58:11,697 - root - INFO - MAE: 10.303380012512207
# 2025-09-18 18:58:11,698 - root - INFO - SAE: 7.970402717590332
# 2025-09-18 18:58:11,703 - root - INFO - F1: 0.7442572741194488
# 2025-09-18 18:58:11,703 - root - INFO - Evaluate wash:
# 2025-09-18 18:58:11,703 - root - INFO - MAE: 14.449784278869629
# 2025-09-18 18:58:11,704 - root - INFO - SAE: 10.936471939086914
# 2025-09-18 18:58:11,709 - root - INFO - F1: 0.9543726235741445
# 2025-09-18 18:58:11,709 - root - INFO - Epoch 20, train loss: 0.199, val loss: 3585.375.
# 2025-09-18 18:58:11,929 - root - INFO - Model saved
# 2025-09-18 18:58:11,929 - root - INFO - Early stopping overall:
# 2025-09-18 18:58:11,930 - root - INFO - EarlyStopping counter: 2 out of 30
# 2025-09-18 18:58:11,930 - root - INFO - # of epoches: 21
# 100% 874/874 [17:38<00:00,  1.21s/it]
# 2025-09-18 19:15:50,062 - root - INFO - Validation:
# 2025-09-18 19:15:50,422 - root - INFO - Evaluate dish washer:
# 2025-09-18 19:15:50,423 - root - INFO - MAE: 12.958549499511719
# 2025-09-18 19:15:50,423 - root - INFO - SAE: 9.534229278564453
# 2025-09-18 19:15:50,430 - root - INFO - F1: 0.901743264659271
# 2025-09-18 19:15:50,430 - root - INFO - Evaluate fridge:
# 2025-09-18 19:15:50,430 - root - INFO - MAE: 25.80405616760254
# 2025-09-18 19:15:50,431 - root - INFO - SAE: 11.076131820678711
# 2025-09-18 19:15:50,436 - root - INFO - F1: 0.8123567851990156
# 2025-09-18 19:15:50,436 - root - INFO - Evaluate microwave:
# 2025-09-18 19:15:50,436 - root - INFO - MAE: 8.38700008392334
# 2025-09-18 19:15:50,437 - root - INFO - SAE: 5.968210697174072
# 2025-09-18 19:15:50,441 - root - INFO - F1: 0.8549382716049383
# 2025-09-18 19:15:50,442 - root - INFO - Evaluate wash:
# 2025-09-18 19:15:50,442 - root - INFO - MAE: 11.267607688903809
# 2025-09-18 19:15:50,442 - root - INFO - SAE: 6.509790897369385
# 2025-09-18 19:15:50,447 - root - INFO - F1: 0.9588297746844402
# 2025-09-18 19:15:50,448 - root - INFO - Epoch 21, train loss: 0.197, val loss: 2579.176.
# 2025-09-18 19:15:50,448 - root - INFO - Early stopping overall:
# 2025-09-18 19:15:50,448 - root - INFO - EarlyStopping counter: 3 out of 30
# 2025-09-18 19:15:50,448 - root - INFO - # of epoches: 22
# 100% 874/874 [17:27<00:00,  1.20s/it]
# 2025-09-18 19:33:17,451 - root - INFO - Validation:
# 2025-09-18 19:33:17,790 - root - INFO - Evaluate dish washer:
# 2025-09-18 19:33:17,790 - root - INFO - MAE: 14.32661247253418
# 2025-09-18 19:33:17,791 - root - INFO - SAE: 13.491015434265137
# 2025-09-18 19:33:17,796 - root - INFO - F1: 0.8525490196078431
# 2025-09-18 19:33:17,796 - root - INFO - Evaluate fridge:
# 2025-09-18 19:33:17,796 - root - INFO - MAE: 26.72886848449707
# 2025-09-18 19:33:17,796 - root - INFO - SAE: 11.548942565917969
# 2025-09-18 19:33:17,800 - root - INFO - F1: 0.8041176716742687
# 2025-09-18 19:33:17,800 - root - INFO - Evaluate microwave:
# 2025-09-18 19:33:17,801 - root - INFO - MAE: 9.431870460510254
# 2025-09-18 19:33:17,801 - root - INFO - SAE: 7.829707145690918
# 2025-09-18 19:33:17,804 - root - INFO - F1: 0.78419452887538
# 2025-09-18 19:33:17,805 - root - INFO - Evaluate wash:
# 2025-09-18 19:33:17,805 - root - INFO - MAE: 14.892924308776855
# 2025-09-18 19:33:17,805 - root - INFO - SAE: 9.542861938476562
# 2025-09-18 19:33:17,809 - root - INFO - F1: 0.9259807549962991
# 2025-09-18 19:33:17,809 - root - INFO - Epoch 22, train loss: 0.195, val loss: 3331.746.
# 2025-09-18 19:33:17,809 - root - INFO - Early stopping overall:
# 2025-09-18 19:33:17,809 - root - INFO - EarlyStopping counter: 4 out of 30
# 2025-09-18 19:33:17,810 - root - INFO - # of epoches: 23
# 100% 874/874 [17:30<00:00,  1.20s/it]
# 2025-09-18 19:50:48,367 - root - INFO - Validation:
# 2025-09-18 19:50:48,701 - root - INFO - Evaluate dish washer:
# 2025-09-18 19:50:48,701 - root - INFO - MAE: 12.381041526794434
# 2025-09-18 19:50:48,702 - root - INFO - SAE: 9.595759391784668
# 2025-09-18 19:50:48,707 - root - INFO - F1: 0.8316831683168316
# 2025-09-18 19:50:48,707 - root - INFO - Evaluate fridge:
# 2025-09-18 19:50:48,707 - root - INFO - MAE: 28.67156410217285
# 2025-09-18 19:50:48,707 - root - INFO - SAE: 11.61591911315918
# 2025-09-18 19:50:48,711 - root - INFO - F1: 0.8078239195640234
# 2025-09-18 19:50:48,712 - root - INFO - Evaluate microwave:
# 2025-09-18 19:50:48,712 - root - INFO - MAE: 8.842558860778809
# 2025-09-18 19:50:48,712 - root - INFO - SAE: 7.252279758453369
# 2025-09-18 19:50:48,716 - root - INFO - F1: 0.7835051546391752
# 2025-09-18 19:50:48,716 - root - INFO - Evaluate wash:
# 2025-09-18 19:50:48,716 - root - INFO - MAE: 14.093774795532227
# 2025-09-18 19:50:48,717 - root - INFO - SAE: 12.309775352478027
# 2025-09-18 19:50:48,720 - root - INFO - F1: 0.9359641689868055
# 2025-09-18 19:50:48,721 - root - INFO - Epoch 23, train loss: 0.193, val loss: 2998.701.
# 2025-09-18 19:50:48,721 - root - INFO - Early stopping overall:
# 2025-09-18 19:50:48,721 - root - INFO - EarlyStopping counter: 5 out of 30
# 2025-09-18 19:50:48,721 - root - INFO - # of epoches: 24
# 100% 874/874 [17:31<00:00,  1.20s/it]
# 2025-09-18 20:08:20,118 - root - INFO - Validation:
# 2025-09-18 20:08:20,512 - root - INFO - Evaluate dish washer:
# 2025-09-18 20:08:20,513 - root - INFO - MAE: 12.951172828674316
# 2025-09-18 20:08:20,513 - root - INFO - SAE: 12.431405067443848
# 2025-09-18 20:08:20,522 - root - INFO - F1: 0.8859478396263137
# 2025-09-18 20:08:20,523 - root - INFO - Evaluate fridge:
# 2025-09-18 20:08:20,523 - root - INFO - MAE: 28.216386795043945
# 2025-09-18 20:08:20,523 - root - INFO - SAE: 14.332304954528809
# 2025-09-18 20:08:20,528 - root - INFO - F1: 0.8043969998809477
# 2025-09-18 20:08:20,528 - root - INFO - Evaluate microwave:
# 2025-09-18 20:08:20,528 - root - INFO - MAE: 12.47355842590332
# 2025-09-18 20:08:20,529 - root - INFO - SAE: 10.164388656616211
# 2025-09-18 20:08:20,533 - root - INFO - F1: 0.6276803118908382
# 2025-09-18 20:08:20,534 - root - INFO - Evaluate wash:
# 2025-09-18 20:08:20,534 - root - INFO - MAE: 8.911555290222168
# 2025-09-18 20:08:20,534 - root - INFO - SAE: 6.157738208770752
# 2025-09-18 20:08:20,540 - root - INFO - F1: 0.9658271254582003
# 2025-09-18 20:08:20,540 - root - INFO - Epoch 24, train loss: 0.191, val loss: 4066.244.
# 2025-09-18 20:08:20,541 - root - INFO - Early stopping overall:
# 2025-09-18 20:08:20,541 - root - INFO - EarlyStopping counter: 6 out of 30
# 2025-09-18 20:08:20,541 - root - INFO - # of epoches: 25
# 100% 874/874 [17:24<00:00,  1.20s/it]
# 2025-09-18 20:25:44,990 - root - INFO - Validation:
# 2025-09-18 20:25:45,327 - root - INFO - Evaluate dish washer:
# 2025-09-18 20:25:45,327 - root - INFO - MAE: 11.796640396118164
# 2025-09-18 20:25:45,328 - root - INFO - SAE: 6.007075309753418
# 2025-09-18 20:25:45,332 - root - INFO - F1: 0.8710232158211522
# 2025-09-18 20:25:45,333 - root - INFO - Evaluate fridge:
# 2025-09-18 20:25:45,333 - root - INFO - MAE: 24.77487564086914
# 2025-09-18 20:25:45,333 - root - INFO - SAE: 10.994413375854492
# 2025-09-18 20:25:45,337 - root - INFO - F1: 0.8067762495806776
# 2025-09-18 20:25:45,337 - root - INFO - Evaluate microwave:
# 2025-09-18 20:25:45,337 - root - INFO - MAE: 6.630985736846924
# 2025-09-18 20:25:45,337 - root - INFO - SAE: 4.237576484680176
# 2025-09-18 20:25:45,341 - root - INFO - F1: 0.9226100151745068
# 2025-09-18 20:25:45,341 - root - INFO - Evaluate wash:
# 2025-09-18 20:25:45,341 - root - INFO - MAE: 10.672880172729492
# 2025-09-18 20:25:45,341 - root - INFO - SAE: 8.127715110778809
# 2025-09-18 20:25:45,345 - root - INFO - F1: 0.9569777142176141
# 2025-09-18 20:25:45,345 - root - INFO - Epoch 25, train loss: 0.189, val loss: 1923.946.
# 2025-09-18 20:25:45,345 - root - INFO - Early stopping overall:
# 2025-09-18 20:25:45,346 - root - INFO - Validation loss decreased (14.391388 --> 13.468845).  Saving model ...
# 2025-09-18 20:25:45,461 - root - INFO - Model saved
# 2025-09-18 20:25:45,462 - root - INFO - # of epoches: 26
# 100% 874/874 [17:23<00:00,  1.19s/it]
# 2025-09-18 20:43:08,589 - root - INFO - Validation:
# 2025-09-18 20:43:08,920 - root - INFO - Evaluate dish washer:
# 2025-09-18 20:43:08,920 - root - INFO - MAE: 8.896536827087402
# 2025-09-18 20:43:08,921 - root - INFO - SAE: 5.443991184234619
# 2025-09-18 20:43:08,925 - root - INFO - F1: 0.9013861386138614
# 2025-09-18 20:43:08,926 - root - INFO - Evaluate fridge:
# 2025-09-18 20:43:08,926 - root - INFO - MAE: 21.94851303100586
# 2025-09-18 20:43:08,926 - root - INFO - SAE: 10.356077194213867
# 2025-09-18 20:43:08,930 - root - INFO - F1: 0.8314786713876243
# 2025-09-18 20:43:08,930 - root - INFO - Evaluate microwave:
# 2025-09-18 20:43:08,930 - root - INFO - MAE: 7.887947082519531
# 2025-09-18 20:43:08,931 - root - INFO - SAE: 5.960370063781738
# 2025-09-18 20:43:08,934 - root - INFO - F1: 0.8625592417061612
# 2025-09-18 20:43:08,934 - root - INFO - Evaluate wash:
# 2025-09-18 20:43:08,935 - root - INFO - MAE: 10.6937837600708
# 2025-09-18 20:43:08,935 - root - INFO - SAE: 8.904359817504883
# 2025-09-18 20:43:08,939 - root - INFO - F1: 0.939522482123379
# 2025-09-18 20:43:08,939 - root - INFO - Epoch 26, train loss: 0.188, val loss: 1980.702.
# 2025-09-18 20:43:08,939 - root - INFO - Early stopping overall:
# 2025-09-18 20:43:08,939 - root - INFO - Validation loss decreased (13.468845 --> 12.356695).  Saving model ...
# 2025-09-18 20:43:09,078 - root - INFO - Model saved
# 2025-09-18 20:43:09,078 - root - INFO - # of epoches: 27
# 100% 874/874 [17:25<00:00,  1.20s/it]
# 2025-09-18 21:00:34,787 - root - INFO - Validation:
# 2025-09-18 21:00:35,116 - root - INFO - Evaluate dish washer:
# 2025-09-18 21:00:35,117 - root - INFO - MAE: 15.337423324584961
# 2025-09-18 21:00:35,118 - root - INFO - SAE: 14.601036071777344
# 2025-09-18 21:00:35,123 - root - INFO - F1: 0.7540983606557377
# 2025-09-18 21:00:35,123 - root - INFO - Evaluate fridge:
# 2025-09-18 21:00:35,123 - root - INFO - MAE: 23.2861385345459
# 2025-09-18 21:00:35,124 - root - INFO - SAE: 9.219491958618164
# 2025-09-18 21:00:35,128 - root - INFO - F1: 0.8140954247783668
# 2025-09-18 21:00:35,128 - root - INFO - Evaluate microwave:
# 2025-09-18 21:00:35,129 - root - INFO - MAE: 8.059171676635742
# 2025-09-18 21:00:35,129 - root - INFO - SAE: 6.554058074951172
# 2025-09-18 21:00:35,133 - root - INFO - F1: 0.8256578947368421
# 2025-09-18 21:00:35,133 - root - INFO - Evaluate wash:
# 2025-09-18 21:00:35,133 - root - INFO - MAE: 11.999683380126953
# 2025-09-18 21:00:35,133 - root - INFO - SAE: 8.145565032958984
# 2025-09-18 21:00:35,137 - root - INFO - F1: 0.9820110701107011
# 2025-09-18 21:00:35,137 - root - INFO - Epoch 27, train loss: 0.186, val loss: 2706.890.
# 2025-09-18 21:00:35,138 - root - INFO - Early stopping overall:
# 2025-09-18 21:00:35,138 - root - INFO - EarlyStopping counter: 1 out of 30
# 2025-09-18 21:00:35,138 - root - INFO - # of epoches: 28
# 100% 874/874 [17:22<00:00,  1.19s/it]
# 2025-09-18 21:17:57,290 - root - INFO - Validation:
# 2025-09-18 21:17:57,625 - root - INFO - Evaluate dish washer:
# 2025-09-18 21:17:57,625 - root - INFO - MAE: 8.628788948059082
# 2025-09-18 21:17:57,625 - root - INFO - SAE: 7.428574562072754
# 2025-09-18 21:17:57,630 - root - INFO - F1: 0.8968538430904023
# 2025-09-18 21:17:57,630 - root - INFO - Evaluate fridge:
# 2025-09-18 21:17:57,631 - root - INFO - MAE: 25.04314613342285
# 2025-09-18 21:17:57,631 - root - INFO - SAE: 8.653800010681152
# 2025-09-18 21:17:57,635 - root - INFO - F1: 0.8022244780862426
# 2025-09-18 21:17:57,635 - root - INFO - Evaluate microwave:
# 2025-09-18 21:17:57,635 - root - INFO - MAE: 6.992465496063232
# 2025-09-18 21:17:57,635 - root - INFO - SAE: 5.3221540451049805
# 2025-09-18 21:17:57,639 - root - INFO - F1: 0.8960468521229868
# 2025-09-18 21:17:57,639 - root - INFO - Evaluate wash:
# 2025-09-18 21:17:57,639 - root - INFO - MAE: 14.552111625671387
# 2025-09-18 21:17:57,640 - root - INFO - SAE: 9.053082466125488
# 2025-09-18 21:17:57,643 - root - INFO - F1: 0.9390316088552149
# 2025-09-18 21:17:57,644 - root - INFO - Epoch 28, train loss: 0.184, val loss: 2073.404.
# 2025-09-18 21:17:57,644 - root - INFO - Early stopping overall:
# 2025-09-18 21:17:57,644 - root - INFO - EarlyStopping counter: 2 out of 30
# 2025-09-18 21:17:57,644 - root - INFO - # of epoches: 29
# 100% 874/874 [17:27<00:00,  1.20s/it]
# 2025-09-18 21:35:24,773 - root - INFO - Validation:
# 2025-09-18 21:35:25,113 - root - INFO - Evaluate dish washer:
# 2025-09-18 21:35:25,113 - root - INFO - MAE: 9.51264476776123
# 2025-09-18 21:35:25,114 - root - INFO - SAE: 7.338129997253418
# 2025-09-18 21:35:25,119 - root - INFO - F1: 0.8929976396538158
# 2025-09-18 21:35:25,119 - root - INFO - Evaluate fridge:
# 2025-09-18 21:35:25,119 - root - INFO - MAE: 23.901716232299805
# 2025-09-18 21:35:25,119 - root - INFO - SAE: 8.827380180358887
# 2025-09-18 21:35:25,123 - root - INFO - F1: 0.7913058844318784
# 2025-09-18 21:35:25,123 - root - INFO - Evaluate microwave:
# 2025-09-18 21:35:25,123 - root - INFO - MAE: 8.01533317565918
# 2025-09-18 21:35:25,124 - root - INFO - SAE: 5.881865978240967
# 2025-09-18 21:35:25,127 - root - INFO - F1: 0.8517441860465116
# 2025-09-18 21:35:25,127 - root - INFO - Evaluate wash:
# 2025-09-18 21:35:25,127 - root - INFO - MAE: 11.175504684448242
# 2025-09-18 21:35:25,128 - root - INFO - SAE: 5.988375186920166
# 2025-09-18 21:35:25,131 - root - INFO - F1: 0.958920468115596
# 2025-09-18 21:35:25,132 - root - INFO - Epoch 29, train loss: 0.183, val loss: 2049.417.
# 2025-09-18 21:35:25,132 - root - INFO - Early stopping overall:
# 2025-09-18 21:35:25,132 - root - INFO - EarlyStopping counter: 3 out of 30
# 2025-09-18 21:35:25,132 - root - INFO - # of epoches: 30
# 100% 874/874 [17:19<00:00,  1.19s/it]
# 2025-09-18 21:52:45,130 - root - INFO - Validation:
# 2025-09-18 21:52:45,464 - root - INFO - Evaluate dish washer:
# 2025-09-18 21:52:45,465 - root - INFO - MAE: 14.395303726196289
# 2025-09-18 21:52:45,465 - root - INFO - SAE: 8.728598594665527
# 2025-09-18 21:52:45,470 - root - INFO - F1: 0.919917864476386
# 2025-09-18 21:52:45,470 - root - INFO - Evaluate fridge:
# 2025-09-18 21:52:45,470 - root - INFO - MAE: 24.766515731811523
# 2025-09-18 21:52:45,471 - root - INFO - SAE: 10.503079414367676
# 2025-09-18 21:52:45,474 - root - INFO - F1: 0.8169450374649421
# 2025-09-18 21:52:45,475 - root - INFO - Evaluate microwave:
# 2025-09-18 21:52:45,475 - root - INFO - MAE: 9.477794647216797
# 2025-09-18 21:52:45,475 - root - INFO - SAE: 6.684576988220215
# 2025-09-18 21:52:45,478 - root - INFO - F1: 0.6201058201058202
# 2025-09-18 21:52:45,479 - root - INFO - Evaluate wash:
# 2025-09-18 21:52:45,479 - root - INFO - MAE: 16.438457489013672
# 2025-09-18 21:52:45,479 - root - INFO - SAE: 12.213674545288086
# 2025-09-18 21:52:45,483 - root - INFO - F1: 0.9615339093383832
# 2025-09-18 21:52:45,483 - root - INFO - Epoch 30, train loss: 0.182, val loss: 2831.129.
# 2025-09-18 21:52:45,674 - root - INFO - Model saved
# 2025-09-18 21:52:45,674 - root - INFO - Early stopping overall:
# 2025-09-18 21:52:45,675 - root - INFO - EarlyStopping counter: 4 out of 30
# 2025-09-18 21:52:45,675 - root - INFO - # of epoches: 31
# 100% 874/874 [17:18<00:00,  1.19s/it]
# 2025-09-18 22:10:03,748 - root - INFO - Validation:
# 2025-09-18 22:10:04,086 - root - INFO - Evaluate dish washer:
# 2025-09-18 22:10:04,087 - root - INFO - MAE: 9.559185981750488
# 2025-09-18 22:10:04,087 - root - INFO - SAE: 8.703493118286133
# 2025-09-18 22:10:04,092 - root - INFO - F1: 0.9334435717238528
# 2025-09-18 22:10:04,092 - root - INFO - Evaluate fridge:
# 2025-09-18 22:10:04,092 - root - INFO - MAE: 23.71038246154785
# 2025-09-18 22:10:04,093 - root - INFO - SAE: 11.256058692932129
# 2025-09-18 22:10:04,096 - root - INFO - F1: 0.8127634950814251
# 2025-09-18 22:10:04,096 - root - INFO - Evaluate microwave:
# 2025-09-18 22:10:04,097 - root - INFO - MAE: 7.923109531402588
# 2025-09-18 22:10:04,097 - root - INFO - SAE: 5.802450180053711
# 2025-09-18 22:10:04,100 - root - INFO - F1: 0.8571428571428571
# 2025-09-18 22:10:04,100 - root - INFO - Evaluate wash:
# 2025-09-18 22:10:04,101 - root - INFO - MAE: 9.42237663269043
# 2025-09-18 22:10:04,101 - root - INFO - SAE: 5.036289215087891
# 2025-09-18 22:10:04,104 - root - INFO - F1: 0.9520958083832335
# 2025-09-18 22:10:04,105 - root - INFO - Epoch 31, train loss: 0.180, val loss: 1990.928.
# 2025-09-18 22:10:04,105 - root - INFO - Early stopping overall:
# 2025-09-18 22:10:04,105 - root - INFO - EarlyStopping counter: 5 out of 30
# 2025-09-18 22:10:04,105 - root - INFO - # of epoches: 32
# 100% 874/874 [17:16<00:00,  1.19s/it]
# 2025-09-18 22:27:20,992 - root - INFO - Validation:
# 2025-09-18 22:27:21,380 - root - INFO - Evaluate dish washer:
# 2025-09-18 22:27:21,380 - root - INFO - MAE: 11.464926719665527
# 2025-09-18 22:27:21,381 - root - INFO - SAE: 11.101645469665527
# 2025-09-18 22:27:21,388 - root - INFO - F1: 0.8755298651252409
# 2025-09-18 22:27:21,388 - root - INFO - Evaluate fridge:
# 2025-09-18 22:27:21,388 - root - INFO - MAE: 24.293561935424805
# 2025-09-18 22:27:21,389 - root - INFO - SAE: 12.603792190551758
# 2025-09-18 22:27:21,395 - root - INFO - F1: 0.8352926410910765
# 2025-09-18 22:27:21,395 - root - INFO - Evaluate microwave:
# 2025-09-18 22:27:21,395 - root - INFO - MAE: 7.985697269439697
# 2025-09-18 22:27:21,396 - root - INFO - SAE: 6.1463541984558105
# 2025-09-18 22:27:21,401 - root - INFO - F1: 0.7346938775510204
# 2025-09-18 22:27:21,401 - root - INFO - Evaluate wash:
# 2025-09-18 22:27:21,401 - root - INFO - MAE: 20.79119110107422
# 2025-09-18 22:27:21,402 - root - INFO - SAE: 13.401002883911133
# 2025-09-18 22:27:21,407 - root - INFO - F1: 0.9531231267234145
# 2025-09-18 22:27:21,409 - root - INFO - Epoch 32, train loss: 0.179, val loss: 2869.950.
# 2025-09-18 22:27:21,409 - root - INFO - Early stopping overall:
# 2025-09-18 22:27:21,409 - root - INFO - EarlyStopping counter: 6 out of 30
# 2025-09-18 22:27:21,409 - root - INFO - # of epoches: 33
# 100% 874/874 [17:17<00:00,  1.19s/it]
# 2025-09-18 22:44:39,052 - root - INFO - Validation:
# 2025-09-18 22:44:39,385 - root - INFO - Evaluate dish washer:
# 2025-09-18 22:44:39,385 - root - INFO - MAE: 17.92973518371582
# 2025-09-18 22:44:39,386 - root - INFO - SAE: 17.900177001953125
# 2025-09-18 22:44:39,390 - root - INFO - F1: 0.8657513348588863
# 2025-09-18 22:44:39,390 - root - INFO - Evaluate fridge:
# 2025-09-18 22:44:39,391 - root - INFO - MAE: 24.893810272216797
# ...
# 2025-09-19 08:18:59,431 - root - INFO - MAE: 8.978530883789062
# 2025-09-19 08:18:59,431 - root - INFO - SAE: 7.163712978363037
# 2025-09-19 08:18:59,435 - root - INFO - F1: 0.714064914992272
# 2025-09-19 08:18:59,435 - root - INFO - Evaluate wash:
# 2025-09-19 08:18:59,435 - root - INFO - MAE: 9.709702491760254
# 2025-09-19 08:18:59,436 - root - INFO - SAE: 8.567438125610352
# 2025-09-19 08:18:59,439 - root - INFO - F1: 0.9714958775029446
# 2025-09-19 08:18:59,440 - root - INFO - Epoch 66, train loss: 0.150, val loss: 2244.970.
# 2025-09-19 08:18:59,440 - root - INFO - Early stopping overall:
# 2025-09-19 08:18:59,440 - root - INFO - EarlyStopping counter: 8 out of 30
# 2025-09-19 08:18:59,440 - root - INFO - # of epoches: 67
# 100% 874/874 [17:29<00:00,  1.20s/it]
# 2025-09-19 08:36:28,474 - root - INFO - Validation:
# 2025-09-19 08:36:28,863 - root - INFO - Evaluate dish washer:
# 2025-09-19 08:36:28,864 - root - INFO - MAE: 6.269306659698486
# 2025-09-19 08:36:28,864 - root - INFO - SAE: 5.613369941711426
# 2025-09-19 08:36:28,872 - root - INFO - F1: 0.9353643474680938
# 2025-09-19 08:36:28,872 - root - INFO - Evaluate fridge:
# 2025-09-19 08:36:28,872 - root - INFO - MAE: 21.449438095092773
# 2025-09-19 08:36:28,872 - root - INFO - SAE: 5.1058173179626465
# 2025-09-19 08:36:28,878 - root - INFO - F1: 0.8340264300896405
# 2025-09-19 08:36:28,878 - root - INFO - Evaluate microwave:
# 2025-09-19 08:36:28,878 - root - INFO - MAE: 9.151471138000488
# 2025-09-19 08:36:28,879 - root - INFO - SAE: 7.444393157958984
# 2025-09-19 08:36:28,884 - root - INFO - F1: 0.6579439252336449
# 2025-09-19 08:36:28,884 - root - INFO - Evaluate wash:
# 2025-09-19 08:36:28,884 - root - INFO - MAE: 9.669354438781738
# 2025-09-19 08:36:28,884 - root - INFO - SAE: 4.652134895324707
# 2025-09-19 08:36:28,889 - root - INFO - F1: 0.9555715658021133
# 2025-09-19 08:36:28,890 - root - INFO - Epoch 67, train loss: 0.150, val loss: 2682.807.
# 2025-09-19 08:36:28,890 - root - INFO - Early stopping overall:
# 2025-09-19 08:36:28,890 - root - INFO - EarlyStopping counter: 9 out of 30
# 2025-09-19 08:36:28,890 - root - INFO - # of epoches: 68
# 100% 874/874 [17:26<00:00,  1.20s/it]
# 2025-09-19 08:53:55,692 - root - INFO - Validation:
# 2025-09-19 08:53:56,025 - root - INFO - Evaluate dish washer:
# 2025-09-19 08:53:56,025 - root - INFO - MAE: 16.49970245361328
# 2025-09-19 08:53:56,026 - root - INFO - SAE: 16.47442054748535
# 2025-09-19 08:53:56,031 - root - INFO - F1: 0.7733605164797825
# 2025-09-19 08:53:56,031 - root - INFO - Evaluate fridge:
# 2025-09-19 08:53:56,031 - root - INFO - MAE: 21.426389694213867
# 2025-09-19 08:53:56,031 - root - INFO - SAE: 6.938912868499756
# 2025-09-19 08:53:56,035 - root - INFO - F1: 0.8403535672409128
# 2025-09-19 08:53:56,035 - root - INFO - Evaluate microwave:
# 2025-09-19 08:53:56,035 - root - INFO - MAE: 9.362610816955566
# 2025-09-19 08:53:56,036 - root - INFO - SAE: 7.669915676116943
# 2025-09-19 08:53:56,039 - root - INFO - F1: 0.7103825136612022
# 2025-09-19 08:53:56,039 - root - INFO - Evaluate wash:
# 2025-09-19 08:53:56,039 - root - INFO - MAE: 16.167673110961914
# 2025-09-19 08:53:56,040 - root - INFO - SAE: 12.693206787109375
# 2025-09-19 08:53:56,043 - root - INFO - F1: 0.9700965387332234
# 2025-09-19 08:53:56,044 - root - INFO - Epoch 68, train loss: 0.149, val loss: 3677.337.
# 2025-09-19 08:53:56,044 - root - INFO - Early stopping overall:
# 2025-09-19 08:53:56,044 - root - INFO - EarlyStopping counter: 10 out of 30
# 2025-09-19 08:53:56,044 - root - INFO - # of epoches: 69
# 100% 874/874 [17:26<00:00,  1.20s/it]
# 2025-09-19 09:11:22,142 - root - INFO - Validation:
# 2025-09-19 09:11:22,476 - root - INFO - Evaluate dish washer:
# 2025-09-19 09:11:22,477 - root - INFO - MAE: 10.171297073364258
# 2025-09-19 09:11:22,477 - root - INFO - SAE: 9.801787376403809
# 2025-09-19 09:11:22,482 - root - INFO - F1: 0.914216673378977
# 2025-09-19 09:11:22,482 - root - INFO - Evaluate fridge:
# 2025-09-19 09:11:22,483 - root - INFO - MAE: 20.97636604309082
# 2025-09-19 09:11:22,483 - root - INFO - SAE: 7.93414306640625
# 2025-09-19 09:11:22,486 - root - INFO - F1: 0.8531338526912181
# 2025-09-19 09:11:22,486 - root - INFO - Evaluate microwave:
# 2025-09-19 09:11:22,487 - root - INFO - MAE: 9.687117576599121
# 2025-09-19 09:11:22,487 - root - INFO - SAE: 7.871159553527832
# 2025-09-19 09:11:22,490 - root - INFO - F1: 0.6492434662998624
# 2025-09-19 09:11:22,490 - root - INFO - Evaluate wash:
# 2025-09-19 09:11:22,491 - root - INFO - MAE: 7.572116374969482
# 2025-09-19 09:11:22,491 - root - INFO - SAE: 5.2334113121032715
# 2025-09-19 09:11:22,494 - root - INFO - F1: 0.9761204564168922
# 2025-09-19 09:11:22,495 - root - INFO - Epoch 69, train loss: 0.148, val loss: 2202.160.
# 2025-09-19 09:11:22,495 - root - INFO - Early stopping overall:
# 2025-09-19 09:11:22,495 - root - INFO - EarlyStopping counter: 11 out of 30
# 2025-09-19 09:11:22,495 - root - INFO - # of epoches: 70
# 100% 874/874 [17:27<00:00,  1.20s/it]
# 2025-09-19 09:28:50,184 - root - INFO - Validation:
# 2025-09-19 09:28:50,560 - root - INFO - Evaluate dish washer:
# 2025-09-19 09:28:50,560 - root - INFO - MAE: 6.363400936126709
# 2025-09-19 09:28:50,561 - root - INFO - SAE: 5.826992034912109
# 2025-09-19 09:28:50,568 - root - INFO - F1: 0.9518627040602763
# 2025-09-19 09:28:50,568 - root - INFO - Evaluate fridge:
# 2025-09-19 09:28:50,568 - root - INFO - MAE: 20.852413177490234
# 2025-09-19 09:28:50,569 - root - INFO - SAE: 6.246480464935303
# 2025-09-19 09:28:50,575 - root - INFO - F1: 0.8283698688509067
# 2025-09-19 09:28:50,575 - root - INFO - Evaluate microwave:
# 2025-09-19 09:28:50,576 - root - INFO - MAE: 9.626931190490723
# 2025-09-19 09:28:50,576 - root - INFO - SAE: 7.77277135848999
# 2025-09-19 09:28:50,581 - root - INFO - F1: 0.6959706959706959
# 2025-09-19 09:28:50,581 - root - INFO - Evaluate wash:
# 2025-09-19 09:28:50,581 - root - INFO - MAE: 11.866013526916504
# 2025-09-19 09:28:50,582 - root - INFO - SAE: 10.25748062133789
# 2025-09-19 09:28:50,586 - root - INFO - F1: 0.9810260014054814
# 2025-09-19 09:28:50,587 - root - INFO - Epoch 70, train loss: 0.148, val loss: 2650.850.
# 2025-09-19 09:28:50,805 - root - INFO - Model saved
# 2025-09-19 09:28:50,805 - root - INFO - Early stopping overall:
# 2025-09-19 09:28:50,805 - root - INFO - EarlyStopping counter: 12 out of 30
# 2025-09-19 09:28:50,805 - root - INFO - # of epoches: 71
# 100% 874/874 [17:17<00:00,  1.19s/it]
# 2025-09-19 09:46:08,683 - root - INFO - Validation:
# 2025-09-19 09:46:09,017 - root - INFO - Evaluate dish washer:
# 2025-09-19 09:46:09,017 - root - INFO - MAE: 7.905376434326172
# 2025-09-19 09:46:09,017 - root - INFO - SAE: 7.456214427947998
# 2025-09-19 09:46:09,022 - root - INFO - F1: 0.9174089068825911
# 2025-09-19 09:46:09,022 - root - INFO - Evaluate fridge:
# 2025-09-19 09:46:09,023 - root - INFO - MAE: 20.675355911254883
# 2025-09-19 09:46:09,023 - root - INFO - SAE: 5.306623458862305
# 2025-09-19 09:46:09,027 - root - INFO - F1: 0.8351312560766703
# 2025-09-19 09:46:09,027 - root - INFO - Evaluate microwave:
# 2025-09-19 09:46:09,027 - root - INFO - MAE: 9.647882461547852
# 2025-09-19 09:46:09,027 - root - INFO - SAE: 7.479939937591553
# 2025-09-19 09:46:09,031 - root - INFO - F1: 0.7658119658119659
# 2025-09-19 09:46:09,031 - root - INFO - Evaluate wash:
# 2025-09-19 09:46:09,031 - root - INFO - MAE: 8.093364715576172
# 2025-09-19 09:46:09,032 - root - INFO - SAE: 5.979985237121582
# 2025-09-19 09:46:09,035 - root - INFO - F1: 0.9633870005963029
# 2025-09-19 09:46:09,036 - root - INFO - Epoch 71, train loss: 0.147, val loss: 2439.564.
# 2025-09-19 09:46:09,036 - root - INFO - Early stopping overall:
# 2025-09-19 09:46:09,036 - root - INFO - EarlyStopping counter: 13 out of 30
# 2025-09-19 09:46:09,036 - root - INFO - # of epoches: 72
# 100% 874/874 [17:15<00:00,  1.19s/it]
# 2025-09-19 10:03:24,846 - root - INFO - Validation:
# 2025-09-19 10:03:25,179 - root - INFO - Evaluate dish washer:
# 2025-09-19 10:03:25,180 - root - INFO - MAE: 8.29458999633789
# 2025-09-19 10:03:25,180 - root - INFO - SAE: 7.839889049530029
# 2025-09-19 10:03:25,185 - root - INFO - F1: 0.906187624750499
# 2025-09-19 10:03:25,185 - root - INFO - Evaluate fridge:
# 2025-09-19 10:03:25,185 - root - INFO - MAE: 22.584508895874023
# 2025-09-19 10:03:25,185 - root - INFO - SAE: 9.294174194335938
# 2025-09-19 10:03:25,189 - root - INFO - F1: 0.8337185469451833
# 2025-09-19 10:03:25,189 - root - INFO - Evaluate microwave:
# 2025-09-19 10:03:25,189 - root - INFO - MAE: 9.061470031738281
# 2025-09-19 10:03:25,190 - root - INFO - SAE: 6.612192153930664
# 2025-09-19 10:03:25,193 - root - INFO - F1: 0.8144499178981938
# 2025-09-19 10:03:25,193 - root - INFO - Evaluate wash:
# 2025-09-19 10:03:25,194 - root - INFO - MAE: 8.589547157287598
# 2025-09-19 10:03:25,194 - root - INFO - SAE: 6.206933498382568
# 2025-09-19 10:03:25,197 - root - INFO - F1: 0.96457573261151
# 2025-09-19 10:03:25,198 - root - INFO - Epoch 72, train loss: 0.147, val loss: 2349.124.
# 2025-09-19 10:03:25,198 - root - INFO - Early stopping overall:
# 2025-09-19 10:03:25,198 - root - INFO - EarlyStopping counter: 14 out of 30
# 2025-09-19 10:03:25,198 - root - INFO - # of epoches: 73
# 100% 874/874 [17:19<00:00,  1.19s/it]
# 2025-09-19 10:20:44,229 - root - INFO - Validation:
# 2025-09-19 10:20:44,559 - root - INFO - Evaluate dish washer:
# 2025-09-19 10:20:44,560 - root - INFO - MAE: 9.359874725341797
# 2025-09-19 10:20:44,560 - root - INFO - SAE: 8.952466011047363
# 2025-09-19 10:20:44,565 - root - INFO - F1: 0.9227013832384052
# 2025-09-19 10:20:44,565 - root - INFO - Evaluate fridge:
# 2025-09-19 10:20:44,565 - root - INFO - MAE: 21.296091079711914
# 2025-09-19 10:20:44,566 - root - INFO - SAE: 5.527388572692871
# 2025-09-19 10:20:44,569 - root - INFO - F1: 0.8229620265018495
# 2025-09-19 10:20:44,569 - root - INFO - Evaluate microwave:
# 2025-09-19 10:20:44,570 - root - INFO - MAE: 7.429554462432861
# 2025-09-19 10:20:44,570 - root - INFO - SAE: 5.684998512268066
# 2025-09-19 10:20:44,573 - root - INFO - F1: 0.8631578947368421
# 2025-09-19 10:20:44,573 - root - INFO - Evaluate wash:
# 2025-09-19 10:20:44,574 - root - INFO - MAE: 7.97923469543457
# 2025-09-19 10:20:44,574 - root - INFO - SAE: 4.305612564086914
# 2025-09-19 10:20:44,577 - root - INFO - F1: 0.9901768172888016
# 2025-09-19 10:20:44,578 - root - INFO - Epoch 73, train loss: 0.146, val loss: 2088.230.
# 2025-09-19 10:20:44,578 - root - INFO - Early stopping overall:
# 2025-09-19 10:20:44,578 - root - INFO - EarlyStopping counter: 15 out of 30
# 2025-09-19 10:20:44,578 - root - INFO - # of epoches: 74
# 100% 874/874 [17:21<00:00,  1.19s/it]
# 2025-09-19 10:38:06,275 - root - INFO - Validation:
# 2025-09-19 10:38:06,606 - root - INFO - Evaluate dish washer:
# 2025-09-19 10:38:06,606 - root - INFO - MAE: 7.49457311630249
# 2025-09-19 10:38:06,607 - root - INFO - SAE: 6.125980377197266
# 2025-09-19 10:38:06,611 - root - INFO - F1: 0.8824561403508772
# 2025-09-19 10:38:06,611 - root - INFO - Evaluate fridge:
# 2025-09-19 10:38:06,612 - root - INFO - MAE: 22.15566635131836
# 2025-09-19 10:38:06,612 - root - INFO - SAE: 9.224608421325684
# 2025-09-19 10:38:06,616 - root - INFO - F1: 0.8436545639633526
# 2025-09-19 10:38:06,616 - root - INFO - Evaluate microwave:
# 2025-09-19 10:38:06,616 - root - INFO - MAE: 9.398462295532227
# 2025-09-19 10:38:06,616 - root - INFO - SAE: 7.221643447875977
# 2025-09-19 10:38:06,620 - root - INFO - F1: 0.7275590551181103
# 2025-09-19 10:38:06,620 - root - INFO - Evaluate wash:
# 2025-09-19 10:38:06,620 - root - INFO - MAE: 7.565932273864746
# 2025-09-19 10:38:06,620 - root - INFO - SAE: 4.759688854217529
# 2025-09-19 10:38:06,624 - root - INFO - F1: 0.9859742668366756
# 2025-09-19 10:38:06,624 - root - INFO - Epoch 74, train loss: 0.146, val loss: 2344.594.
# 2025-09-19 10:38:06,624 - root - INFO - Early stopping overall:
# 2025-09-19 10:38:06,624 - root - INFO - EarlyStopping counter: 16 out of 30
# 2025-09-19 10:38:06,624 - root - INFO - # of epoches: 75
# 100% 874/874 [17:18<00:00,  1.19s/it]
# 2025-09-19 10:55:25,586 - root - INFO - Validation:
# 2025-09-19 10:55:25,949 - root - INFO - Evaluate dish washer:
# 2025-09-19 10:55:25,950 - root - INFO - MAE: 7.7080078125
# 2025-09-19 10:55:25,951 - root - INFO - SAE: 7.232859134674072
# 2025-09-19 10:55:25,957 - root - INFO - F1: 0.896797153024911
# 2025-09-19 10:55:25,957 - root - INFO - Evaluate fridge:
# 2025-09-19 10:55:25,957 - root - INFO - MAE: 23.12590980529785
# 2025-09-19 10:55:25,958 - root - INFO - SAE: 8.8994722366333
# 2025-09-19 10:55:25,963 - root - INFO - F1: 0.8298031617420406
# 2025-09-19 10:55:25,963 - root - INFO - Evaluate microwave:
# 2025-09-19 10:55:25,963 - root - INFO - MAE: 9.674162864685059
# 2025-09-19 10:55:25,964 - root - INFO - SAE: 7.704108238220215
# 2025-09-19 10:55:25,968 - root - INFO - F1: 0.6666666666666666
# 2025-09-19 10:55:25,969 - root - INFO - Evaluate wash:
# 2025-09-19 10:55:25,969 - root - INFO - MAE: 13.851818084716797
# 2025-09-19 10:55:25,969 - root - INFO - SAE: 9.427023887634277
# 2025-09-19 10:55:25,974 - root - INFO - F1: 0.948952564411269
# 2025-09-19 10:55:25,975 - root - INFO - Epoch 75, train loss: 0.145, val loss: 2888.060.
# 2025-09-19 10:55:25,975 - root - INFO - Early stopping overall:
# 2025-09-19 10:55:25,975 - root - INFO - EarlyStopping counter: 17 out of 30
# 2025-09-19 10:55:25,975 - root - INFO - # of epoches: 76
# 100% 874/874 [17:16<00:00,  1.19s/it]
# 2025-09-19 11:12:42,521 - root - INFO - Validation:
# 2025-09-19 11:12:42,851 - root - INFO - Evaluate dish washer:
# 2025-09-19 11:12:42,852 - root - INFO - MAE: 5.950162887573242
# 2025-09-19 11:12:42,852 - root - INFO - SAE: 5.282988548278809
# 2025-09-19 11:12:42,857 - root - INFO - F1: 0.9293924466338259
# 2025-09-19 11:12:42,857 - root - INFO - Evaluate fridge:
# 2025-09-19 11:12:42,857 - root - INFO - MAE: 22.40336036682129
# 2025-09-19 11:12:42,858 - root - INFO - SAE: 6.9460835456848145
# 2025-09-19 11:12:42,861 - root - INFO - F1: 0.8351424394134066
# 2025-09-19 11:12:42,861 - root - INFO - Evaluate microwave:
# 2025-09-19 11:12:42,862 - root - INFO - MAE: 8.05729866027832
# 2025-09-19 11:12:42,862 - root - INFO - SAE: 6.06165075302124
# 2025-09-19 11:12:42,865 - root - INFO - F1: 0.7785467128027682
# 2025-09-19 11:12:42,866 - root - INFO - Evaluate wash:
# 2025-09-19 11:12:42,866 - root - INFO - MAE: 6.564729690551758
# 2025-09-19 11:12:42,866 - root - INFO - SAE: 4.978452682495117
# 2025-09-19 11:12:42,870 - root - INFO - F1: 0.9887379542551956
# 2025-09-19 11:12:42,870 - root - INFO - Epoch 76, train loss: 0.145, val loss: 2096.174.
# 2025-09-19 11:12:42,870 - root - INFO - Early stopping overall:
# 2025-09-19 11:12:42,870 - root - INFO - Validation loss decreased (11.163266 --> 10.743887).  Saving model ...
# 2025-09-19 11:12:43,016 - root - INFO - Model saved
# 2025-09-19 11:12:43,016 - root - INFO - # of epoches: 77
# 100% 874/874 [17:17<00:00,  1.19s/it]
# 2025-09-19 11:30:00,912 - root - INFO - Validation:
# 2025-09-19 11:30:01,316 - root - INFO - Evaluate dish washer:
# 2025-09-19 11:30:01,317 - root - INFO - MAE: 5.651907920837402
# 2025-09-19 11:30:01,317 - root - INFO - SAE: 4.947409629821777
# 2025-09-19 11:30:01,323 - root - INFO - F1: 0.9590443686006825
# 2025-09-19 11:30:01,324 - root - INFO - Evaluate fridge:
# 2025-09-19 11:30:01,324 - root - INFO - MAE: 22.1715030670166
# 2025-09-19 11:30:01,324 - root - INFO - SAE: 4.0219035148620605
# 2025-09-19 11:30:01,329 - root - INFO - F1: 0.8134916864608076
# 2025-09-19 11:30:01,330 - root - INFO - Evaluate microwave:
# 2025-09-19 11:30:01,330 - root - INFO - MAE: 9.404827117919922
# 2025-09-19 11:30:01,330 - root - INFO - SAE: 8.597251892089844
# 2025-09-19 11:30:01,335 - root - INFO - F1: 0.6740196078431373
# 2025-09-19 11:30:01,335 - root - INFO - Evaluate wash:
# 2025-09-19 11:30:01,336 - root - INFO - MAE: 12.988236427307129
# 2025-09-19 11:30:01,336 - root - INFO - SAE: 7.417811393737793
# 2025-09-19 11:30:01,341 - root - INFO - F1: 0.9522094140249759
# 2025-09-19 11:30:01,342 - root - INFO - Epoch 77, train loss: 0.144, val loss: 2736.729.
# 2025-09-19 11:30:01,342 - root - INFO - Early stopping overall:
# 2025-09-19 11:30:01,342 - root - INFO - EarlyStopping counter: 1 out of 30
# 2025-09-19 11:30:01,342 - root - INFO - # of epoches: 78
#  65% 565/874 [11:11<06:00,  1.17s/it]

# %%
# Modify custom_types.py to include save_dir in TrainConfig.from_dict
with open("custom_types.py", "w") as f:
    f.write("""
import collections
import typing

class TrainConfig(typing.NamedTuple):

    input_size: int
    batch_size: int
    hidden: int
    lr: float
    dropout: float
    logname: str
    outputLength: int
    inputLength: int
    subName: str
    save_dir: str # Add save_dir here
    debug: bool = False
    dataAug: bool = False
    prob0: float = 0.1
    prob1: float = 0.1
    prob2: float = 0.6
    prob3: float = 0.6


    @classmethod
    def from_dict(cls,dikt):
        input_size = dikt['input_size']
        batch_size = dikt['batch_size']
        hidden = dikt['hidden']
        lr = dikt['lr']
        dropout = dikt['dropout']
        logname = dikt["logname"]
        outputLength = dikt["outputLength"]
        inputLength= dikt["inputLength"]
        subName = dikt['subName']
        save_dir = dikt['save_dir'] # Get save_dir from dictionary
        dataAug = dikt['dataAug']
        prob0 = dikt['prob0']
        prob1 = dikt['prob1']
        prob2 = dikt['prob2']
        prob3 = dikt['prob3']


        return cls(input_size,batch_size,hidden,lr,dropout,
                   logname,outputLength,inputLength,subName,save_dir,dataAug=dataAug, prob0=prob0, prob1=prob1, prob2=prob2, prob3=prob3)


Basic = collections.namedtuple("NILM", ["model", "model_opt"])
""")

# %% [markdown]
# # Task
# Modify the `main.py` script to save checkpoints to a specified Google Drive directory and run the script with the necessary arguments to enable this functionality.

# %% [markdown]
# ## Mount google drive
#
# ### Subtask:
# Mount Google Drive to access files from the Colab environment.

# %% [markdown]
# **Reasoning**:
# Mount Google Drive to access files from the Colab environment and then print the current working directory to confirm successful mounting.

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/MATNilm-master

# %%
import os
print(os.listdir("/content/drive/MyDrive/MATNilm_checkpoints"))
# Out:
# ['test']
