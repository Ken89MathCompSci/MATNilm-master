# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/MATNilm-master/blob/kengoh-just-add-kl-loss-only/matnilm_base_17_November_2025_interrupted_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
cd MATNilm-master/
# Out:
# /content/MATNilm-master

# %%
# !python main.py --dataAug
# Out:
# 2025-11-16 03:55:11,646 - root - INFO - Using computation device: cuda:0
# 2025-11-16 03:55:11,646 - root - INFO - Namespace(batch=32, lr=0.001, dropout=0.1, hidden=32, logname='root', subName='test', inputLength=864, outputLength=864, debug=False, dataAug=True, prob0=0.3, prob1=0.6, prob2=0.3, prob3=0.3, patience=30, resume=False, checkpoint='All_best_onoff.ckpt')
# 2025-11-16 03:55:11,646 - root - INFO - loading data
# 2025-11-16 03:55:11,681 - root - INFO - loading data finished
# 2025-11-16 03:55:11,685 - root - INFO - Training size: 27937.
# 2025-11-16 03:55:11,685 - root - INFO - Initialize model
# 2025-11-16 03:55:11,935 - root - INFO - Model MAT
# 2025-11-16 03:55:16,411 - root - INFO - Training start
# 2025-11-16 03:55:16,421 - root - INFO - # of epoches: 0
# ...
