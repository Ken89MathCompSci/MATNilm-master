# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/MATNilm-master/blob/kengoh-just-add-kl-loss-only/14-February-2026-Added-KL-Loss-RUN-Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
cd MATNilm-master/
# Out:
# /content/MATNilm-master

# %%
# !python main.py --epochs 20 --patience 10 --subName run20epochs
# Out:
# 2026-02-14 01:04:34,971 - root - INFO - Using computation device: cuda:0
# 2026-02-14 01:04:34,972 - root - INFO - Namespace(batch=32, lr=0.001, dropout=0.1, hidden=32, logname='root', subName='run20epochs', inputLength=864, outputLength=864, debug=False, dataAug=False, prob0=0.3, prob1=0.6, prob2=0.3, prob3=0.3, epochs=20, patience=10, resume=False, checkpoint='All_best_onoff.ckpt')
# 2026-02-14 01:04:34,972 - root - INFO - loading data
# 2026-02-14 01:04:35,008 - root - INFO - loading data finished
# 2026-02-14 01:04:35,013 - root - INFO - Training size: 27937.
# 2026-02-14 01:04:35,013 - root - INFO - Initialize model
# 2026-02-14 01:04:35,276 - root - INFO - Model MAT
# 2026-02-14 01:04:40,032 - root - INFO - Training start
# 2026-02-14 01:04:40,032 - root - INFO - # of epoches: 0
# ...
