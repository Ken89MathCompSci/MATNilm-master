# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/MATNilm-master/blob/master/MATNilm_base_22_September_2025-interrupted-results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
cd MATNilm-master/
# Out:
# /content/MATNilm-master

# %%
# Write the content of cell 95b50e1b to main.py
with open("main.py", "w") as f:
    f.write("""
import copy
import os
import utils
import argparse
import joblib
from tqdm import tqdm
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from custom_types import Basic, TrainConfig
from modules import MATconv as MAT
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"


def get_args():

    parser = argparse.ArgumentParser()

    parser.add_argument("--batch", type=int, default=32, help="batch size")
    parser.add_argument("--lr", type=float, default=0.001, help="learning rate")
    parser.add_argument("--dropout", type=float, default=0.1, help="dropout")
    parser.add_argument("--hidden", type=int, default=32, help="encoder decoder hidden size")
    parser.add_argument("--logname", action="store", default='root', help="name for log")
    parser.add_argument("--subName", action="store", type=str, default='test', help="name of the directory of current run")
    parser.add_argument("--inputLength", type=int, default=864, help="input length for the model")
    parser.add_argument("--outputLength", type=int, default=864, help="output length for the model")
    parser.add_argument("--debug", action="store_true", help="debug mode")
    parser.add_argument("--dataAug", action="store_true", help="data augmentation mode")
    parser.add_argument("--prob0", type=float, default=0.3, help="augment probability for Dishwasher")
    parser.add_argument("--prob1", type=float, default=0.6, help="weight")
    parser.add_argument("--prob2", type=float, default=0.3, help="weight")
    parser.add_argument("--prob3", type=float, default=0.3, help="weight")
    parser.add_argument("--resume", action="store_true", help="resume training from checkpoint")
    parser.add_argument("--checkpoint", type=str, default="All_best_onoff.ckpt", help="checkpoint file name to resume from")
    parser.add_argument("--save_dir", type=str, default="./", help="directory to save checkpoints")
    return parser.parse_args()


def train(t_net, train_Dataloader, vali_Dataloader, config, criterion, modelDir, epo=200):
    iter_loss = []
    vali_loss = []
    early_stopping_all = utils.EarlyStopping(logger, patience=30, verbose=True)

    if config.dataAug:
        sigClass = utils.sigGen(config)

    path_all = os.path.join(modelDir, "All_best_onoff.ckpt")

    for e_i in range(epo):

        logger.info(f"# of epoches: {e_i}")
        for t_i, (_, _, X_scaled, Y_scaled, Y_of) in enumerate(tqdm(train_Dataloader)):
            if config.dataAug:
                X_scaled, Y_scaled, Y_of = utils.dataAug(X_scaled.clone(), Y_scaled.clone(), Y_of.clone(), sigClass, config)

            t_net.model_opt.zero_grad(set_to_none=True)

            X_scaled = X_scaled.type(torch.FloatTensor).to(device, non_blocking=True)
            Y_scaled = Y_scaled.type(torch.FloatTensor).to(device, non_blocking=True)
            Y_of = Y_of.type(torch.FloatTensor).to(device, non_blocking=True)

            y_pred_dish_r, y_pred_dish_c = t_net.model(X_scaled)

            loss_r = criterion[0](y_pred_dish_r,Y_scaled)
            loss_c = criterion[1](y_pred_dish_c, Y_of)

            loss=loss_r+loss_c
            loss.backward()

            t_net.model_opt.step()
            iter_loss.append(loss.item())

        epoch_losses = np.average(iter_loss)

        logger.info(f"Validation: ")
        maeScore, y_vali_ori, y_vali_pred_d_update, _, _, _ = utils.evaluateResult(net, config, vali_Dataloader, logger)
        val_loss = criterion[0](y_vali_ori, y_vali_pred_d_update)
        logger.info(f"Epoch {e_i:d}, train loss: {epoch_losses:3.3f}, val loss: {val_loss:3.3f}.")
        vali_loss.append(val_loss)

        if e_i % 10 == 0:
            checkpointName = os.path.join(config.save_dir, "checkpoint_" + str(e_i) + '.ckpt')
            utils.saveModel(logger, net, checkpointName)

        logger.info(f"Early stopping overall: ")
        early_stopping_all(np.mean(maeScore), net, path_all)
        if early_stopping_all.early_stop:
            print("Early stopping")
            break

    net_all = copy.deepcopy(net)
    checkpoint_all = torch.load(path_all, map_location=device)
    utils.loadModel(logger, net_all, checkpoint_all)
    net_all.model.eval()

    return net_all

if __name__ == '__main__':
    args = get_args()
    utils.mkdir("log/" + args.subName)
    logger = utils.setup_log(args.subName, args.logname)
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using computation device: {device}")
    logger.info(args)
    if args.debug:
        epo = 2
    else:
        epo = 200

    # splitLoss = False
    # trainFull = True

    # Dataloder
    logger.info(f"loading data")
    train_data, val_data, test_data = utils.data_loader(args)

    logger.info(f"loading data finished")

    config_dict = {
        "input_size": 1,
        "batch_size": args.batch,
        "hidden": args.hidden,
        "lr": args.lr,
        "dropout": args.dropout,
        "logname": args.logname,
        "outputLength": args.outputLength,
        "inputLength" : args.inputLength,
        "subName": args.subName,
        "dataAug": args.dataAug,
        "prob0": args.prob0,
        "prob1": args.prob1,
        "prob2": args.prob2,
        "prob3": args.prob3,
        "save_dir": args.save_dir,
    }

    config = TrainConfig.from_dict(config_dict)
    modelDir = utils.mkdirectory(config.subName, saveModel=True)
    joblib.dump(config, os.path.join(modelDir, "config.pkl"))


    logger.info(f"Training size: {train_data.cumulative_sizes[-1]:d}.")

    index = np.arange(0,train_data.cumulative_sizes[-1])
    train_subsampler = torch.utils.data.SubsetRandomSampler(index)
    train_Dataloader = DataLoader(
        train_data,
        batch_size=config.batch_size,
        sampler=train_subsampler,
        num_workers=1,
        pin_memory=True)

    sampler = utils.testSampler(val_data.cumulative_sizes[-1], config.outputLength)
    sampler_test = utils.testSampler(test_data.cumulative_sizes[-1], config.outputLength)

    vali_Dataloader = DataLoader(
        val_data,
        batch_size=config.batch_size,
        sampler=sampler,
        num_workers=1,
        pin_memory=True)

    test_Dataloader = DataLoader(
        test_data,
        batch_size=config.batch_size,
        sampler=sampler_test,
        num_workers=1,
        pin_memory=True)

    logger.info("Initialize model")
    model = MAT(config).to(device)
    logger.info("Model MAT")

    optim = optim.Adam(params=[p for p in model.parameters() if p.requires_grad], lr=config.lr)
    net = Basic(model, optim)

    # Resume from checkpoint if specified
    if args.resume:
        checkpoint_path = os.path.join(modelDir, args.checkpoint)
        if os.path.exists(checkpoint_path):
            logger.info(f"Resuming training from checkpoint: {checkpoint_path}")
            checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=False)
            net = utils.loadModel(logger, net, checkpoint)
        else:
            logger.error(f"Checkpoint file not found: {checkpoint_path}")
            logger.info("Starting training from scratch")

    criterion_r = nn.MSELoss()
    criterion_c = nn.BCELoss()
    criterion = [criterion_r, criterion_c]

    logger.info("Training start")
    net_all = train(net, train_Dataloader, vali_Dataloader, config, criterion, modelDir, epo=epo)
    logger.info("Training end")

    logger.info("validation start")
    utils.evaluateResult(net_all, config, vali_Dataloader, logger)
    logger.info("test start")
    utils.evaluateResult(net_all, config, test_Dataloader, logger)
""")
# !python main.py --dataAug --resume --checkpoint checkpoint_80.ckpt --save_dir "/content/drive/MyDrive/MATNilm_checkpoints"
# Out:
# 2025-09-21 13:30:01,644 - root - INFO - Using computation device: cuda:0
# 2025-09-21 13:30:01,644 - root - INFO - Namespace(batch=32, lr=0.001, dropout=0.1, hidden=32, logname='root', subName='test', inputLength=864, outputLength=864, debug=False, dataAug=True, prob0=0.3, prob1=0.6, prob2=0.3, prob3=0.3, resume=True, checkpoint='checkpoint_80.ckpt', save_dir='/content/drive/MyDrive/MATNilm_checkpoints')
# 2025-09-21 13:30:01,644 - root - INFO - loading data
# 2025-09-21 13:30:01,674 - root - INFO - loading data finished
# 2025-09-21 13:30:01,674 - root - INFO - Training size: 27937.
# 2025-09-21 13:30:01,675 - root - INFO - Initialize model
# 2025-09-21 13:30:01,905 - root - INFO - Model MAT
# 2025-09-21 13:30:02,745 - root - INFO - Resuming training from checkpoint: history_model/test/s0/checkpoint_80.ckpt
# 2025-09-21 13:30:02,885 - root - INFO - Model loaded
# 2025-09-21 13:30:02,885 - root - INFO - Training start
# 2025-09-21 13:30:02,894 - root - INFO - # of epoches: 0
#   0% 0/874 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:366: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1027.)
#   return F.conv1d(
# 100% 874/874 [16:10<00:00,  1.11s/it]
# 2025-09-21 13:46:13,699 - root - INFO - Validation:
# 2025-09-21 13:46:14,009 - root - INFO - Evaluate dish washer:
# 2025-09-21 13:46:14,009 - root - INFO - MAE: 4.665012359619141
# 2025-09-21 13:46:14,010 - root - INFO - SAE: 3.731870651245117
# 2025-09-21 13:46:14,020 - root - INFO - F1: 0.9790272199910754
# 2025-09-21 13:46:14,020 - root - INFO - Evaluate fridge:
# 2025-09-21 13:46:14,020 - root - INFO - MAE: 21.5456600189209
# 2025-09-21 13:46:14,020 - root - INFO - SAE: 8.278116226196289
# 2025-09-21 13:46:14,024 - root - INFO - F1: 0.8504277352543899
# 2025-09-21 13:46:14,024 - root - INFO - Evaluate microwave:
# 2025-09-21 13:46:14,025 - root - INFO - MAE: 4.515059471130371
# 2025-09-21 13:46:14,025 - root - INFO - SAE: 3.5006444454193115
# 2025-09-21 13:46:14,029 - root - INFO - F1: 0.9325337331334332
# 2025-09-21 13:46:14,029 - root - INFO - Evaluate wash:
# 2025-09-21 13:46:14,029 - root - INFO - MAE: 6.198140621185303
# 2025-09-21 13:46:14,029 - root - INFO - SAE: 2.7999699115753174
# 2025-09-21 13:46:14,033 - root - INFO - F1: 0.9958601655933763
# 2025-09-21 13:46:14,034 - root - INFO - Epoch 0, train loss: 0.081, val loss: 941.811.
# 2025-09-21 13:46:18,341 - root - INFO - Model saved
# 2025-09-21 13:46:18,341 - root - INFO - Early stopping overall:
# 2025-09-21 13:46:18,341 - root - INFO - Validation loss decreased (inf --> 9.230968).  Saving model ...
# 2025-09-21 13:46:18,449 - root - INFO - Model saved
# 2025-09-21 13:46:18,449 - root - INFO - # of epoches: 1
# 100% 874/874 [16:14<00:00,  1.12s/it]
# 2025-09-21 14:02:33,065 - root - INFO - Validation:
# 2025-09-21 14:02:33,374 - root - INFO - Evaluate dish washer:
# 2025-09-21 14:02:33,374 - root - INFO - MAE: 8.08216381072998
- root - INFO - EarlyStopping counter: 4 out of 30
# 2025-09-21 14:51:22,695 - root - INFO - # of epoches: 5
# 100% 874/874 [16:13<00:00,  1.11s/it]
# 2025-09-21 15:07:36,589 - root - INFO - Validation:
# 2025-09-21 15:07:36,899 - root - INFO - Evaluate dish washer:
# 2025-09-21 15:07:36,900 - root - INFO - MAE: 3.7400808334350586
# 2025-09-21 15:07:36,900 - root - INFO - SAE: 2.983558177947998
# 2025-09-21 15:07:36,905 - root - INFO - F1: 0.9817534490431686
# 2025-09-21 15:07:36,905 - root - INFO - Evaluate fridge:
# 2025-09-21 15:07:36,905 - root - INFO - MAE: 19.43798828125
# 2025-09-21 15:07:36,905 - root - INFO - SAE: 7.783595085144043
# 2025-09-21 15:07:36,909 - root - INFO - F1: 0.8477568740955137
# 2025-09-21 15:07:36,909 - root - INFO - Evaluate microwave:
# 2025-09-21 15:07:36,909 - root - INFO - MAE: 6.447779655456543
# 2025-09-21 15:07:36,910 - root - INFO - SAE: 5.519744873046875
# 2025-09-21 15:07:36,913 - root - INFO - F1: 0.8809891808346213
# 2025-09-21 15:07:36,913 - root - INFO - Evaluate wash:
# 2025-09-21 15:07:36,913 - root - INFO - MAE: 6.5694146156311035
# 2025-09-21 15:07:36,914 - root - INFO - SAE: 4.107634544372559
# 2025-09-21 15:07:36,917 - root - INFO - F1: 0.9942555147058824
# 2025-09-21 15:07:36,917 - root - INFO - Epoch 5, train loss: 0.082, val loss: 1505.243.
# 2025-09-21 15:07:36,918 - root - INFO - Early stopping overall:
# 2025-09-21 15:07:36,918 - root - INFO - Validation loss decreased (9.230968 --> 9.048817).  Saving model ...
# 2025-09-21 15:07:37,034 - root - INFO - Model saved
# 2025-09-21 15:07:37,034 - root - INFO - # of epoches: 6
# 100% 874/874 [16:14<00:00,  1.11s/it]
# 2025-09-21 15:23:51,308 - root - INFO - Validation:
# 2025-09-21 15:23:51,613 - root - INFO - Evaluate dish washer:
# 2025-09-21 15:23:51,614 - root - INFO - MAE: 7.577476501464844
# 2025-09-21 15:23:51,614 - root - INFO - SAE: 7.16921329498291
# 2025-09-21 15:23:51,619 - root - INFO - F1: 0.938585345192715
# 2025-09-21 15:23:51,619 - root - INFO - Evaluate fridge:
# 2025-09-21 15:23:51,619 - root - INFO - MAE: 19.520719528198242
# 2025-09-21 15:23:51,619 - root - INFO - SAE: 6.01456356048584
# 2025-09-21 15:23:51,623 - root - INFO - F1: 0.8447870032768726
# 2025-09-21 15:23:51,623 - root - INFO - Evaluate microwave:
# 2025-09-21 15:23:51,623 - root - INFO - MAE: 7.586422443389893
# 2025-09-21 15:23:51,623 - root - INFO - SAE: 6.943624973297119
# 2025-09-21 15:23:51,627 - root - INFO - F1: 0.8296296296296296
# 2025-09-21 15:23:51,627 - root - INFO - Evaluate wash:
# 2025-09-21 15:23:51,627 - root - INFO - MAE: 7.158632755279541
# 2025-09-21 15:23:51,627 - root - INFO - SAE: 5.1011857986450195
# 2025-09-21 15:23:51,631 - root - INFO - F1: 0.980498866213152
# 2025-09-21 15:23:51,631 - root - INFO - Epoch 6, train loss: 0.082, val loss: 1956.338.
# 2025-09-21 15:23:51,631 - root - INFO - Early stopping overall:
# 2025-09-21 15:23:51,631 - root - INFO - EarlyStopping counter: 1 out of 30
# 2025-09
# 100% 874/874 [16:12<00:00,  1.11s/it]
# 2025-09-21 18:22:12,169 - root - INFO - Validation:
# 2025-09-21 18:22:12,492 - root - INFO - Evaluate dish washer:
# 2025-09-21 18:22:12,493 - root - INFO - MAE: 3.9010188579559326
# 2025-09-21 18:22:12,493 - root - INFO - SAE: 2.555048704147339
# 2025-09-21 18:22:12,498 - root - INFO - F1: 0.983957219251337
# 2025-09-21 18:22:12,498 - root - INFO - Evaluate fridge:
# 2025-09-21 18:22:12,498 - root - INFO - MAE: 19.702245712280273
# 2025-09-21 18:22:12,498 - root - INFO - SAE: 8.709364891052246
# 2025-09-21 18:22:12,502 - root - INFO - F1: 0.8630252100840337
# 2025-09-21 18:22:12,502 - root - INFO - Evaluate microwave:
# 2025-09-21 18:22:12,502 - root - INFO - MAE: 7.078639984130859
# 2025-09-21 18:22:12,503 - root - INFO - SAE: 5.813877582550049
# 2025-09-21 18:22:12,506 - root - INFO - F1: 0.8594771241830066
# 2025-09-21 18:22:12,506 - root - INFO - Evaluate wash:
# 2025-09-21 18:22:12,506 - root - INFO - MAE: 10.208243370056152
# 2025-09-21 18:22:12,507 - root - INFO - SAE: 4.645755290985107
# 2025-09-21 18:22:12,510 - root - INFO - F1: 0.947763907405163
# 2025-09-21 18:22:12,511 - root - INFO - Epoch 17, train loss: 0.081, val loss: 1871.723.
# 2025-09-21 18:22:12,511 - root - INFO - Early stopping overall:
# 2025-09-21 18:22:12,511 - root - INFO - EarlyStopping counter: 5 out of 30
# 2025-09-21 18:22:12,511 - root - INFO - # of epoches: 18
# 100% 874/874 [16:09<00:00,  1.11s/it]
# 2025-09-21 18:38:21,612 - root - INFO - Validation:
# 2025-09-21 18:38:21,920 - root - INFO - Evaluate dish washer:
# 2025-09-21 18:38:21,921 - root - INFO - MAE: 2.396604061126709
# 2025-09-21 18:38:21,921 - root - INFO - SAE: 1.2660211324691772
# 2025-09-21 18:38:21,926 - root - INFO - F1: 0.982174688057041
# 2025-09-21 18:38:21,926 - root - INFO - Evaluate fridge:
# 2025-09-21 18:38:21,926 - root - INFO - MAE: 22.774782180786133
# 2025-09-21 18:38:21,926 - root - INFO - SAE: 8.982722282409668
# 2025-09-21 18:38:21,930 - root - INFO - F1: 0.8371810449574727
# 2025-09-21 18:38:21,930 - root - INFO - Evaluate microwave:
# 2025-09-21 18:38:21,930 - root - INFO - MAE: 4.976278305053711
# 2025-09-21 18:38:21,930 - root - INFO - SAE: 3.4303343296051025
# 2025-09-21 18:38:21,934 - root - INFO - F1: 0.8940092165898618
# 2025-09-21 18:38:21,934 - root - INFO - Evaluate wash:
# 2025-09-21 18:38:21,934 - root - INFO - MAE: 5.4656805992126465
# 2025-09-21 18:38:21,934 - root - INFO - SAE: 3.5325937271118164
# 2025-09-21 18:38:21,938 - root - INFO - F1: 0.994701681640175
# 2025-09-21 18:38:21,938 - root - INFO - Epoch 18, train loss: 0.081, val loss: 1194.428.
# 2025-09-21 18:38:21,938 - root - INFO - Early stopping overall:
# 2025-09-21 18:38:21,939 - root - INFO - Validation loss decreased (9.000670 --> 8.903337).  Saving model ...
# 2025-09-21 18:38:22,058 - root - INFO - Model saved
# 2025-09-21 18:38:22,058 - root - INFO - # of epoches: 19
# 100% 874/874 [16:09<00:00,  1.11s/it]
# 2025-09-21 18:54:31,712 - root - INFO - Validation:
# 2025-09-21 18:54:32,020 - root - INFO - Evaluate dish washer:
- root - INFO - EarlyStopping counter: 4 out of 30
# 2025-09-21 19:43:04,449 - root - INFO - # of epoches: 23
# 100% 874/874 [16:10<00:00,  1.11s/it]
# 2025-09-21 19:59:14,637 - root - INFO - Validation:
# 2025-09-21 19:59:14,947 - root - INFO - Evaluate dish washer:
# 2025-09-21 19:59:14,947 - root - INFO - MAE: 3.2087979316711426
# 2025-09-21 19:59:14,948 - root - INFO - SAE: 2.5730063915252686
# 2025-09-21 19:59:14,952 - root - INFO - F1: 0.9796999117387467
# 2025-09-21 19:59:14,952 - root - INFO - Evaluate fridge:
# 2025-09-21 19:59:14,952 - root - INFO - MAE: 21.494686126708984
# 2025-09-21 19:59:14,953 - root - INFO - SAE: 9.282509803771973
# 2025-09-21 19:59:14,956 - root - INFO - F1: 0.8537161379949062
# 2025-09-21 19:59:14,956 - root - INFO - Evaluate microwave:
# 2025-09-21 19:59:14,956 - root - INFO - MAE: 7.28054666519165
# 2025-09-21 19:59:14,957 - root - INFO - SAE: 6.768285274505615
# 2025-09-21 19:59:14,960 - root - INFO - F1: 0.8113522537562604
# 2025-09-21 19:59:14,960 - root - INFO - Evaluate wash:
# 2025-09-21 19:59:14,960 - root - INFO - MAE: 7.758909702301025
# 2025-09-21 19:59:14,961 - root - INFO - SAE: 4.267209529876709
# 2025-09-21 19:59:14,964 - root - INFO - F1: 0.9534939759036145
# 2025-09-21 19:59:14,964 - root - INFO - Epoch 23, train loss: 0.081, val loss: 2202.272.
# 2025-09-21 19:59:14,964 - root - INFO - Early stopping overall:
# 2025-09-21 19:59:14,964 - root - INFO - EarlyStopping counter: 5 out of 30
# 2025-09-21 19:59:14,964 - root - INFO - # of epoches: 24
# 100% 874/874 [16:19<00:00,  1.12s/it]
# 2025-09-21 20:15:34,791 - root - INFO - Validation:
# 2025-09-21 20:15:35,102 - root - INFO - Evaluate dish washer:
# 2025-09-21 20:15:35,102 - root - INFO - MAE: 3.9533839225769043
# 2025-09-21 20:15:35,103 - root - INFO - SAE: 2.9430012702941895
# 2025-09-21 20:15:35,108 - root - INFO - F1: 0.9729965156794426
# 2025-09-21 20:15:35,108 - root - INFO - Evaluate fridge:
# 2025-09-21 20:15:35,108 - root - INFO - MAE: 20.512535095214844
# 2025-09-21 20:15:35,108 - root - INFO - SAE: 8.540185928344727
# 2025-09-21 20:15:35,112 - root - INFO - F1: 0.8345921450151057
# 2025-09-21 20:15:35,112 - root - INFO - Evaluate microwave:
# 2025-09-21 20:15:35,112 - root - INFO - MAE: 7.445261001586914
# 2025-09-21 20:15:35,112 - root - INFO - SAE: 6.699253082275391
# 2025-09-21 20:15:35,116 - root - INFO - F1: 0.8757961783439491
# 2025-09-21 20:15:35,116 - root - INFO - Evaluate wash:
# 2025-09-21 20:15:35,116 - root - INFO - MAE: 6.459911823272705
# 2025-09-21 20:15:35,117 - root - INFO - SAE: 3.375370740890503
# 2025-09-21 20:15:35,120 - root - INFO - F1: 0.9618338650596715
# 2025-09-21 20:15:35,121 - root - INFO - Epoch 24, train loss: 0.081, val loss: 1852.888.
# 2025-09-21 20:15:35,121 - root - INFO - Early stopping overall:
# 2025-09-21 20:15:35,121 - root - INFO - EarlyStopping counter: 6 out of 30
# 2025-09-21 20:15:35,121 - root - INFO - # of epoches: 25
# 100% 874/874 [16:16<00:00,  1.12s/it]
# 2025-09-21 20:31:51,131 - root - INFO - Validation:
# 2025-09-21 20:31:51,446 - root - INFO - Evaluate dish washer:
# 2025-09-21 20:31:51,446 - root - INFO - MAE: 9.046361923217773
# 2025-09-21 20:31:51,446 - root - INFO - SAE: 8.546224594116211
# 2025-09-21 20:31:51,451 - root - INFO - F1: 0.9125506072874494
# 2025-09-21 20:31:51,451 - root - INFO - Evaluate fridge:
# 2025-09-21 20:31:51,452 - root - INFO - MAE: 19.933378219604492
# 2025-09-21 20:31:51,452 - root - INFO - SAE: 8.122925758361816
# 2025-09-21 20:31:51,456 - root - INFO - F1: 0.8600400145507457
# 2025-09-21 20:31:51,456 - root - INFO - Evaluate microwave:
# 2025-09-21 20:31:51,456 - root - INFO - MAE: 6.985191345214844
# 2025-09-21 20:31:51,456 - root - INFO - SAE: 5.453298568725586
# 2025-09-21 20:31:51,460 - root - INFO - F1: 0.7726675427069645
# 2025-09-21 20:31:51,460 - root - INFO - Evaluate wash:
# 2025-09-21 20:31:51,460 - root - INFO - MAE: 8.718780517578125
# 2025-09-21 20:31:51,460 - root - INFO - SAE: 4.9986419677734375
# 2025-09-21 20:31:51,464 - root - INFO - F1: 0.9938550724637681
# 2025-09-21 20:31:51,464 - root - INFO - Epoch 25, train loss: 0.081, val loss: 1583.318.
# 2025-09-21 20:31:51,465 - root - INFO - Early stopping overall:
# 2025-09-21 20:31:51,465 - root - INFO - EarlyStopping counter: 7 out of 30
# 2025-09-21 20:31:51,465 - root - INFO - # of epoches: 26
# 100% 874/874 [16:11<00:00,  1.11s/it]
# 2025-09-21 20:48:03,385 - root - INFO - Validation:
# 2025-09-21 20:48:03,703 - root - INFO - Evaluate dish washer:
# 2025-09-21 20:48:03,704 - root - INFO - MAE: 3.770514726638794
# 2025-09-21 20:48:03,704 - root - INFO - SAE: 3.050410270690918
# 2025-09-21 20:48:03,709 - root - INFO - F1: 0.9821905609973286
# 2025-09-21 20:48:03,709 - root - INFO - Evaluate fridge:
# 2025-09-21 20:48:03,709 - root - INFO - MAE: 19.003734588623047
# 2025-09-21 20:48:03,709 - root - INFO - SAE: 5.871303081512451
# 2025-09-21 20:48:03,713 - root - INFO - F1: 0.8545235669969442
# 2025-09-21 20:48:03,713 - root - INFO - Evaluate microwave:
# 2025-09-21 20:48:03,713 - root - INFO - MAE: 7.376069068908691
# 2025-09-21 20:48:03,713 - root - INFO - SAE: 6.2020649909973145
# 2025-09-21 20:48:03,716 - root - INFO - F1: 0.8628048780487805
# 2025-09-21 20:48:03,717 - root - INFO - Evaluate wash:
# 2025-09-21 20:48:03,717 - root - INFO - MAE: 5.543843746185303
# 2025-09-21 20:48:03,717 - root - INFO - SAE: 2.8886494636535645
# 2025-09-21 20:48:03,720 - root - INFO - F1: 0.9864927806241267
# 2025-09-21 20:48:03,721 - root - INFO - Epoch 26, train loss: 0.081, val loss: 1560.023.
# 2025-09-21 20:48:03,721 - root - INFO - Early stopping overall:
# 2025-09-21 20:48:03,721 - root - INFO - EarlyStopping counter: 8 out of 30
# 2025-09-21 20:48:03,721 - root - INFO - # of epoches: 27
# 100% 874/874 [16:08<00:00,  1.11s/it]
# 2025-09-21 21:04:12,025 - root - INFO - Validation:
# 100% 874/874 [16:09<00:00,  1.11s/it]
# 2025-09-21 21:36:30,315 - root - INFO - Validation:
# 2025-09-21 21:36:30,625 - root - INFO - Evaluate dish washer:
# 2025-09-21 21:36:30,626 - root - INFO - MAE: 9.574359893798828
# 2025-09-21 21:36:30,626 - root - INFO - SAE: 9.148794174194336
# 2025-09-21 21:36:30,631 - root - INFO - F1: 0.9084188911704312
# 2025-09-21 21:36:30,631 - root - INFO - Evaluate fridge:
# 2025-09-21 21:36:30,631 - root - INFO - MAE: 21.694530487060547
# 2025-09-21 21:36:30,631 - root - INFO - SAE: 11.518295288085938
# 2025-09-21 21:36:30,635 - root - INFO - F1: 0.818241469816273
# 2025-09-21 21:36:30,635 - root - INFO - Evaluate microwave:
# 2025-09-21 21:36:30,635 - root - INFO - MAE: 6.103260040283203
# 2025-09-21 21:36:30,635 - root - INFO - SAE: 5.550167560577393
# 2025-09-21 21:36:30,639 - root - INFO - F1: 0.8987730061349694
# 2025-09-21 21:36:30,639 - root - INFO - Evaluate wash:
# 2025-09-21 21:36:30,639 - root - INFO - MAE: 6.735182762145996
# 2025-09-21 21:36:30,639 - root - INFO - SAE: 4.152612209320068
# 2025-09-21 21:36:30,643 - root - INFO - F1: 0.9470772191484244
# 2025-09-21 21:36:30,643 - root - INFO - Epoch 29, train loss: 0.081, val loss: 1782.995.
# 2025-09-21 21:36:30,644 - root - INFO - Early stopping overall:
# 2025-09-21 21:36:30,644 - root - INFO - EarlyStopping counter: 11 out of 30
# 2025-09-21 21:36:30,644 - root - INFO - # of epoches: 30
# 100% 874/874 [16:16<00:00,  1.12s/it]
# 2025-09-21 21:52:46,782 - root - INFO - Validation:
# 2025-09-21 21:52:47,093 - root - INFO - Evaluate dish washer:
# 2025-09-21 21:52:47,094 - root - INFO - MAE: 4.344283580780029
# 2025-09-21 21:52:47,094 - root - INFO - SAE: 3.1199111938476562
# 2025-09-21 21:52:47,099 - root - INFO - F1: 0.9520137103684662
# 2025-09-21 21:52:47,099 - root - INFO - Evaluate fridge:
# 2025-09-21 21:52:47,099 - root - INFO - MAE: 22.18657684326172
# 2025-09-21 21:52:47,100 - root - INFO - SAE: 7.1330885887146
# 2025-09-21 21:52:47,103 - root - INFO - F1: 0.8182210501078878
# 2025-09-21 21:52:47,104 - root - INFO - Evaluate microwave:
# 2025-09-21 21:52:47,104 - root - INFO - MAE: 6.664048671722412
# 2025-09-21 21:52:47,104 - root - INFO - SAE: 5.485902786254883
# 2025-09-21 21:52:47,108 - root - INFO - F1: 0.89375
# 2025-09-21 21:52:47,108 - root - INFO - Evaluate wash:
# 2025-09-21 21:52:47,108 - root - INFO - MAE: 7.2226786613464355
# 2025-09-21 21:52:47,108 - root - INFO - SAE: 3.506033182144165
# 2025-09-21 21:52:47,112 - root - INFO - F1: 0.9556437071763433
# 2025-09-21 21:52:47,113 - root - INFO - Epoch 30, train loss: 0.080, val loss: 1428.439.
# 2025-09-21 21:52:52,321 - root - INFO - Model saved
# 2025-09-21 21:52:52,321 - root - INFO - Early stopping overall:
# 2025-09-22 07:05:59,727 - root - INFO - F1: 0.8840125391849529
# 2025-09-22 07:05:59,727 - root - INFO - Evaluate wash:
# 2025-09-22 07:05:59,727 - root - INFO - MAE: 5.650485038757324
# 2025-09-22 07:05:59,727 - root - INFO - SAE: 2.926849842071533
# 2025-09-22 07:05:59,731 - root - INFO - F1: 0.9844789356984479
# 2025-09-22 07:05:59,731 - root - INFO - Epoch 64, train loss: 0.079, val loss: 1565.163.
# 2025-09-22 07:05:59,731 - root - INFO - Early stopping overall:
# 2025-09-22 07:05:59,732 - root - INFO - EarlyStopping counter: 17 out of 30
# 2025-09-22 07:05:59,732 - root - INFO - # of epoches: 65
# 100% 874/874 [16:10<00:00,  1.11s/it]
# 2025-09-22 07:22:10,686 - root - INFO - Validation:
# 2025-09-22 07:22:11,000 - root - INFO - Evaluate dish washer:
# 2025-09-22 07:22:11,000 - root - INFO - MAE: 9.730049133300781
# 2025-09-22 07:22:11,001 - root - INFO - SAE: 9.351957321166992
# 2025-09-22 07:22:11,005 - root - INFO - F1: 0.8675445391169636
# 2025-09-22 07:22:11,005 - root - INFO - Evaluate fridge:
# 2025-09-22 07:22:11,006 - root - INFO - MAE: 20.019683837890625
# 2025-09-22 07:22:11,006 - root - INFO - SAE: 8.701179504394531
# 2025-09-22 07:22:11,009 - root - INFO - F1: 0.8408944510904574
# 2025-09-22 07:22:11,009 - root - INFO - Evaluate microwave:
# 2025-09-22 07:22:11,010 - root - INFO - MAE: 6.764394760131836
# 2025-09-22 07:22:11,010 - root - INFO - SAE: 5.434628486633301
# 2025-09-22 07:22:11,013 - root - INFO - F1: 0.8598726114649682
# 2025-09-22 07:22:11,013 - root - INFO - Evaluate wash:
# 2025-09-22 07:22:11,013 - root - INFO - MAE: 6.69668436050415
# 2025-09-22 07:22:11,014 - root - INFO - SAE: 5.28487491607666
# 2025-09-22 07:22:11,017 - root - INFO - F1: 0.9970018450184502
# 2025-09-22 07:22:11,018 - root - INFO - Epoch 65, train loss: 0.079, val loss: 1768.552.
# 2025-09-22 07:22:11,018 - root - INFO - Early stopping overall:
# 2025-09-22 07:22:11,018 - root - INFO - EarlyStopping counter: 18 out of 30
# 2025-09-22 07:22:11,018 - root - INFO - # of epoches: 66
# 100% 874/874 [16:14<00:00,  1.11s/it]
# 2025-09-22 07:38:25,130 - root - INFO - Validation:
# 2025-09-22 07:38:25,445 - root - INFO - Evaluate dish washer:
# 2025-09-22 07:38:25,446 - root - INFO - MAE: 8.842185020446777
# 2025-09-22 07:38:25,446 - root - INFO - SAE: 8.397265434265137
# 2025-09-22 07:38:25,451 - root - INFO - F1: 0.9187192118226601
# 2025-09-22 07:38:25,451 - root - INFO - Evaluate fridge:
# 2025-09-22 07:38:25,451 - root - INFO - MAE: 20.60079574584961
# 2025-09-22 07:38:25,452 - root - INFO - SAE: 7.53279447555542
# 2025-09-22 07:38:25,455 - root - INFO - F1: 0.8629941552763588
# 2025-09-22 07:38:25,455 - root - INFO - Evaluate microwave:
# 2025-09-22 07:38:25,456 - root - INFO - MAE: 5.926638126373291
# 2025-09-22 08:10:50,391 - root - INFO - SAE: 5.908536911010742
# 2025-09-22 08:10:50,394 - root - INFO - F1: 0.8783570300157978
# 2025-09-22 08:10:50,394 - root - INFO - Evaluate wash:
# 2025-09-22 08:10:50,394 - root - INFO - MAE: 12.968586921691895
# 2025-09-22 08:10:50,395 - root - INFO - SAE: 12.452227592468262
# 2025-09-22 08:10:50,398 - root - INFO - F1: 0.9645539906103286
# 2025-09-22 08:10:50,399 - root - INFO - Epoch 68, train loss: 0.079, val loss: 2108.837.
# 2025-09-22 08:10:50,399 - root - INFO - Early stopping overall:
# 2025-09-22 08:10:50,399 - root - INFO - EarlyStopping counter: 21 out of 30
# 2025-09-22 08:10:50,399 - root - INFO - # of epoches: 69
# 100% 874/874 [16:12<00:00,  1.11s/it]
# 2025-09-22 08:27:02,445 - root - INFO - Validation:
# 2025-09-22 08:27:02,757 - root - INFO - Evaluate dish washer:
# 2025-09-22 08:27:02,758 - root - INFO - MAE: 4.071147441864014
# 2025-09-22 08:27:02,758 - root - INFO - SAE: 3.5708351135253906
# 2025-09-22 08:27:02,763 - root - INFO - F1: 0.9725010912265386
# 2025-09-22 08:27:02,763 - root - INFO - Evaluate fridge:
# 2025-09-22 08:27:02,763 - root - INFO - MAE: 21.366230010986328
# 2025-09-22 08:27:02,763 - root - INFO - SAE: 7.474896430969238
# 2025-09-22 08:27:02,767 - root - INFO - F1: 0.8324668633787644
# 2025-09-22 08:27:02,767 - root - INFO - Evaluate microwave:
# 2025-09-22 08:27:02,767 - root - INFO - MAE: 6.594779014587402
# 2025-09-22 08:27:02,767 - root - INFO - SAE: 5.5611958503723145
# 2025-09-22 08:27:02,771 - root - INFO - F1: 0.8710691823899371
# 2025-09-22 08:27:02,771 - root - INFO - Evaluate wash:
# 2025-09-22 08:27:02,771 - root - INFO - MAE: 8.98153305053711
# 2025-09-22 08:27:02,771 - root - INFO - SAE: 8.23959732055664
# 2025-09-22 08:27:02,775 - root - INFO - F1: 0.9451597520267048
# 2025-09-22 08:27:02,775 - root - INFO - Epoch 69, train loss: 0.079, val loss: 1697.235.
# 2025-09-22 08:27:02,775 - root - INFO - Early stopping overall:
# 2025-09-22 08:27:02,775 - root - INFO - EarlyStopping counter: 22 out of 30
# 2025-09-22 08:27:02,776 - root - INFO - # of epoches: 70
# 100% 874/874 [16:13<00:00,  1.11s/it]
# 2025-09-22 08:43:16,780 - root - INFO - Validation:
# 2025-09-22 08:43:17,092 - root - INFO - Evaluate dish washer:
# 2025-09-22 08:43:17,092 - root - INFO - MAE: 4.3389573097229
# 2025-09-22 08:43:17,093 - root - INFO - SAE: 3.5953919887542725
# 2025-09-22 08:43:17,098 - root - INFO - F1: 0.9841549295774648
# 2025-09-22 08:43:17,098 - root - INFO - Evaluate fridge:
# 2025-09-22 08:43:17,098 - root - INFO - MAE: 18.6253719329834
# 2025-09-22 08:43:17,098 - root - INFO - SAE: 6.12367582321167
# 2025-09-22 08:43:17,102 - root - INFO - F1: 0.8653371146281219
# 2025-09-22 08:43:17,102 - root - INFO - Evaluate microwave:
# 2025-09-22 08:43:17,102 - root - INFO - MAE: 7.955159664154053
# 2025-09-22 09:15:44,709 - root - INFO - F1: 0.8474173033810678
# 2025-09-22 09:15:44,709 - root - INFO - Evaluate microwave:
# 2025-09-22 09:15:44,709 - root - INFO - MAE: 7.680941581726074
# 2025-09-22 09:15:44,709 - root - INFO - SAE: 6.386612892150879
# 2025-09-22 09:15:44,713 - root - INFO - F1: 0.782991202346041
# 2025-09-22 09:15:44,713 - root - INFO - Evaluate wash:
# 2025-09-22 09:15:44,713 - root - INFO - MAE: 8.363654136657715
# 2025-09-22 09:15:44,713 - root - INFO - SAE: 7.160760402679443
# 2025-09-22 09:15:44,717 - root - INFO - F1: 0.9957299480669359
# 2025-09-22 09:15:44,717 - root - INFO - Epoch 72, train loss: 0.079, val loss: 1906.709.
# 2025-09-22 09:15:44,718 - root - INFO - Early stopping overall:
# 2025-09-22 09:15:44,718 - root - INFO - EarlyStopping counter: 25 out of 30
# 2025-09-22 09:15:44,718 - root - INFO - # of epoches: 73
# 100% 874/874 [16:14<00:00,  1.11s/it]
# 2025-09-22 09:31:58,986 - root - INFO - Validation:
# 2025-09-22 09:31:59,303 - root - INFO - Evaluate dish washer:
# 2025-09-22 09:31:59,303 - root - INFO - MAE: 3.9738552570343018
# 2025-09-22 09:31:59,304 - root - INFO - SAE: 3.074146270751953
# 2025-09-22 09:31:59,308 - root - INFO - F1: 0.9849157054125999
# 2025-09-22 09:31:59,308 - root - INFO - Evaluate fridge:
# 2025-09-22 09:31:59,308 - root - INFO - MAE: 19.145803451538086
# 2025-09-22 09:31:59,309 - root - INFO - SAE: 7.360414505004883
# 2025-09-22 09:31:59,312 - root - INFO - F1: 0.8551704836979337
# 2025-09-22 09:31:59,312 - root - INFO - Evaluate microwave:
# 2025-09-22 09:31:59,312 - root - INFO - MAE: 5.725763320922852
# 2025-09-22 09:31:59,313 - root - INFO - SAE: 5.083723545074463
# 2025-09-22 09:31:59,316 - root - INFO - F1: 0.9228395061728395
# 2025-09-22 09:31:59,316 - root - INFO - Evaluate wash:
# 2025-09-22 09:31:59,317 - root - INFO - MAE: 8.673538208007812
# 2025-09-22 09:31:59,317 - root - INFO - SAE: 5.249352931976318
# 2025-09-22 09:31:59,321 - root - INFO - F1: 0.9631923764145325
# 2025-09-22 09:31:59,321 - root - INFO - Epoch 73, train loss: 0.079, val loss: 1434.081.
# 2025-09-22 09:31:59,321 - root - INFO - Early stopping overall:
# 2025-09-22 09:31:59,321 - root - INFO - EarlyStopping counter: 26 out of 30
# 2025-09-22 09:31:59,321 - root - INFO - # of epoches: 74
# 100% 874/874 [16:10<00:00,  1.11s/it]
# 2025-09-22 09:48:09,722 - root - INFO - Validation:
# 2025-09-22 09:48:10,035 - root - INFO - Evaluate dish washer:
# 2025-09-22 09:48:10,035 - root - INFO - MAE: 3.7552809715270996
# 2025-09-22 09:48:10,035 - root - INFO - SAE: 2.1492700576782227
# 2025-09-22 09:48:10,040 - root - INFO - F1: 0.9835482436638506
# 2025-09-22 09:48:10,040 - root - INFO - Evaluate fridge:
# 2025-09-22 09:48:10,040 - root - INFO - MAE: 17.83685874938965
# 2025-09-22 09:48:10,041 - root - INFO - SAE: 5.512959003448486
# 2025-09-22 09:48:10,044 - root - INFO - F1: 0.8717854518736223
# 2025-09-22 09:48:10,044 - root - INFO - Evaluate microwave:
# 2025-09-22 09:48:10,044 - root - INFO - MAE: 4.957156181335449
# 2025-09-22 09:48:10,045 - root - INFO - SAE: 3.5933806896209717
# 2025-09-22 09:48:10,048 - root - INFO - F1: 0.9272727272727272
# 2025-09-22 09:48:10,048 - root - INFO - Evaluate wash:
# 2025-09-22 09:48:10,048 - root - INFO - MAE: 7.188157081604004
# 2025-09-22 09:48:10,049 - root - INFO - SAE: 3.163939952850342
# 2025-09-22 09:48:10,052 - root - INFO - F1: 0.9764150943396226
# 2025-09-22 09:48:10,053 - root - INFO - Epoch 74, train loss: 0.079, val loss: 905.384.
# 2025-09-22 09:48:10,053 - root - INFO - Early stopping overall:
# 2025-09-22 09:48:10,053 - root - INFO - Validation loss decreased (8.543191 --> 8.434363).  Saving model ...
# 2025-09-22 09:48:10,169 - root - INFO - Model saved
# 2025-09-22 09:48:10,170 - root - INFO - # of epoches: 75
#  46% 402/874 [07:26<08:50,  1.12s/it]^C

# %%
# Modify custom_types.py to include save_dir in TrainConfig.from_dict
with open("custom_types.py", "w") as f:
    f.write("""
import collections
import typing

class TrainConfig(typing.NamedTuple):

    input_size: int
    batch_size: int
    hidden: int
    lr: float
    dropout: float
    logname: str
    outputLength: int
    inputLength: int
    subName: str
    save_dir: str # Add save_dir here
    debug: bool = False
    dataAug: bool = False
    prob0: float = 0.1
    prob1: float = 0.1
    prob2: float = 0.6
    prob3: float = 0.6


    @classmethod
    def from_dict(cls,dikt):
        input_size = dikt['input_size']
        batch_size = dikt['batch_size']
        hidden = dikt['hidden']
        lr = dikt['lr']
        dropout = dikt['dropout']
        logname = dikt["logname"]
        outputLength = dikt["outputLength"]
        inputLength= dikt["inputLength"]
        subName = dikt['subName']
        save_dir = dikt['save_dir'] # Get save_dir from dictionary
        dataAug = dikt['dataAug']
        prob0 = dikt['prob0']
        prob1 = dikt['prob1']
        prob2 = dikt['prob2']
        prob3 = dikt['prob3']


        return cls(input_size,batch_size,hidden,lr,dropout,
                   logname,outputLength,inputLength,subName,save_dir,dataAug=dataAug, prob0=prob0, prob1=prob1, prob2=prob2, prob3=prob3)


Basic = collections.namedtuple("NILM", ["model", "model_opt"])
""")

# %% [markdown]
# # Task
# Modify the `main.py` script to save checkpoints to a specified Google Drive directory and run the script with the necessary arguments to enable this functionality.

# %% [markdown]
# ## Mount google drive
#
# ### Subtask:
# Mount Google Drive to access files from the Colab environment.

# %% [markdown]
# **Reasoning**:
# Mount Google Drive to access files from the Colab environment and then print the current working directory to confirm successful mounting.

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/MATNilm-master

# %%
import os
print(os.listdir("/content/drive/MyDrive/MATNilm_checkpoints"))
# Out:
# ['test', 'checkpoint_0.ckpt', 'checkpoint_10.ckpt', 'checkpoint_20.ckpt', 'checkpoint_30.ckpt', 'checkpoint_40.ckpt', 'checkpoint_50.ckpt', 'checkpoint_60.ckpt', 'checkpoint_70.ckpt', 'checkpoint_80.ckpt']
