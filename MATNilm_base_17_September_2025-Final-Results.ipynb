# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/MATNilm-master/blob/master/MATNilm_base_17_September_2025-Final-Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
cd MATNilm-master/
# Out:
# /content/MATNilm-master

# %%
# Write the content of cell 95b50e1b to main.py
with open("main.py", "w") as f:
    f.write("""
import copy
import os
import utils
import argparse
import joblib
from tqdm import tqdm
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from custom_types import Basic, TrainConfig
from modules import MATconv as MAT
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"


def get_args():

    parser = argparse.ArgumentParser()

    parser.add_argument("--batch", type=int, default=32, help="batch size")
    parser.add_argument("--lr", type=float, default=0.001, help="learning rate")
    parser.add_argument("--dropout", type=float, default=0.1, help="dropout")
    parser.add_argument("--hidden", type=int, default=32, help="encoder decoder hidden size")
    parser.add_argument("--logname", action="store", default='root', help="name for log")
    parser.add_argument("--subName", action="store", type=str, default='test', help="name of the directory of current run")
    parser.add_argument("--inputLength", type=int, default=864, help="input length for the model")
    parser.add_argument("--outputLength", type=int, default=864, help="output length for the model")
    parser.add_argument("--debug", action="store_true", help="debug mode")
    parser.add_argument("--dataAug", action="store_true", help="data augmentation mode")
    parser.add_argument("--prob0", type=float, default=0.3, help="augment probability for Dishwasher")
    parser.add_argument("--prob1", type=float, default=0.6, help="weight")
    parser.add_argument("--prob2", type=float, default=0.3, help="weight")
    parser.add_argument("--prob3", type=float, default=0.3, help="weight")
    parser.add_argument("--resume", action="store_true", help="resume training from checkpoint")
    parser.add_argument("--checkpoint", type=str, default="All_best_onoff.ckpt", help="checkpoint file name to resume from")
    parser.add_argument("--save_dir", type=str, default="./", help="directory to save checkpoints")
    return parser.parse_args()


def train(t_net, train_Dataloader, vali_Dataloader, config, criterion, modelDir, epo=200):
    iter_loss = []
    vali_loss = []
    early_stopping_all = utils.EarlyStopping(logger, patience=30, verbose=True)

    if config.dataAug:
        sigClass = utils.sigGen(config)

    path_all = os.path.join(modelDir, "All_best_onoff.ckpt")

    for e_i in range(epo):

        logger.info(f"# of epoches: {e_i}")
        for t_i, (_, _, X_scaled, Y_scaled, Y_of) in enumerate(tqdm(train_Dataloader)):
            if config.dataAug:
                X_scaled, Y_scaled, Y_of = utils.dataAug(X_scaled.clone(), Y_scaled.clone(), Y_of.clone(), sigClass, config)

            t_net.model_opt.zero_grad(set_to_none=True)

            X_scaled = X_scaled.type(torch.FloatTensor).to(device, non_blocking=True)
            Y_scaled = Y_scaled.type(torch.FloatTensor).to(device, non_blocking=True)
            Y_of = Y_of.type(torch.FloatTensor).to(device, non_blocking=True)

            y_pred_dish_r, y_pred_dish_c = t_net.model(X_scaled)

            loss_r = criterion[0](y_pred_dish_r,Y_scaled)
            loss_c = criterion[1](y_pred_dish_c, Y_of)

            loss=loss_r+loss_c
            loss.backward()

            t_net.model_opt.step()
            iter_loss.append(loss.item())

        epoch_losses = np.average(iter_loss)

        logger.info(f"Validation: ")
        maeScore, y_vali_ori, y_vali_pred_d_update, _, _, _ = utils.evaluateResult(net, config, vali_Dataloader, logger)
        val_loss = criterion[0](y_vali_ori, y_vali_pred_d_update)
        logger.info(f"Epoch {e_i:d}, train loss: {epoch_losses:3.3f}, val loss: {val_loss:3.3f}.")
        vali_loss.append(val_loss)

        if e_i % 10 == 0:
            checkpointName = os.path.join(config.save_dir, "checkpoint_" + str(e_i) + '.ckpt')
            utils.saveModel(logger, net, checkpointName)

        logger.info(f"Early stopping overall: ")
        early_stopping_all(np.mean(maeScore), net, path_all)
        if early_stopping_all.early_stop:
            print("Early stopping")
            break

    net_all = copy.deepcopy(net)
    checkpoint_all = torch.load(path_all, map_location=device)
    utils.loadModel(logger, net_all, checkpoint_all)
    net_all.model.eval()

    return net_all

if __name__ == '__main__':
    args = get_args()
    utils.mkdir("log/" + args.subName)
    logger = utils.setup_log(args.subName, args.logname)
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using computation device: {device}")
    logger.info(args)
    if args.debug:
        epo = 2
    else:
        epo = 200

    # splitLoss = False
    # trainFull = True

    # Dataloder
    logger.info(f"loading data")
    train_data, val_data, test_data = utils.data_loader(args)

    logger.info(f"loading data finished")

    config_dict = {
        "input_size": 1,
        "batch_size": args.batch,
        "hidden": args.hidden,
        "lr": args.lr,
        "dropout": args.dropout,
        "logname": args.logname,
        "outputLength": args.outputLength,
        "inputLength" : args.inputLength,
        "subName": args.subName,
        "dataAug": args.dataAug,
        "prob0": args.prob0,
        "prob1": args.prob1,
        "prob2": args.prob2,
        "prob3": args.prob3,
        "save_dir": args.save_dir,
    }

    config = TrainConfig.from_dict(config_dict)
    modelDir = utils.mkdirectory(config.subName, saveModel=True)
    joblib.dump(config, os.path.join(modelDir, "config.pkl"))


    logger.info(f"Training size: {train_data.cumulative_sizes[-1]:d}.")

    index = np.arange(0,train_data.cumulative_sizes[-1])
    train_subsampler = torch.utils.data.SubsetRandomSampler(index)
    train_Dataloader = DataLoader(
        train_data,
        batch_size=config.batch_size,
        sampler=train_subsampler,
        num_workers=1,
        pin_memory=True)

    sampler = utils.testSampler(val_data.cumulative_sizes[-1], config.outputLength)
    sampler_test = utils.testSampler(test_data.cumulative_sizes[-1], config.outputLength)

    vali_Dataloader = DataLoader(
        val_data,
        batch_size=config.batch_size,
        sampler=sampler,
        num_workers=1,
        pin_memory=True)

    test_Dataloader = DataLoader(
        test_data,
        batch_size=config.batch_size,
        sampler=sampler_test,
        num_workers=1,
        pin_memory=True)

    logger.info("Initialize model")
    model = MAT(config).to(device)
    logger.info("Model MAT")

    optim = optim.Adam(params=[p for p in model.parameters() if p.requires_grad], lr=config.lr)
    net = Basic(model, optim)

    # Resume from checkpoint if specified
    if args.resume:
        checkpoint_path = os.path.join(modelDir, args.checkpoint)
        if os.path.exists(checkpoint_path):
            logger.info(f"Resuming training from checkpoint: {checkpoint_path}")
            checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=False)
            net = utils.loadModel(logger, net, checkpoint)
        else:
            logger.error(f"Checkpoint file not found: {checkpoint_path}")
            logger.info("Starting training from scratch")

    criterion_r = nn.MSELoss()
    criterion_c = nn.BCELoss()
    criterion = [criterion_r, criterion_c]

    logger.info("Training start")
    net_all = train(net, train_Dataloader, vali_Dataloader, config, criterion, modelDir, epo=epo)
    logger.info("Training end")

    logger.info("validation start")
    utils.evaluateResult(net_all, config, vali_Dataloader, logger)
    logger.info("test start")
    utils.evaluateResult(net_all, config, test_Dataloader, logger)
""")
# !python main.py --dataAug --resume --checkpoint checkpoint_70.ckpt --save_dir "/content/drive/MyDrive/MATNilm_checkpoints"
# Out:
# 2025-09-22 10:08:20,504 - root - INFO - Using computation device: cuda:0
# 2025-09-22 10:08:20,504 - root - INFO - Namespace(batch=32, lr=0.001, dropout=0.1, hidden=32, logname='root', subName='test', inputLength=864, outputLength=864, debug=False, dataAug=True, prob0=0.3, prob1=0.6, prob2=0.3, prob3=0.3, resume=True, checkpoint='checkpoint_70.ckpt', save_dir='/content/drive/MyDrive/MATNilm_checkpoints')
# 2025-09-22 10:08:20,504 - root - INFO - loading data
# 2025-09-22 10:08:20,536 - root - INFO - loading data finished
# 2025-09-22 10:08:20,537 - root - INFO - Training size: 27937.
# 2025-09-22 10:08:20,537 - root - INFO - Initialize model
# 2025-09-22 10:08:20,792 - root - INFO - Model MAT
# 2025-09-22 10:08:21,684 - root - INFO - Resuming training from checkpoint: history_model/test/s0/checkpoint_70.ckpt
# 2025-09-22 10:08:21,833 - root - INFO - Model loaded
# 2025-09-22 10:08:21,833 - root - INFO - Training start
# 2025-09-22 10:08:21,844 - root - INFO - # of epoches: 0
#   0% 0/874 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:366: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1027.)
#   return F.conv1d(
# 100% 874/874 [16:30<00:00,  1.13s/it]
# 2025-09-22 10:24:52,519 - root - INFO - Validation:
# 2025-09-22 10:24:52,842 - root - INFO - Evaluate dish washer:
# 2025-09-22 10:24:52,842 - root - INFO - MAE: 4.819499969482422
# 2025-09-22 10:24:52,843 - root - INFO - SAE: 4.076198101043701
# 2025-09-22 10:24:52,854 - root - INFO - F1: 0.982750995134896
# 2025-09-22 10:24:52,854 - root - INFO - Evaluate fridge:
# 2025-09-22 10:24:52,855 - root - INFO - MAE: 19.740360260009766
# 2025-09-22 10:24:52,855 - root - INFO - SAE: 8.89544677734375
# 2025-09-22 10:24:52,858 - root - INFO - F1: 0.860315091938386
# 2025-09-22 10:24:52,859 - root - INFO - Evaluate microwave:
# 2025-09-22 10:24:52,859 - root - INFO - MAE: 10.28943157196045
# 2025-09-22 10:24:52,859 - root - INFO - SAE: 9.30333137512207
# 2025-09-22 10:24:52,862 - root - INFO - F1: 0.7570422535211268
# 2025-09-22 10:24:52,863 - root - INFO - Evaluate wash:
# 2025-09-22 10:24:52,863 - root - INFO - MAE: 8.67905044555664
# 2025-09-22 10:24:52,863 - root - INFO - SAE: 7.809566497802734
# 2025-09-22 10:24:52,866 - root - INFO - F1: 0.9433827042522694
# 2025-09-22 10:24:52,867 - root - INFO - Epoch 0, train loss: 0.076, val loss: 2951.487.
# 2025-09-22 10:24:55,571 - root - INFO - Model saved
# 2025-09-22 10:24:55,572 - root - INFO - Early stopping overall:
# 2025-09-22 10:24:55,572 - root - INFO - Validation loss decreased (inf --> 10.882086).  Saving model ...
# 2025-09-22 10:24:55,668 - root - INFO - Model saved
# 2025-09-22 10:24:55,669 - root - INFO - # of epoches: 1
# 100% 874/874 [16:30<00:00,  1.13s/it]
# 2025-09-22 10:41:25,748 - root - INFO - Validation:
# 2025-09-22 10:41:26,068 - root - INFO - Evaluate dish washer:
# 2025-09-22 10:41:26,069 - root - INFO - MAE: 4.375709533691406
# 2025-09-22 10:41:26,069 - root - INFO - SAE: 1.672179102897644
# 2025-09-22 10:41:26,074 - root - INFO - F1: 0.9841409691629956
# 2025-09-22 10:41:26,074 - root - INFO - Evaluate fridge:
# 2025-09-22 10:41:26,074 - root - INFO - MAE: 21.344615936279297
# 2025-09-22 10:41:26,074 - root - INFO - SAE: 9.435626983642578
# 2025-09-22 10:41:26,078 - root - INFO - F1: 0.8548670927109382
# 2025-09-22 10:41:26,078 - root - INFO - Evaluate microwave:
# 2025-09-22 10:41:26,078 - root - INFO - MAE: 7.2276225090026855
# 2025-09-22 10:41:26,079 - root - INFO - SAE: 6.499146461486816
# 2025-09-22 10:41:26,082 - root - INFO - F1: 0.8778135048231511
# 2025-09-22 10:41:26,082 - root - INFO - Evaluate wash:
# 2025-09-22 10:41:26,083 - root - INFO - MAE: 5.471199989318848
# 2025-09-22 10:41:26,083 - root - INFO - SAE: 3.349978446960449
# 2025-09-22 10:41:26,087 - root - INFO - F1: 0.9687462863933453
# 2025-09-22 10:41:26,087 - root - INFO - Epoch 1, train loss: 0.076, val loss: 2104.291.
# 2025-09-22 10:41:26,087 - root - INFO - Early stopping overall:
# 2025-09-22 10:41:26,087 - root - INFO - Validation loss decreased (10.882086 --> 9.604787).  Saving model ...
# 2025-09-22 10:41:26,217 - root - INFO - Model saved
# 2025-09-22 10:41:26,217 - root - INFO - # of epoches: 2
# 100% 874/874 [16:32<00:00,  1.14s/it]
# 2025-09-22 10:57:58,501 - root - INFO - Validation:
# 2025-09-22 10:57:58,816 - root - INFO - Evaluate dish washer:
# 2025-09-22 10:57:58,816 - root - INFO - MAE: 3.9722399711608887
# 2025-09-22 10:57:58,817 - root - INFO - SAE: 3.1784589290618896
# 2025-09-22 10:57:58,822 - root - INFO - F1: 0.9757815940114487
# 2025-09-22 10:57:58,822 - root - INFO - Evaluate fridge:
# 2025-09-22 10:57:58,822 - root - INFO - MAE: 21.412343978881836
# 2025-09-22 10:57:58,822 - root - INFO - SAE: 9.691181182861328
# 2025-09-22 10:57:58,826 - root - INFO - F1: 0.8596005621087596
# 2025-09-22 10:57:58,826 - root - INFO - Evaluate microwave:
# 2025-09-22 10:57:58,826 - root - INFO - MAE: 5.054389476776123
# 2025-09-22 10:57:58,826 - root - INFO - SAE: 3.7430667877197266
# 2025-09-22 10:57:58,830 - root - INFO - F1: 0.9216589861751152
# 2025-09-22 10:57:58,830 - root - INFO - Evaluate wash:
# 2025-09-22 10:57:58,830 - root - INFO - MAE: 6.685726165771484
# 2025-09-22 10:57:58,831 - root - INFO - SAE: 4.774163246154785
# 2025-09-22 10:57:58,834 - root - INFO - F1: 0.9825
# 2025-09-22 10:57:58,835 - root - INFO - Epoch 2, train loss: 0.076, val loss: 1154.834.
# 2025-09-22 10:57:58,835 - root - INFO - Early stopping overall:
# 2025-09-22 10:57:58,835 - root - INFO - Validation loss decreased (9.604787 --> 9.281176).  Saving model ...
# 2025-09-22 10:57:58,954 - root - INFO - Model saved
# 2025-09-22 10:57:58,954 - root - INFO - # of epoches: 3
# 100% 874/874 [16:31<00:00,  1.13s/it]
# 2025-09-22 11:14:30,600 - root - INFO - Validation:
# 2025-09-22 11:14:30,919 - root - INFO - Evaluate dish washer:
# 2025-09-22 11:14:30,920 - root - INFO - MAE: 5.567092418670654
# 2025-09-22 11:14:30,920 - root - INFO - SAE: 4.804765224456787
# 2025-09-22 11:14:30,925 - root - INFO - F1: 0.9828571428571429
# 2025-09-22 11:14:30,925 - root - INFO - Evaluate fridge:
# 2025-09-22 11:14:30,926 - root - INFO - MAE: 17.703245162963867
# 2025-09-22 11:14:30,926 - root - INFO - SAE: 6.145216464996338
# 2025-09-22 11:14:30,930 - root - INFO - F1: 0.8715123511640306
# 2025-09-22 11:14:30,930 - root - INFO - Evaluate microwave:
# 2025-09-22 11:14:30,930 - root - INFO - MAE: 6.309999465942383
# 2025-09-22 11:14:30,931 - root - INFO - SAE: 5.59768533706665
# 2025-09-22 11:14:30,935 - root - INFO - F1: 0.8850393700787401
# 2025-09-22 11:14:30,935 - root - INFO - Evaluate wash:
# 2025-09-22 11:14:30,935 - root - INFO - MAE: 6.049300193786621
# 2025-09-22 11:14:30,935 - root - INFO - SAE: 4.7625250816345215
# 2025-09-22 11:14:30,939 - root - INFO - F1: 0.9797250058261477
# 2025-09-22 11:14:30,940 - root - INFO - Epoch 3, train loss: 0.076, val loss: 1498.776.
# 2025-09-22 11:14:30,940 - root - INFO - Early stopping overall:
# 2025-09-22 11:14:30,940 - root - INFO - Validation loss decreased (9.281176 --> 8.907410).  Saving model ...
# 2025-09-22 11:14:31,062 - root - INFO - Model saved
# 2025-09-22 11:14:31,063 - root - INFO - # of epoches: 4
# 100% 874/874 [16:31<00:00,  1.13s/it]
# 2025-09-22 11:31:02,123 - root - INFO - Validation:
# 2025-09-22 11:31:02,440 - root - INFO - Evaluate dish washer:
# 2025-09-22 11:31:02,440 - root - INFO - MAE: 3.475693702697754
# 2025-09-22 11:31:02,441 - root - INFO - SAE: 2.7141072750091553
# 2025-09-22 11:31:02,446 - root - INFO - F1: 0.9791574279379157
# 2025-09-22 11:31:02,446 - root - INFO - Evaluate fridge:
# 2025-09-22 11:31:02,446 - root - INFO - MAE: 20.393932342529297
# 2025-09-22 11:31:02,446 - root - INFO - SAE: 9.354544639587402
# 2025-09-22 11:31:02,450 - root - INFO - F1: 0.8633318834275772
# 2025-09-22 11:31:02,450 - root - INFO - Evaluate microwave:
# 2025-09-22 11:31:02,451 - root - INFO - MAE: 7.411925315856934
# 2025-09-22 11:31:02,451 - root - INFO - SAE: 6.758574485778809
# 2025-09-22 11:31:02,455 - root - INFO - F1: 0.8691437802907916
# 2025-09-22 11:31:02,455 - root - INFO - Evaluate wash:
# 2025-09-22 11:31:02,455 - root - INFO - MAE: 5.174732208251953
# 2025-09-22 11:31:02,455 - root - INFO - SAE: 3.488966226577759
# 2025-09-22 11:31:02,459 - root - INFO - F1: 0.9952889808112145
# 2025-09-22 11:31:02,459 - root - INFO - Epoch 4, train loss: 0.077, val loss: 1953.036.
# 2025-09-22 11:31:02,459 - root - INFO - Early stopping overall:
# 2025-09-22 11:31:02,459 - root - INFO - EarlyStopping counter: 1 out of 30
# 2025-09-22 11:31:02,460 - root - INFO - # of epoches: 5
# 100% 874/874 [16:35<00:00,  1.14s/it]
# 2025-09-22 11:47:37,497 - root - INFO - Validation:
# 2025-09-22 11:47:37,814 - root - INFO - Evaluate dish washer:
# 2025-09-22 11:47:37,814 - root - INFO - MAE: 4.5345330238342285
# 2025-09-22 11:47:37,815 - root - INFO - SAE: 3.733903408050537
# 2025-09-22 11:47:37,819 - root - INFO - F1: 0.9857397504456328
# 2025-09-22 11:47:37,819 - root - INFO - Evaluate fridge:
# 2025-09-22 11:47:37,820 - root - INFO - MAE: 17.203519821166992
# 2025-09-22 11:47:37,820 - root - INFO - SAE: 5.17165994644165
# 2025-09-22 11:47:37,824 - root - INFO - F1: 0.868178396687994
# 2025-09-22 11:47:37,824 - root - INFO - Evaluate microwave:
# 2025-09-22 11:47:37,824 - root - INFO - MAE: 6.1237640380859375
# 2025-09-22 11:47:37,825 - root - INFO - SAE: 5.067249774932861
# 2025-09-22 11:47:37,828 - root - INFO - F1: 0.8714733542319749
# 2025-09-22 11:47:37,828 - root - INFO - Evaluate wash:
# 2025-09-22 11:47:37,828 - root - INFO - MAE: 5.583410263061523
# 2025-09-22 11:47:37,829 - root - INFO - SAE: 2.3646469116210938
# 2025-09-22 11:47:37,832 - root - INFO - F1: 0.9890976571561123
# 2025-09-22 11:47:37,833 - root - INFO - Epoch 5, train loss: 0.076, val loss: 1338.020.
# 2025-09-22 11:47:37,833 - root - INFO - Early stopping overall:
# 2025-09-22 11:47:37,833 - root - INFO - Validation loss decreased (8.907410 --> 8.361307).  Saving model ...
# 2025-09-22 11:47:37,961 - root - INFO - Model saved
# 2025-09-22 11:47:37,961 - root - INFO - # of epoches: 6
# 100% 874/874 [16:34<00:00,  1.14s/it]
# 2025-09-22 12:04:12,097 - root - INFO - Validation:
# 2025-09-22 12:04:12,414 - root - INFO - Evaluate dish washer:
# 2025-09-22 12:04:12,415 - root - INFO - MAE: 4.527966499328613
# 2025-09-22 12:04:12,415 - root - INFO - SAE: 2.2911837100982666
# 2025-09-22 12:04:12,420 - root - INFO - F1: 0.9817209094962104
# 2025-09-22 12:04:12,420 - root - INFO - Evaluate fridge:
# 2025-09-22 12:04:12,420 - root - INFO - MAE: 20.571735382080078
# 2025-09-22 12:04:12,420 - root - INFO - SAE: 6.38999080657959
# 2025-09-22 12:04:12,424 - root - INFO - F1: 0.84608754819687
# 2025-09-22 12:04:12,424 - root - INFO - Evaluate microwave:
# 2025-09-22 12:04:12,424 - root - INFO - MAE: 5.7752766609191895
# 2025-09-22 12:04:12,425 - root - INFO - SAE: 4.76344108581543
# 2025-09-22 12:04:12,428 - root - INFO - F1: 0.893353941267388
# 2025-09-22 12:04:12,428 - root - INFO - Evaluate wash:
# 2025-09-22 12:04:12,429 - root - INFO - MAE: 7.112501621246338
# 2025-09-22 12:04:12,429 - root - INFO - SAE: 6.0014448165893555
# 2025-09-22 12:04:12,432 - root - INFO - F1: 0.9585615622767325
# 2025-09-22 12:04:12,433 - root - INFO - Epoch 6, train loss: 0.076, val loss: 1636.083.
# 2025-09-22 12:04:12,433 - root - INFO - Early stopping overall:
# 2025-09-22 12:04:12,433 - root - INFO - EarlyStopping counter: 1 out of 30
# 2025-09-22 12:04:12,433 - root - INFO - # of epoches: 7
# 100% 874/874 [16:36<00:00,  1.14s/it]
# 2025-09-22 12:20:48,895 - root - INFO - Validation:
# 2025-09-22 12:20:49,215 - root - INFO - Evaluate dish washer:
# 2025-09-22 12:20:49,215 - root - INFO - MAE: 5.819197177886963
# 2025-09-22 12:20:49,216 - root - INFO - SAE: 5.078080177307129
# 2025-09-22 12:20:49,220 - root - INFO - F1: 0.9822380106571936
# 2025-09-22 12:20:49,220 - root - INFO - Evaluate fridge:
# 2025-09-22 12:20:49,221 - root - INFO - MAE: 20.002553939819336
# 2025-09-22 12:20:49,221 - root - INFO - SAE: 7.383249759674072
# 2025-09-22 12:20:49,225 - root - INFO - F1: 0.8683807104375629
# 2025-09-22 12:20:49,225 - root - INFO - Evaluate microwave:
# 2025-09-22 12:20:49,225 - root - INFO - MAE: 6.735311985015869
# 2025-09-22 12:20:49,225 - root - INFO - SAE: 5.813084602355957
# 2025-09-22 12:20:49,229 - root - INFO - F1: 0.8985959438377535
# 2025-09-22 12:20:49,229 - root - INFO - Evaluate wash:
# 2025-09-22 12:20:49,229 - root - INFO - MAE: 4.9447832107543945
# 2025-09-22 12:20:49,229 - root - INFO - SAE: 2.826777696609497
# 2025-09-22 12:20:49,233 - root - INFO - F1: 0.9901449275362318
# 2025-09-22 12:20:49,234 - root - INFO - Epoch 7, train loss: 0.077, val loss: 1571.744.
# 2025-09-22 12:20:49,234 - root - INFO - Early stopping overall:
# 2025-09-22 12:20:49,234 - root - INFO - EarlyStopping counter: 2 out of 30
# 2025-09-22 12:20:49,234 - root - INFO - # of epoches: 8
# 100% 874/874 [16:38<00:00,  1.14s/it]
# 2025-09-22 12:37:27,625 - root - INFO - Validation:
# 2025-09-22 12:37:27,944 - root - INFO - Evaluate dish washer:
# 2025-09-22 12:37:27,944 - root - INFO - MAE: 7.125914573669434
# 2025-09-22 12:37:27,945 - root - INFO - SAE: 6.323342323303223
# 2025-09-22 12:37:27,950 - root - INFO - F1: 0.9567099567099567
# 2025-09-22 12:37:27,950 - root - INFO - Evaluate fridge:
# 2025-09-22 12:37:27,950 - root - INFO - MAE: 20.11237335205078
# 2025-09-22 12:37:27,950 - root - INFO - SAE: 7.818569183349609
# 2025-09-22 12:37:27,954 - root - INFO - F1: 0.8517364404100619
# 2025-09-22 12:37:27,954 - root - INFO - Evaluate microwave:
# 2025-09-22 12:37:27,954 - root - INFO - MAE: 6.999129772186279
# 2025-09-22 12:37:27,955 - root - INFO - SAE: 6.189087390899658
# 2025-09-22 12:37:27,958 - root - INFO - F1: 0.8952380952380953
# 2025-09-22 12:37:27,959 - root - INFO - Evaluate wash:
# 2025-09-22 12:37:27,959 - root - INFO - MAE: 5.884825706481934
# 2025-09-22 12:37:27,959 - root - INFO - SAE: 3.575735330581665
# 2025-09-22 12:37:27,963 - root - INFO - F1: 0.9844300488691897
# 2025-09-22 12:37:27,963 - root - INFO - Epoch 8, train loss: 0.077, val loss: 1928.020.
# 2025-09-22 12:37:27,963 - root - INFO - Early stopping overall:
# 2025-09-22 12:37:27,964 - root - INFO - EarlyStopping counter: 3 out of 30
# 2025-09-22 12:37:27,964 - root - INFO - # of epoches: 9
# 100% 874/874 [16:33<00:00,  1.14s/it]
# 2025-09-22 12:54:01,514 - root - INFO - Validation:
# 2025-09-22 12:54:01,828 - root - INFO - Evaluate dish washer:
# 2025-09-22 12:54:01,828 - root - INFO - MAE: 5.839172840118408
# 2025-09-22 12:54:01,829 - root - INFO - SAE: 5.270086288452148
# 2025-09-22 12:54:01,834 - root - INFO - F1: 0.9784425868895732
# 2025-09-22 12:54:01,834 - root - INFO - Evaluate fridge:
# 2025-09-22 12:54:01,834 - root - INFO - MAE: 18.485544204711914
# 2025-09-22 12:54:01,834 - root - INFO - SAE: 7.881042957305908
# 2025-09-22 12:54:01,838 - root - INFO - F1: 0.8706830217716018
# 2025-09-22 12:54:01,838 - root - INFO - Evaluate microwave:
# 2025-09-22 12:54:01,839 - root - INFO - MAE: 8.475048065185547
# 2025-09-22 12:54:01,839 - root - INFO - SAE: 7.740347385406494
# 2025-09-22 12:54:01,843 - root - INFO - F1: 0.8519736842105263
# 2025-09-22 12:54:01,843 - root - INFO - Evaluate wash:
# 2025-09-22 12:54:01,843 - root - INFO - MAE: 5.980166435241699
# 2025-09-22 12:54:01,843 - root - INFO - SAE: 2.4999842643737793
# 2025-09-22 12:54:01,847 - root - INFO - F1: 0.9702147858075234
# 2025-09-22 12:54:01,848 - root - INFO - Epoch 9, train loss: 0.077, val loss: 2097.886.
# 2025-09-22 12:54:01,848 - root - INFO - Early stopping overall:
# 2025-09-22 12:54:01,848 - root - INFO - EarlyStopping counter: 4 out of 30
# 2025-09-22 12:54:01,848 - root - INFO - # of epoches: 10
# 100% 874/874 [16:39<00:00,  1.14s/it]
# 2025-09-22 13:10:41,410 - root - INFO - Validation:
# 2025-09-22 13:10:41,726 - root - INFO - Evaluate dish washer:
# 2025-09-22 13:10:41,727 - root - INFO - MAE: 3.4684016704559326
# 2025-09-22 13:10:41,727 - root - INFO - SAE: 2.7308318614959717
# 2025-09-22 13:10:41,732 - root - INFO - F1: 0.9862160960426857
# 2025-09-22 13:10:41,732 - root - INFO - Evaluate fridge:
# 2025-09-22 13:10:41,733 - root - INFO - MAE: 17.793352127075195
# 2025-09-22 13:10:41,733 - root - INFO - SAE: 7.101431846618652
# 2025-09-22 13:10:41,737 - root - INFO - F1: 0.8667858739383102
# 2025-09-22 13:10:41,737 - root - INFO - Evaluate microwave:
# 2025-09-22 13:10:41,737 - root - INFO - MAE: 7.1503424644470215
# 2025-09-22 13:10:41,737 - root - INFO - SAE: 6.306559085845947
# 2025-09-22 13:10:41,741 - root - INFO - F1: 0.8736
# 2025-09-22 13:10:41,741 - root - INFO - Evaluate wash:
# 2025-09-22 13:10:41,742 - root - INFO - MAE: 9.850455284118652
# 2025-09-22 13:10:41,742 - root - INFO - SAE: 9.178825378417969
# 2025-09-22 13:10:41,746 - root - INFO - F1: 0.9476617397625394
# 2025-09-22 13:10:41,746 - root - INFO - Epoch 10, train loss: 0.077, val loss: 2114.565.
# 2025-09-22 13:10:44,048 - root - INFO - Model saved
# 2025-09-22 13:10:44,049 - root - INFO - Early stopping overall:
# 2025-09-22 13:10:44,049 - root - INFO - EarlyStopping counter: 5 out of 30
# 2025-09-22 13:10:44,049 - root - INFO - # of epoches: 11
# 100% 874/874 [16:30<00:00,  1.13s/it]
# 2025-09-22 13:27:15,012 - root - INFO - Validation:
# 2025-09-22 13:27:15,333 - root - INFO - Evaluate dish washer:
# 2025-09-22 13:27:15,333 - root - INFO - MAE: 3.691848039627075
# 2025-09-22 13:27:15,333 - root - INFO - SAE: 2.853909969329834
# 2025-09-22 13:27:15,338 - root - INFO - F1: 0.9852875613018279
# 2025-09-22 13:27:15,339 - root - INFO - Evaluate fridge:
# 2025-09-22 13:27:15,339 - root - INFO - MAE: 20.762897491455078
# 2025-09-22 13:27:15,339 - root - INFO - SAE: 7.620367050170898
# 2025-09-22 13:27:15,343 - root - INFO - F1: 0.852157858296792
# 2025-09-22 13:27:15,343 - root - INFO - Evaluate microwave:
# 2025-09-22 13:27:15,343 - root - INFO - MAE: 5.723155975341797
# 2025-09-22 13:27:15,344 - root - INFO - SAE: 4.198988437652588
# 2025-09-22 13:27:15,347 - root - INFO - F1: 0.9393939393939394
# 2025-09-22 13:27:15,348 - root - INFO - Evaluate wash:
# 2025-09-22 13:27:15,348 - root - INFO - MAE: 6.688945770263672
# 2025-09-22 13:27:15,348 - root - INFO - SAE: 4.180178642272949
# 2025-09-22 13:27:15,352 - root - INFO - F1: 0.9673140691615348
# 2025-09-22 13:27:15,352 - root - INFO - Epoch 11, train loss: 0.077, val loss: 1117.517.
# 2025-09-22 13:27:15,352 - root - INFO - Early stopping overall:
# 2025-09-22 13:27:15,352 - root - INFO - EarlyStopping counter: 6 out of 30
# 2025-09-22 13:27:15,352 - root - INFO - # of epoches: 12
# 100% 874/874 [16:38<00:00,  1.14s/it]
# 2025-09-22 13:43:53,813 - root - INFO - Validation:
# 2025-09-22 13:43:54,133 - root - INFO - Evaluate dish washer:
# 2025-09-22 13:43:54,134 - root - INFO - MAE: 4.129340171813965
# 2025-09-22 13:43:54,134 - root - INFO - SAE: 3.1219820976257324
# 2025-09-22 13:43:54,139 - root - INFO - F1: 0.9782897651750111
# 2025-09-22 13:43:54,139 - root - INFO - Evaluate fridge:
# 2025-09-22 13:43:54,139 - root - INFO - MAE: 21.844501495361328
# 2025-09-22 13:43:54,140 - root - INFO - SAE: 8.826969146728516
# 2025-09-22 13:43:54,144 - root - INFO - F1: 0.8566897739114675
# 2025-09-22 13:43:54,144 - root - INFO - Evaluate microwave:
# 2025-09-22 13:43:54,144 - root - INFO - MAE: 6.021058082580566
# 2025-09-22 13:43:54,144 - root - INFO - SAE: 5.268491744995117
# 2025-09-22 13:43:54,148 - root - INFO - F1: 0.8913385826771654
# 2025-09-22 13:43:54,148 - root - INFO - Evaluate wash:
# 2025-09-22 13:43:54,148 - root - INFO - MAE: 7.068364143371582
# 2025-09-22 13:43:54,149 - root - INFO - SAE: 4.9473876953125
# 2025-09-22 13:43:54,152 - root - INFO - F1: 0.9480284577354395
# 2025-09-22 13:43:54,153 - root - INFO - Epoch 12, train loss: 0.076, val loss: 1396.182.
# 2025-09-22 13:43:54,153 - root - INFO - Early stopping overall:
# 2025-09-22 13:43:54,153 - root - INFO - EarlyStopping counter: 7 out of 30
# 2025-09-22 13:43:54,153 - root - INFO - # of epoches: 13
# 100% 874/874 [16:47<00:00,  1.15s/it]
# 2025-09-22 14:00:41,358 - root - INFO - Validation:
# 2025-09-22 14:00:41,681 - root - INFO - Evaluate dish washer:
# 2025-09-22 14:00:41,682 - root - INFO - MAE: 5.14027738571167
# 2025-09-22 14:00:41,682 - root - INFO - SAE: 2.5601139068603516
# 2025-09-22 14:00:41,687 - root - INFO - F1: 0.96512641673932
# 2025-09-22 14:00:41,687 - root - INFO - Evaluate fridge:
# 2025-09-22 14:00:41,687 - root - INFO - MAE: 19.530120849609375
# 2025-09-22 14:00:41,687 - root - INFO - SAE: 9.673149108886719
# 2025-09-22 14:00:41,691 - root - INFO - F1: 0.8456369618610686
# 2025-09-22 14:00:41,691 - root - INFO - Evaluate microwave:
# 2025-09-22 14:00:41,691 - root - INFO - MAE: 6.997711658477783
# 2025-09-22 14:00:41,692 - root - INFO - SAE: 5.749522686004639
# 2025-09-22 14:00:41,695 - root - INFO - F1: 0.8842443729903537
# 2025-09-22 14:00:41,695 - root - INFO - Evaluate wash:
# 2025-09-22 14:00:41,695 - root - INFO - MAE: 10.277952194213867
# 2025-09-22 14:00:41,696 - root - INFO - SAE: 5.823305130004883
# 2025-09-22 14:00:41,699 - root - INFO - F1: 0.9895494658615884
# 2025-09-22 14:00:41,700 - root - INFO - Epoch 13, train loss: 0.076, val loss: 2011.255.
# 2025-09-22 14:00:41,700 - root - INFO - Early stopping overall:
# 2025-09-22 14:00:41,700 - root - INFO - EarlyStopping counter: 8 out of 30
# 2025-09-22 14:00:41,700 - root - INFO - # of epoches: 14
# 100% 874/874 [16:42<00:00,  1.15s/it]
# 2025-09-22 14:17:24,475 - root - INFO - Validation:
# 2025-09-22 14:17:24,791 - root - INFO - Evaluate dish washer:
# 2025-09-22 14:17:24,791 - root - INFO - MAE: 4.081129550933838
# 2025-09-22 14:17:24,792 - root - INFO - SAE: 3.1417605876922607
# 2025-09-22 14:17:24,796 - root - INFO - F1: 0.976148409893993
# 2025-09-22 14:17:24,796 - root - INFO - Evaluate fridge:
# 2025-09-22 14:17:24,797 - root - INFO - MAE: 21.270336151123047
# 2025-09-22 14:17:24,797 - root - INFO - SAE: 6.983154296875
# 2025-09-22 14:17:24,801 - root - INFO - F1: 0.8542467021522796
# 2025-09-22 14:17:24,801 - root - INFO - Evaluate microwave:
# 2025-09-22 14:17:24,801 - root - INFO - MAE: 6.4091105461120605
# 2025-09-22 14:17:24,802 - root - INFO - SAE: 5.389616012573242
# 2025-09-22 14:17:24,805 - root - INFO - F1: 0.9303030303030303
# 2025-09-22 14:17:24,805 - root - INFO - Evaluate wash:
# 2025-09-22 14:17:24,805 - root - INFO - MAE: 6.411393642425537
# 2025-09-22 14:17:24,806 - root - INFO - SAE: 3.8685572147369385
# 2025-09-22 14:17:24,809 - root - INFO - F1: 0.9596735477676428
# 2025-09-22 14:17:24,810 - root - INFO - Epoch 14, train loss: 0.077, val loss: 1396.533.
# 2025-09-22 14:17:24,810 - root - INFO - Early stopping overall:
# 2025-09-22 14:17:24,810 - root - INFO - EarlyStopping counter: 9 out of 30
# 2025-09-22 14:17:24,810 - root - INFO - # of epoches: 15
# 100% 874/874 [16:28<00:00,  1.13s/it]
# 2025-09-22 14:33:53,515 - root - INFO - Validation:
# 2025-09-22 14:33:53,826 - root - INFO - Evaluate dish washer:
# 2025-09-22 14:33:53,826 - root - INFO - MAE: 4.0895586013793945
# 2025-09-22 14:33:53,827 - root - INFO - SAE: 3.306504487991333
# 2025-09-22 14:33:53,832 - root - INFO - F1: 0.9581355200690548
# 2025-09-22 14:33:53,832 - root - INFO - Evaluate fridge:
# 2025-09-22 14:33:53,832 - root - INFO - MAE: 19.790355682373047
# 2025-09-22 14:33:53,832 - root - INFO - SAE: 7.0584940910339355
# 2025-09-22 14:33:53,836 - root - INFO - F1: 0.8511056971514243
# 2025-09-22 14:33:53,836 - root - INFO - Evaluate microwave:
# 2025-09-22 14:33:53,836 - root - INFO - MAE: 8.241205215454102
# 2025-09-22 14:33:53,836 - root - INFO - SAE: 7.829717636108398
# 2025-09-22 14:33:53,840 - root - INFO - F1: 0.7823439878234398
# 2025-09-22 14:33:53,840 - root - INFO - Evaluate wash:
# 2025-09-22 14:33:53,840 - root - INFO - MAE: 6.115511894226074
# 2025-09-22 14:33:53,840 - root - INFO - SAE: 3.2036168575286865
# 2025-09-22 14:33:53,844 - root - INFO - F1: 0.9818139426439729
# 2025-09-22 14:33:53,844 - root - INFO - Epoch 15, train loss: 0.076, val loss: 2000.858.
# 2025-09-22 14:33:53,844 - root - INFO - Early stopping overall:
# 2025-09-22 14:33:53,845 - root - INFO - EarlyStopping counter: 10 out of 30
# 2025-09-22 14:33:53,845 - root - INFO - # of epoches: 16
# 100% 874/874 [16:37<00:00,  1.14s/it]
# 2025-09-22 14:50:31,247 - root - INFO - Validation:
# 2025-09-22 14:50:31,572 - root - INFO - Evaluate dish washer:
# 2025-09-22 14:50:31,573 - root - INFO - MAE: 3.5011792182922363
# 2025-09-22 14:50:31,573 - root - INFO - SAE: 2.636610984802246
# 2025-09-22 14:50:31,578 - root - INFO - F1: 0.9798775153105862
# 2025-09-22 14:50:31,578 - root - INFO - Evaluate fridge:
# 2025-09-22 14:50:31,579 - root - INFO - MAE: 19.201412200927734
# 2025-09-22 14:50:31,579 - root - INFO - SAE: 6.071594715118408
# 2025-09-22 14:50:31,583 - root - INFO - F1: 0.8735802698066849
# 2025-09-22 14:50:31,583 - root - INFO - Evaluate microwave:
# 2025-09-22 14:50:31,583 - root - INFO - MAE: 5.676766395568848
# 2025-09-22 14:50:31,583 - root - INFO - SAE: 4.254761219024658
# 2025-09-22 14:50:31,587 - root - INFO - F1: 0.8798751950078003
# 2025-09-22 14:50:31,587 - root - INFO - Evaluate wash:
# 2025-09-22 14:50:31,587 - root - INFO - MAE: 6.580198764801025
# 2025-09-22 14:50:31,588 - root - INFO - SAE: 3.785416603088379
# 2025-09-22 14:50:31,591 - root - INFO - F1: 0.9947162876177349
# 2025-09-22 14:50:31,592 - root - INFO - Epoch 16, train loss: 0.076, val loss: 1271.150.
# 2025-09-22 14:50:31,592 - root - INFO - Early stopping overall:
# 2025-09-22 14:50:31,592 - root - INFO - EarlyStopping counter: 11 out of 30
# 2025-09-22 14:50:31,592 - root - INFO - # of epoches: 17
# 100% 874/874 [16:42<00:00,  1.15s/it]
# 2025-09-22 15:07:13,945 - root - INFO - Validation:
# 2025-09-22 15:07:14,265 - root - INFO - Evaluate dish washer:
# 2025-09-22 15:07:14,266 - root - INFO - MAE: 5.651272773742676
# 2025-09-22 15:07:14,266 - root - INFO - SAE: 3.237783670425415
# 2025-09-22 15:07:14,271 - root - INFO - F1: 0.9372423270728355
# 2025-09-22 15:07:14,271 - root - INFO - Evaluate fridge:
# 2025-09-22 15:07:14,271 - root - INFO - MAE: 18.788387298583984
# 2025-09-22 15:07:14,271 - root - INFO - SAE: 5.75023078918457
# 2025-09-22 15:07:14,275 - root - INFO - F1: 0.8677563150074294
# 2025-09-22 15:07:14,275 - root - INFO - Evaluate microwave:
# 2025-09-22 15:07:14,276 - root - INFO - MAE: 6.892590522766113
# 2025-09-22 15:07:14,276 - root - INFO - SAE: 6.0857014656066895
# 2025-09-22 15:07:14,280 - root - INFO - F1: 0.8757961783439491
# 2025-09-22 15:07:14,280 - root - INFO - Evaluate wash:
# 2025-09-22 15:07:14,280 - root - INFO - MAE: 5.6338372230529785
# 2025-09-22 15:07:14,280 - root - INFO - SAE: 3.6212806701660156
# 2025-09-22 15:07:14,284 - root - INFO - F1: 0.9662653474788413
# 2025-09-22 15:07:14,284 - root - INFO - Epoch 17, train loss: 0.076, val loss: 1880.849.
# 2025-09-22 15:07:14,284 - root - INFO - Early stopping overall:
# 2025-09-22 15:07:14,284 - root - INFO - EarlyStopping counter: 12 out of 30
# 2025-09-22 15:07:14,284 - root - INFO - # of epoches: 18
# 100% 874/874 [16:40<00:00,  1.14s/it]
# 2025-09-22 15:23:54,504 - root - INFO - Validation:
# 2025-09-22 15:23:54,824 - root - INFO - Evaluate dish washer:
# 2025-09-22 15:23:54,824 - root - INFO - MAE: 4.690700531005859
# 2025-09-22 15:23:54,825 - root - INFO - SAE: 3.90043306350708
# 2025-09-22 15:23:54,830 - root - INFO - F1: 0.9771328056288479
# 2025-09-22 15:23:54,830 - root - INFO - Evaluate fridge:
# 2025-09-22 15:23:54,830 - root - INFO - MAE: 21.279794692993164
# 2025-09-22 15:23:54,830 - root - INFO - SAE: 8.142455101013184
# 2025-09-22 15:23:54,834 - root - INFO - F1: 0.852330771708619
# 2025-09-22 15:23:54,834 - root - INFO - Evaluate microwave:
# 2025-09-22 15:23:54,834 - root - INFO - MAE: 6.7953691482543945
# 2025-09-22 15:23:54,835 - root - INFO - SAE: 5.8159260749816895
# 2025-09-22 15:23:54,838 - root - INFO - F1: 0.890282131661442
# 2025-09-22 15:23:54,838 - root - INFO - Evaluate wash:
# 2025-09-22 15:23:54,839 - root - INFO - MAE: 7.291467189788818
# 2025-09-22 15:23:54,839 - root - INFO - SAE: 5.4871506690979
# 2025-09-22 15:23:54,843 - root - INFO - F1: 0.99102416570771
# 2025-09-22 15:23:54,843 - root - INFO - Epoch 18, train loss: 0.076, val loss: 1815.333.
# 2025-09-22 15:23:54,843 - root - INFO - Early stopping overall:
# 2025-09-22 15:23:54,843 - root - INFO - EarlyStopping counter: 13 out of 30
# 2025-09-22 15:23:54,843 - root - INFO - # of epoches: 19
# 100% 874/874 [16:36<00:00,  1.14s/it]
# 2025-09-22 15:40:31,497 - root - INFO - Validation:
# 2025-09-22 15:40:31,812 - root - INFO - Evaluate dish washer:
# 2025-09-22 15:40:31,813 - root - INFO - MAE: 4.781580924987793
# 2025-09-22 15:40:31,813 - root - INFO - SAE: 3.2497122287750244
# 2025-09-22 15:40:31,818 - root - INFO - F1: 0.9805481874447391
# 2025-09-22 15:40:31,818 - root - INFO - Evaluate fridge:
# 2025-09-22 15:40:31,818 - root - INFO - MAE: 20.07339859008789
# 2025-09-22 15:40:31,818 - root - INFO - SAE: 7.193114757537842
# 2025-09-22 15:40:31,822 - root - INFO - F1: 0.8577600073532791
# 2025-09-22 15:40:31,822 - root - INFO - Evaluate microwave:
# 2025-09-22 15:40:31,822 - root - INFO - MAE: 4.5247673988342285
# 2025-09-22 15:40:31,823 - root - INFO - SAE: 3.1345059871673584
# 2025-09-22 15:40:31,826 - root - INFO - F1: 0.9210134128166915
# 2025-09-22 15:40:31,826 - root - INFO - Evaluate wash:
# 2025-09-22 15:40:31,826 - root - INFO - MAE: 5.290577411651611
# 2025-09-22 15:40:31,827 - root - INFO - SAE: 3.2994191646575928
# 2025-09-22 15:40:31,830 - root - INFO - F1: 0.985273492286115
# 2025-09-22 15:40:31,831 - root - INFO - Epoch 19, train loss: 0.076, val loss: 855.179.
# 2025-09-22 15:40:31,831 - root - INFO - Early stopping overall:
# 2025-09-22 15:40:31,831 - root - INFO - EarlyStopping counter: 14 out of 30
# 2025-09-22 15:40:31,831 - root - INFO - # of epoches: 20
# 100% 874/874 [16:31<00:00,  1.13s/it]
# 2025-09-22 15:57:03,678 - root - INFO - Validation:
# 2025-09-22 15:57:03,993 - root - INFO - Evaluate dish washer:
# 2025-09-22 15:57:03,994 - root - INFO - MAE: 6.957678318023682
# 2025-09-22 15:57:03,994 - root - INFO - SAE: 6.190632343292236
# 2025-09-22 15:57:03,999 - root - INFO - F1: 0.965992251399053
# 2025-09-22 15:57:03,999 - root - INFO - Evaluate fridge:
# 2025-09-22 15:57:03,999 - root - INFO - MAE: 17.98003387451172
# 2025-09-22 15:57:03,999 - root - INFO - SAE: 6.9201860427856445
# 2025-09-22 15:57:04,003 - root - INFO - F1: 0.8621324354657688
# 2025-09-22 15:57:04,003 - root - INFO - Evaluate microwave:
# 2025-09-22 15:57:04,003 - root - INFO - MAE: 6.679324626922607
# 2025-09-22 15:57:04,004 - root - INFO - SAE: 5.949826717376709
# 2025-09-22 15:57:04,007 - root - INFO - F1: 0.8832
# 2025-09-22 15:57:04,008 - root - INFO - Evaluate wash:
# 2025-09-22 15:57:04,008 - root - INFO - MAE: 6.996271133422852
# 2025-09-22 15:57:04,008 - root - INFO - SAE: 4.072403430938721
# 2025-09-22 15:57:04,011 - root - INFO - F1: 0.9476590636254502
# 2025-09-22 15:57:04,012 - root - INFO - Epoch 20, train loss: 0.076, val loss: 1532.316.
# 2025-09-22 15:57:05,942 - root - INFO - Model saved
# 2025-09-22 15:57:05,942 - root - INFO - Early stopping overall:
# 2025-09-22 15:57:05,943 - root - INFO - EarlyStopping counter: 15 out of 30
# 2025-09-22 15:57:05,943 - root - INFO - # of epoches: 21
# 100% 874/874 [16:28<00:00,  1.13s/it]
# 2025-09-22 16:13:34,338 - root - INFO - Validation:
# 2025-09-22 16:13:34,657 - root - INFO - Evaluate dish washer:
# 2025-09-22 16:13:34,657 - root - INFO - MAE: 3.965756416320801
# 2025-09-22 16:13:34,658 - root - INFO - SAE: 2.7504358291625977
# 2025-09-22 16:13:34,663 - root - INFO - F1: 0.9858030168589175
# 2025-09-22 16:13:34,663 - root - INFO - Evaluate fridge:
# 2025-09-22 16:13:34,663 - root - INFO - MAE: 20.81818199157715
# 2025-09-22 16:13:34,664 - root - INFO - SAE: 7.694000244140625
# 2025-09-22 16:13:34,667 - root - INFO - F1: 0.8374982082278178
# 2025-09-22 16:13:34,667 - root - INFO - Evaluate microwave:
# 2025-09-22 16:13:34,668 - root - INFO - MAE: 8.616291046142578
# 2025-09-22 16:13:34,668 - root - INFO - SAE: 7.824553489685059
# 2025-09-22 16:13:34,672 - root - INFO - F1: 0.8580645161290322
# 2025-09-22 16:13:34,672 - root - INFO - Evaluate wash:
# 2025-09-22 16:13:34,672 - root - INFO - MAE: 11.063343048095703
# 2025-09-22 16:13:34,672 - root - INFO - SAE: 9.6428861618042
# 2025-09-22 16:13:34,676 - root - INFO - F1: 0.9927024209428935
# 2025-09-22 16:13:34,677 - root - INFO - Epoch 21, train loss: 0.076, val loss: 2413.320.
# 2025-09-22 16:13:34,677 - root - INFO - Early stopping overall:
# 2025-09-22 16:13:34,677 - root - INFO - EarlyStopping counter: 16 out of 30
# 2025-09-22 16:13:34,677 - root - INFO - # of epoches: 22
# 100% 874/874 [16:34<00:00,  1.14s/it]
# 2025-09-22 16:30:09,099 - root - INFO - Validation:
# 2025-09-22 16:30:09,413 - root - INFO - Evaluate dish washer:
# 2025-09-22 16:30:09,413 - root - INFO - MAE: 3.6500117778778076
# 2025-09-22 16:30:09,413 - root - INFO - SAE: 3.0102498531341553
# 2025-09-22 16:30:09,418 - root - INFO - F1: 0.9800173761946134
# 2025-09-22 16:30:09,418 - root - INFO - Evaluate fridge:
# 2025-09-22 16:30:09,418 - root - INFO - MAE: 21.53890609741211
# 2025-09-22 16:30:09,418 - root - INFO - SAE: 9.158309936523438
# 2025-09-22 16:30:09,422 - root - INFO - F1: 0.8480245829675154
# 2025-09-22 16:30:09,422 - root - INFO - Evaluate microwave:
# 2025-09-22 16:30:09,422 - root - INFO - MAE: 6.232898235321045
# 2025-09-22 16:30:09,423 - root - INFO - SAE: 5.251654624938965
# 2025-09-22 16:30:09,426 - root - INFO - F1: 0.9216867469879518
# 2025-09-22 16:30:09,426 - root - INFO - Evaluate wash:
# 2025-09-22 16:30:09,426 - root - INFO - MAE: 7.197603702545166
# 2025-09-22 16:30:09,427 - root - INFO - SAE: 5.936888694763184
# 2025-09-22 16:30:09,430 - root - INFO - F1: 0.9518290474465774
# 2025-09-22 16:30:09,431 - root - INFO - Epoch 22, train loss: 0.076, val loss: 1402.577.
# 2025-09-22 16:30:09,431 - root - INFO - Early stopping overall:
# 2025-09-22 16:30:09,431 - root - INFO - EarlyStopping counter: 17 out of 30
# 2025-09-22 16:30:09,431 - root - INFO - # of epoches: 23
# 100% 874/874 [16:36<00:00,  1.14s/it]
# 2025-09-22 16:46:45,455 - root - INFO - Validation:
# 2025-09-22 16:46:45,768 - root - INFO - Evaluate dish washer:
# 2025-09-22 16:46:45,768 - root - INFO - MAE: 4.040105819702148
# 2025-09-22 16:46:45,769 - root - INFO - SAE: 3.1025900840759277
# 2025-09-22 16:46:45,773 - root - INFO - F1: 0.9849290780141844
# 2025-09-22 16:46:45,774 - root - INFO - Evaluate fridge:
# 2025-09-22 16:46:45,774 - root - INFO - MAE: 19.108234405517578
# 2025-09-22 16:46:45,774 - root - INFO - SAE: 7.1239333152771
# 2025-09-22 16:46:45,778 - root - INFO - F1: 0.8590284142988084
# 2025-09-22 16:46:45,778 - root - INFO - Evaluate microwave:
# 2025-09-22 16:46:45,778 - root - INFO - MAE: 7.2350053787231445
# 2025-09-22 16:46:45,778 - root - INFO - SAE: 6.776447772979736
# 2025-09-22 16:46:45,782 - root - INFO - F1: 0.8659127625201939
# 2025-09-22 16:46:45,782 - root - INFO - Evaluate wash:
# 2025-09-22 16:46:45,783 - root - INFO - MAE: 9.360201835632324
# 2025-09-22 16:46:45,783 - root - INFO - SAE: 7.733930587768555
# 2025-09-22 16:46:45,786 - root - INFO - F1: 0.9394302130715825
# 2025-09-22 16:46:45,787 - root - INFO - Epoch 23, train loss: 0.076, val loss: 2012.991.
# 2025-09-22 16:46:45,787 - root - INFO - Early stopping overall:
# 2025-09-22 16:46:45,787 - root - INFO - EarlyStopping counter: 18 out of 30
# 2025-09-22 16:46:45,787 - root - INFO - # of epoches: 24
# 100% 874/874 [16:35<00:00,  1.14s/it]
# 2025-09-22 17:03:21,131 - root - INFO - Validation:
# 2025-09-22 17:03:21,448 - root - INFO - Evaluate dish washer:
# 2025-09-22 17:03:21,448 - root - INFO - MAE: 3.8738231658935547
# 2025-09-22 17:03:21,449 - root - INFO - SAE: 2.883074998855591
# 2025-09-22 17:03:21,454 - root - INFO - F1: 0.9844375277901289
# 2025-09-22 17:03:21,454 - root - INFO - Evaluate fridge:
# 2025-09-22 17:03:21,454 - root - INFO - MAE: 19.112079620361328
# 2025-09-22 17:03:21,454 - root - INFO - SAE: 7.917891025543213
# 2025-09-22 17:03:21,458 - root - INFO - F1: 0.841541755888651
# 2025-09-22 17:03:21,458 - root - INFO - Evaluate microwave:
# 2025-09-22 17:03:21,458 - root - INFO - MAE: 6.561500549316406
# 2025-09-22 17:03:21,459 - root - INFO - SAE: 5.811925411224365
# 2025-09-22 17:03:21,462 - root - INFO - F1: 0.8562091503267973
# 2025-09-22 17:03:21,462 - root - INFO - Evaluate wash:
# 2025-09-22 17:03:21,463 - root - INFO - MAE: 5.782087802886963
# 2025-09-22 17:03:21,463 - root - INFO - SAE: 3.547809600830078
# 2025-09-22 17:03:21,466 - root - INFO - F1: 0.9746192893401016
# 2025-09-22 17:03:21,467 - root - INFO - Epoch 24, train loss: 0.076, val loss: 1637.868.
# 2025-09-22 17:03:21,467 - root - INFO - Early stopping overall:
# 2025-09-22 17:03:21,467 - root - INFO - EarlyStopping counter: 19 out of 30
# 2025-09-22 17:03:21,467 - root - INFO - # of epoches: 25
# 100% 874/874 [16:35<00:00,  1.14s/it]
# 2025-09-22 17:19:56,525 - root - INFO - Validation:
# 2025-09-22 17:19:56,848 - root - INFO - Evaluate dish washer:
# 2025-09-22 17:19:56,848 - root - INFO - MAE: 4.54119873046875
# 2025-09-22 17:19:56,849 - root - INFO - SAE: 3.9947638511657715
# 2025-09-22 17:19:56,853 - root - INFO - F1: 0.9815789473684211
# 2025-09-22 17:19:56,854 - root - INFO - Evaluate fridge:
# 2025-09-22 17:19:56,854 - root - INFO - MAE: 20.516489028930664
# 2025-09-22 17:19:56,854 - root - INFO - SAE: 8.00336742401123
# 2025-09-22 17:19:56,858 - root - INFO - F1: 0.8260427263479145
# 2025-09-22 17:19:56,858 - root - INFO - Evaluate microwave:
# 2025-09-22 17:19:56,858 - root - INFO - MAE: 6.042539119720459
# 2025-09-22 17:19:56,859 - root - INFO - SAE: 5.261331558227539
# 2025-09-22 17:19:56,862 - root - INFO - F1: 0.8764044943820225
# 2025-09-22 17:19:56,862 - root - INFO - Evaluate wash:
# 2025-09-22 17:19:56,862 - root - INFO - MAE: 12.213109016418457
# 2025-09-22 17:19:56,863 - root - INFO - SAE: 9.472407341003418
# 2025-09-22 17:19:56,867 - root - INFO - F1: 0.9950591749971275
# 2025-09-22 17:19:56,867 - root - INFO - Epoch 25, train loss: 0.076, val loss: 2022.805.
# 2025-09-22 17:19:56,867 - root - INFO - Early stopping overall:
# 2025-09-22 17:19:56,867 - root - INFO - EarlyStopping counter: 20 out of 30
# 2025-09-22 17:19:56,867 - root - INFO - # of epoches: 26
# 100% 874/874 [16:48<00:00,  1.15s/it]
# 2025-09-22 17:36:45,357 - root - INFO - Validation:
# 2025-09-22 17:36:45,688 - root - INFO - Evaluate dish washer:
# 2025-09-22 17:36:45,688 - root - INFO - MAE: 3.3869664669036865
# 2025-09-22 17:36:45,688 - root - INFO - SAE: 2.6521217823028564
# 2025-09-22 17:36:45,693 - root - INFO - F1: 0.9854817421909371
# 2025-09-22 17:36:45,693 - root - INFO - Evaluate fridge:
# 2025-09-22 17:36:45,694 - root - INFO - MAE: 20.172555923461914
# 2025-09-22 17:36:45,694 - root - INFO - SAE: 9.169774055480957
# 2025-09-22 17:36:45,698 - root - INFO - F1: 0.843278447920011
# 2025-09-22 17:36:45,698 - root - INFO - Evaluate microwave:
# 2025-09-22 17:36:45,698 - root - INFO - MAE: 6.300351142883301
# 2025-09-22 17:36:45,698 - root - INFO - SAE: 5.490494251251221
# 2025-09-22 17:36:45,702 - root - INFO - F1: 0.8958990536277602
# 2025-09-22 17:36:45,702 - root - INFO - Evaluate wash:
# 2025-09-22 17:36:45,702 - root - INFO - MAE: 6.207489490509033
# 2025-09-22 17:36:45,703 - root - INFO - SAE: 4.245771408081055
# 2025-09-22 17:36:45,706 - root - INFO - F1: 0.9910496338486574
# 2025-09-22 17:36:45,707 - root - INFO - Epoch 26, train loss: 0.076, val loss: 1510.286.
# 2025-09-22 17:36:45,707 - root - INFO - Early stopping overall:
# 2025-09-22 17:36:45,707 - root - INFO - EarlyStopping counter: 21 out of 30
# 2025-09-22 17:36:45,707 - root - INFO - # of epoches: 27
# 100% 874/874 [16:43<00:00,  1.15s/it]
# 2025-09-22 17:53:29,217 - root - INFO - Validation:
# 2025-09-22 17:53:29,545 - root - INFO - Evaluate dish washer:
# 2025-09-22 17:53:29,546 - root - INFO - MAE: 3.5783023834228516
# 2025-09-22 17:53:29,546 - root - INFO - SAE: 2.36785626411438
# 2025-09-22 17:53:29,551 - root - INFO - F1: 0.9761061946902655
# 2025-09-22 17:53:29,551 - root - INFO - Evaluate fridge:
# 2025-09-22 17:53:29,551 - root - INFO - MAE: 19.791175842285156
# 2025-09-22 17:53:29,552 - root - INFO - SAE: 7.614504814147949
# 2025-09-22 17:53:29,556 - root - INFO - F1: 0.8232535885167465
# 2025-09-22 17:53:29,556 - root - INFO - Evaluate microwave:
# 2025-09-22 17:53:29,556 - root - INFO - MAE: 4.540342807769775
# 2025-09-22 17:53:29,556 - root - INFO - SAE: 3.3884341716766357
# 2025-09-22 17:53:29,560 - root - INFO - F1: 0.9393939393939394
# 2025-09-22 17:53:29,560 - root - INFO - Evaluate wash:
# 2025-09-22 17:53:29,560 - root - INFO - MAE: 6.210213661193848
# 2025-09-22 17:53:29,560 - root - INFO - SAE: 4.731103420257568
# 2025-09-22 17:53:29,564 - root - INFO - F1: 0.984240193258944
# 2025-09-22 17:53:29,565 - root - INFO - Epoch 27, train loss: 0.076, val loss: 881.029.
# 2025-09-22 17:53:29,565 - root - INFO - Early stopping overall:
# 2025-09-22 17:53:29,565 - root - INFO - EarlyStopping counter: 22 out of 30
# 2025-09-22 17:53:29,565 - root - INFO - # of epoches: 28
# 100% 874/874 [16:39<00:00,  1.14s/it]
# 2025-09-22 18:10:08,879 - root - INFO - Validation:
# 2025-09-22 18:10:09,198 - root - INFO - Evaluate dish washer:
# 2025-09-22 18:10:09,199 - root - INFO - MAE: 3.4818897247314453
# 2025-09-22 18:10:09,199 - root - INFO - SAE: 2.6604747772216797
# 2025-09-22 18:10:09,204 - root - INFO - F1: 0.9800620292423571
# 2025-09-22 18:10:09,204 - root - INFO - Evaluate fridge:
# 2025-09-22 18:10:09,205 - root - INFO - MAE: 19.13479232788086
# 2025-09-22 18:10:09,205 - root - INFO - SAE: 7.200023651123047
# 2025-09-22 18:10:09,209 - root - INFO - F1: 0.8566790352504638
# 2025-09-22 18:10:09,209 - root - INFO - Evaluate microwave:
# 2025-09-22 18:10:09,209 - root - INFO - MAE: 7.005481243133545
# 2025-09-22 18:10:09,209 - root - INFO - SAE: 6.028482437133789
# 2025-09-22 18:10:09,213 - root - INFO - F1: 0.8941548183254344
# 2025-09-22 18:10:09,213 - root - INFO - Evaluate wash:
# 2025-09-22 18:10:09,213 - root - INFO - MAE: 6.401652812957764
# 2025-09-22 18:10:09,214 - root - INFO - SAE: 4.644539833068848
# 2025-09-22 18:10:09,217 - root - INFO - F1: 0.9920166608816383
# 2025-09-22 18:10:09,218 - root - INFO - Epoch 28, train loss: 0.076, val loss: 1511.458.
# 2025-09-22 18:10:09,218 - root - INFO - Early stopping overall:
# 2025-09-22 18:10:09,218 - root - INFO - EarlyStopping counter: 23 out of 30
# 2025-09-22 18:10:09,218 - root - INFO - # of epoches: 29
# 100% 874/874 [16:40<00:00,  1.15s/it]
# 2025-09-22 18:26:50,024 - root - INFO - Validation:
# 2025-09-22 18:26:50,361 - root - INFO - Evaluate dish washer:
# 2025-09-22 18:26:50,361 - root - INFO - MAE: 7.702211380004883
# 2025-09-22 18:26:50,362 - root - INFO - SAE: 6.995848178863525
# 2025-09-22 18:26:50,366 - root - INFO - F1: 0.8953771289537713
# 2025-09-22 18:26:50,367 - root - INFO - Evaluate fridge:
# 2025-09-22 18:26:50,367 - root - INFO - MAE: 17.38587760925293
# 2025-09-22 18:26:50,367 - root - INFO - SAE: 6.880290508270264
# 2025-09-22 18:26:50,371 - root - INFO - F1: 0.8771386967601019
# 2025-09-22 18:26:50,371 - root - INFO - Evaluate microwave:
# 2025-09-22 18:26:50,371 - root - INFO - MAE: 7.572082996368408
# 2025-09-22 18:26:50,372 - root - INFO - SAE: 6.578577995300293
# 2025-09-22 18:26:50,375 - root - INFO - F1: 0.8828250401284109
# 2025-09-22 18:26:50,375 - root - INFO - Evaluate wash:
# 2025-09-22 18:26:50,376 - root - INFO - MAE: 5.163131237030029
# 2025-09-22 18:26:50,376 - root - INFO - SAE: 2.334052801132202
# 2025-09-22 18:26:50,380 - root - INFO - F1: 0.9908214244219821
# 2025-09-22 18:26:50,380 - root - INFO - Epoch 29, train loss: 0.076, val loss: 1931.591.
# 2025-09-22 18:26:50,381 - root - INFO - Early stopping overall:
# 2025-09-22 18:26:50,381 - root - INFO - EarlyStopping counter: 24 out of 30
# 2025-09-22 18:26:50,381 - root - INFO - # of epoches: 30
# 100% 874/874 [16:39<00:00,  1.14s/it]
# 2025-09-22 18:43:29,611 - root - INFO - Validation:
# 2025-09-22 18:43:29,936 - root - INFO - Evaluate dish washer:
# 2025-09-22 18:43:29,936 - root - INFO - MAE: 4.434927940368652
# 2025-09-22 18:43:29,937 - root - INFO - SAE: 3.850492238998413
# 2025-09-22 18:43:29,942 - root - INFO - F1: 0.9767032967032967
# 2025-09-22 18:43:29,942 - root - INFO - Evaluate fridge:
# 2025-09-22 18:43:29,942 - root - INFO - MAE: 19.534019470214844
# 2025-09-22 18:43:29,942 - root - INFO - SAE: 8.828763961791992
# 2025-09-22 18:43:29,946 - root - INFO - F1: 0.8686634919222039
# 2025-09-22 18:43:29,946 - root - INFO - Evaluate microwave:
# 2025-09-22 18:43:29,946 - root - INFO - MAE: 6.895033359527588
# 2025-09-22 18:43:29,947 - root - INFO - SAE: 5.880390167236328
# 2025-09-22 18:43:29,950 - root - INFO - F1: 0.8801261829652997
# 2025-09-22 18:43:29,950 - root - INFO - Evaluate wash:
# 2025-09-22 18:43:29,950 - root - INFO - MAE: 7.520909309387207
# 2025-09-22 18:43:29,951 - root - INFO - SAE: 6.183660984039307
# 2025-09-22 18:43:29,954 - root - INFO - F1: 0.9781720555620403
# 2025-09-22 18:43:29,955 - root - INFO - Epoch 30, train loss: 0.076, val loss: 1822.862.
# 2025-09-22 18:43:31,948 - root - INFO - Model saved
# 2025-09-22 18:43:31,948 - root - INFO - Early stopping overall:
# 2025-09-22 18:43:31,949 - root - INFO - EarlyStopping counter: 25 out of 30
# 2025-09-22 18:43:31,949 - root - INFO - # of epoches: 31
# 100% 874/874 [16:34<00:00,  1.14s/it]
# 2025-09-22 19:00:06,779 - root - INFO - Validation:
# 2025-09-22 19:00:07,100 - root - INFO - Evaluate dish washer:
# 2025-09-22 19:00:07,100 - root - INFO - MAE: 3.9878506660461426
# 2025-09-22 19:00:07,101 - root - INFO - SAE: 3.4311866760253906
# 2025-09-22 19:00:07,105 - root - INFO - F1: 0.9858407079646018
# 2025-09-22 19:00:07,105 - root - INFO - Evaluate fridge:
# 2025-09-22 19:00:07,106 - root - INFO - MAE: 20.664066314697266
# 2025-09-22 19:00:07,106 - root - INFO - SAE: 10.041221618652344
# 2025-09-22 19:00:07,110 - root - INFO - F1: 0.8651788443900947
# 2025-09-22 19:00:07,110 - root - INFO - Evaluate microwave:
# 2025-09-22 19:00:07,110 - root - INFO - MAE: 4.9703216552734375
# 2025-09-22 19:00:07,110 - root - INFO - SAE: 3.46209979057312
# 2025-09-22 19:00:07,114 - root - INFO - F1: 0.9085271317829458
# 2025-09-22 19:00:07,114 - root - INFO - Evaluate wash:
# 2025-09-22 19:00:07,114 - root - INFO - MAE: 5.463122844696045
# 2025-09-22 19:00:07,114 - root - INFO - SAE: 4.079580307006836
# 2025-09-22 19:00:07,118 - root - INFO - F1: 0.988503077459064
# 2025-09-22 19:00:07,118 - root - INFO - Epoch 31, train loss: 0.076, val loss: 1029.919.
# 2025-09-22 19:00:07,118 - root - INFO - Early stopping overall:
# 2025-09-22 19:00:07,118 - root - INFO - EarlyStopping counter: 26 out of 30
# 2025-09-22 19:00:07,118 - root - INFO - # of epoches: 32
# 100% 874/874 [16:41<00:00,  1.15s/it]
# 2025-09-22 19:16:48,512 - root - INFO - Validation:
# 2025-09-22 19:16:48,834 - root - INFO - Evaluate dish washer:
# 2025-09-22 19:16:48,835 - root - INFO - MAE: 4.404334545135498
# 2025-09-22 19:16:48,835 - root - INFO - SAE: 3.866243600845337
# 2025-09-22 19:16:48,841 - root - INFO - F1: 0.984561093956771
# 2025-09-22 19:16:48,841 - root - INFO - Evaluate fridge:
# 2025-09-22 19:16:48,841 - root - INFO - MAE: 20.002574920654297
# 2025-09-22 19:16:48,841 - root - INFO - SAE: 8.57719898223877
# 2025-09-22 19:16:48,845 - root - INFO - F1: 0.8368262103047497
# 2025-09-22 19:16:48,845 - root - INFO - Evaluate microwave:
# 2025-09-22 19:16:48,846 - root - INFO - MAE: 7.0388689041137695
# 2025-09-22 19:16:48,846 - root - INFO - SAE: 6.026734828948975
# 2025-09-22 19:16:48,850 - root - INFO - F1: 0.8829113924050633
# 2025-09-22 19:16:48,850 - root - INFO - Evaluate wash:
# 2025-09-22 19:16:48,850 - root - INFO - MAE: 6.746423721313477
# 2025-09-22 19:16:48,850 - root - INFO - SAE: 5.665104866027832
# 2025-09-22 19:16:48,854 - root - INFO - F1: 0.9942008814660172
# 2025-09-22 19:16:48,855 - root - INFO - Epoch 32, train loss: 0.076, val loss: 1739.193.
# 2025-09-22 19:16:48,855 - root - INFO - Early stopping overall:
# 2025-09-22 19:16:48,855 - root - INFO - EarlyStopping counter: 27 out of 30
# 2025-09-22 19:16:48,855 - root - INFO - # of epoches: 33
# 100% 874/874 [16:38<00:00,  1.14s/it]
# 2025-09-22 19:33:27,163 - root - INFO - Validation:
# 2025-09-22 19:33:27,481 - root - INFO - Evaluate dish washer:
# 2025-09-22 19:33:27,482 - root - INFO - MAE: 4.22316312789917
# 2025-09-22 19:33:27,482 - root - INFO - SAE: 3.5049147605895996
# 2025-09-22 19:33:27,487 - root - INFO - F1: 0.978328173374613
# 2025-09-22 19:33:27,487 - root - INFO - Evaluate fridge:
# 2025-09-22 19:33:27,487 - root - INFO - MAE: 18.17535972595215
# 2025-09-22 19:33:27,487 - root - INFO - SAE: 7.480350017547607
# 2025-09-22 19:33:27,491 - root - INFO - F1: 0.8401376804665838
# 2025-09-22 19:33:27,491 - root - INFO - Evaluate microwave:
# 2025-09-22 19:33:27,492 - root - INFO - MAE: 8.025403022766113
# 2025-09-22 19:33:27,492 - root - INFO - SAE: 7.469244956970215
# 2025-09-22 19:33:27,496 - root - INFO - F1: 0.8040201005025126
# 2025-09-22 19:33:27,496 - root - INFO - Evaluate wash:
# 2025-09-22 19:33:27,496 - root - INFO - MAE: 6.521599769592285
# 2025-09-22 19:33:27,496 - root - INFO - SAE: 5.271772861480713
# 2025-09-22 19:33:27,500 - root - INFO - F1: 0.9863461314038978
# 2025-09-22 19:33:27,501 - root - INFO - Epoch 33, train loss: 0.076, val loss: 2021.255.
# 2025-09-22 19:33:27,501 - root - INFO - Early stopping overall:
# 2025-09-22 19:33:27,501 - root - INFO - EarlyStopping counter: 28 out of 30
# 2025-09-22 19:33:27,501 - root - INFO - # of epoches: 34
# 100% 874/874 [16:39<00:00,  1.14s/it]
# 2025-09-22 19:50:06,610 - root - INFO - Validation:
# 2025-09-22 19:50:06,941 - root - INFO - Evaluate dish washer:
# 2025-09-22 19:50:06,942 - root - INFO - MAE: 2.9876012802124023
# 2025-09-22 19:50:06,942 - root - INFO - SAE: 2.024359941482544
# 2025-09-22 19:50:06,947 - root - INFO - F1: 0.9816882536846807
# 2025-09-22 19:50:06,947 - root - INFO - Evaluate fridge:
# 2025-09-22 19:50:06,947 - root - INFO - MAE: 17.800472259521484
# 2025-09-22 19:50:06,948 - root - INFO - SAE: 6.466702938079834
# 2025-09-22 19:50:06,952 - root - INFO - F1: 0.8599068434252956
# 2025-09-22 19:50:06,952 - root - INFO - Evaluate microwave:
# 2025-09-22 19:50:06,952 - root - INFO - MAE: 7.3231658935546875
# 2025-09-22 19:50:06,952 - root - INFO - SAE: 6.919877529144287
# 2025-09-22 19:50:06,956 - root - INFO - F1: 0.8828250401284109
# 2025-09-22 19:50:06,956 - root - INFO - Evaluate wash:
# 2025-09-22 19:50:06,956 - root - INFO - MAE: 6.4910359382629395
# 2025-09-22 19:50:06,957 - root - INFO - SAE: 4.720609188079834
# 2025-09-22 19:50:06,961 - root - INFO - F1: 0.9482110369921164
# 2025-09-22 19:50:06,962 - root - INFO - Epoch 34, train loss: 0.076, val loss: 1730.584.
# 2025-09-22 19:50:06,962 - root - INFO - Early stopping overall:
# 2025-09-22 19:50:06,962 - root - INFO - EarlyStopping counter: 29 out of 30
# 2025-09-22 19:50:06,962 - root - INFO - # of epoches: 35
# 100% 874/874 [16:37<00:00,  1.14s/it]
# 2025-09-22 20:06:43,985 - root - INFO - Validation:
# 2025-09-22 20:06:44,310 - root - INFO - Evaluate dish washer:
# 2025-09-22 20:06:44,310 - root - INFO - MAE: 5.199769973754883
# 2025-09-22 20:06:44,311 - root - INFO - SAE: 3.938494920730591
# 2025-09-22 20:06:44,315 - root - INFO - F1: 0.9813829787234043
# 2025-09-22 20:06:44,315 - root - INFO - Evaluate fridge:
# 2025-09-22 20:06:44,316 - root - INFO - MAE: 20.126083374023438
# 2025-09-22 20:06:44,316 - root - INFO - SAE: 8.8668794631958
# 2025-09-22 20:06:44,320 - root - INFO - F1: 0.8556812315201577
# 2025-09-22 20:06:44,320 - root - INFO - Evaluate microwave:
# 2025-09-22 20:06:44,320 - root - INFO - MAE: 6.211851119995117
# 2025-09-22 20:06:44,320 - root - INFO - SAE: 5.526554107666016
# 2025-09-22 20:06:44,324 - root - INFO - F1: 0.8745980707395499
# 2025-09-22 20:06:44,324 - root - INFO - Evaluate wash:
# 2025-09-22 20:06:44,324 - root - INFO - MAE: 6.217746734619141
# 2025-09-22 20:06:44,325 - root - INFO - SAE: 3.079360008239746
# 2025-09-22 20:06:44,329 - root - INFO - F1: 0.9821924144310823
# 2025-09-22 20:06:44,329 - root - INFO - Epoch 35, train loss: 0.076, val loss: 1517.591.
# 2025-09-22 20:06:44,329 - root - INFO - Early stopping overall:
# 2025-09-22 20:06:44,329 - root - INFO - EarlyStopping counter: 30 out of 30
# Early stopping
# 2025-09-22 20:06:44,748 - root - INFO - Model loaded
# 2025-09-22 20:06:44,755 - root - INFO - Training end
# 2025-09-22 20:06:44,756 - root - INFO - validation start
# 2025-09-22 20:06:45,094 - root - INFO - Evaluate dish washer:
# 2025-09-22 20:06:45,094 - root - INFO - MAE: 3.845512628555298
# 2025-09-22 20:06:45,095 - root - INFO - SAE: 2.814965009689331
# 2025-09-22 20:06:45,100 - root - INFO - F1: 0.9795918367346939
# 2025-09-22 20:06:45,100 - root - INFO - Evaluate fridge:
# 2025-09-22 20:06:45,100 - root - INFO - MAE: 16.360050201416016
# 2025-09-22 20:06:45,101 - root - INFO - SAE: 5.9881110191345215
# 2025-09-22 20:06:45,105 - root - INFO - F1: 0.8779384745842559
# 2025-09-22 20:06:45,105 - root - INFO - Evaluate microwave:
# 2025-09-22 20:06:45,105 - root - INFO - MAE: 6.140356063842773
# 2025-09-22 20:06:45,105 - root - INFO - SAE: 5.287326812744141
# 2025-09-22 20:06:45,109 - root - INFO - F1: 0.8849840255591054
# 2025-09-22 20:06:45,109 - root - INFO - Evaluate wash:
# 2025-09-22 20:06:45,109 - root - INFO - MAE: 5.934713840484619
# 2025-09-22 20:06:45,110 - root - INFO - SAE: 2.6803839206695557
# 2025-09-22 20:06:45,114 - root - INFO - F1: 0.9893518518518518
# 2025-09-22 20:06:45,114 - root - INFO - test start
# 2025-09-22 20:06:52,643 - root - INFO - Evaluate dish washer:
# 2025-09-22 20:06:52,646 - root - INFO - MAE: 8.401164054870605
# 2025-09-22 20:06:52,654 - root - INFO - SAE: 7.4406585693359375
# 2025-09-22 20:06:52,726 - root - INFO - F1: 0.8348970233176154
# 2025-09-22 20:06:52,726 - root - INFO - Evaluate fridge:
# 2025-09-22 20:06:52,730 - root - INFO - MAE: 18.403112411499023
# 2025-09-22 20:06:52,737 - root - INFO - SAE: 14.341347694396973
# 2025-09-22 20:06:52,797 - root - INFO - F1: 0.904273599712157
# 2025-09-22 20:06:52,797 - root - INFO - Evaluate microwave:
# 2025-09-22 20:06:52,801 - root - INFO - MAE: 9.909242630004883
# 2025-09-22 20:06:52,809 - root - INFO - SAE: 8.185297012329102
# 2025-09-22 20:06:52,873 - root - INFO - F1: 0.7527899202879917
# 2025-09-22 20:06:52,874 - root - INFO - Evaluate wash:
# 2025-09-22 20:06:52,878 - root - INFO - MAE: 15.6603364944458
# 2025-09-22 20:06:52,889 - root - INFO - SAE: 13.595011711120605
# 2025-09-22 20:06:52,955 - root - INFO - F1: 0.7217192160204516

# %%
# Modify custom_types.py to include save_dir in TrainConfig.from_dict
with open("custom_types.py", "w") as f:
    f.write("""
import collections
import typing

class TrainConfig(typing.NamedTuple):

    input_size: int
    batch_size: int
    hidden: int
    lr: float
    dropout: float
    logname: str
    outputLength: int
    inputLength: int
    subName: str
    save_dir: str # Add save_dir here
    debug: bool = False
    dataAug: bool = False
    prob0: float = 0.1
    prob1: float = 0.1
    prob2: float = 0.6
    prob3: float = 0.6


    @classmethod
    def from_dict(cls,dikt):
        input_size = dikt['input_size']
        batch_size = dikt['batch_size']
        hidden = dikt['hidden']
        lr = dikt['lr']
        dropout = dikt['dropout']
        logname = dikt["logname"]
        outputLength = dikt["outputLength"]
        inputLength= dikt["inputLength"]
        subName = dikt['subName']
        save_dir = dikt['save_dir'] # Get save_dir from dictionary
        dataAug = dikt['dataAug']
        prob0 = dikt['prob0']
        prob1 = dikt['prob1']
        prob2 = dikt['prob2']
        prob3 = dikt['prob3']


        return cls(input_size,batch_size,hidden,lr,dropout,
                   logname,outputLength,inputLength,subName,save_dir,dataAug=dataAug, prob0=prob0, prob1=prob1, prob2=prob2, prob3=prob3)


Basic = collections.namedtuple("NILM", ["model", "model_opt"])
""")

# %% [markdown]
# # Task
# Modify the `main.py` script to save checkpoints to a specified Google Drive directory and run the script with the necessary arguments to enable this functionality.

# %% [markdown]
# ## Mount google drive
#
# ### Subtask:
# Mount Google Drive to access files from the Colab environment.

# %% [markdown]
# **Reasoning**:
# Mount Google Drive to access files from the Colab environment and then print the current working directory to confirm successful mounting.

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/MATNilm-master

# %%
import os
print(os.listdir("/content/drive/MyDrive/MATNilm_checkpoints"))
# Out:
# ['test', 'checkpoint_0.ckpt', 'checkpoint_10.ckpt', 'checkpoint_20.ckpt', 'checkpoint_30.ckpt', 'checkpoint_40.ckpt', 'checkpoint_50.ckpt', 'checkpoint_60.ckpt', 'checkpoint_70.ckpt', 'checkpoint_80.ckpt']
