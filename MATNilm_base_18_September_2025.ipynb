# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/MATNilm-master/blob/master/MATNilm_base_18_September_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content/MATNilm-master'

# %%
cd MATNilm-master/
# Out:
# [Errno 2] No such file or directory: 'MATNilm-master/'
# /content/MATNilm-master

# %%
# !sed -i "s/torch.load(checkpoint_path, map_location=device)/torch.load(checkpoint_path, map_location=device, weights_only=False)/" main.py
# !python main.py --resume --dataAug
# Out:
# 2025-09-17 12:06:15,251 - root - INFO - Using computation device: cuda:0
# 2025-09-17 12:06:15,251 - root - INFO - Namespace(batch=32, lr=0.001, dropout=0.1, hidden=32, logname='root', subName='test', inputLength=864, outputLength=864, debug=False, dataAug=True, prob0=0.3, prob1=0.6, prob2=0.3, prob3=0.3, resume=True, checkpoint='All_best_onoff.ckpt')
# 2025-09-17 12:06:15,251 - root - INFO - loading data
# 2025-09-17 12:06:15,280 - root - INFO - loading data finished
# 2025-09-17 12:06:15,281 - root - INFO - Training size: 27937.
# 2025-09-17 12:06:15,281 - root - INFO - Initialize model
# 2025-09-17 12:06:15,432 - root - INFO - Model MAT
# 2025-09-17 12:06:16,306 - root - INFO - Resuming training from checkpoint: history_model/test/s0/All_best_onoff.ckpt
# Traceback (most recent call last):
#   File "/content/MATNilm-master/main.py", line 181, in <module>
#     checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=False)
# ...

# %%
# !rm history_model/test/s0/All_best_onoff.ckpt

# %%
# !python main.py --resume --dataAug
# Out:
# 2025-09-17 12:07:26,024 - root - INFO - Using computation device: cuda:0
# 2025-09-17 12:07:26,024 - root - INFO - Namespace(batch=32, lr=0.001, dropout=0.1, hidden=32, logname='root', subName='test', inputLength=864, outputLength=864, debug=False, dataAug=True, prob0=0.3, prob1=0.6, prob2=0.3, prob3=0.3, resume=True, checkpoint='All_best_onoff.ckpt')
# 2025-09-17 12:07:26,024 - root - INFO - loading data
# 2025-09-17 12:07:26,054 - root - INFO - loading data finished
# 2025-09-17 12:07:26,054 - root - INFO - Training size: 27937.
# 2025-09-17 12:07:26,055 - root - INFO - Initialize model
# 2025-09-17 12:07:26,204 - root - INFO - Model MAT
# 2025-09-17 12:07:27,072 - root - ERROR - Checkpoint file not found: history_model/test/s0/All_best_onoff.ckpt
# 2025-09-17 12:07:27,073 - root - INFO - Starting training from scratch
# 2025-09-17 12:07:27,073 - root - INFO - Training start
# 2025-09-17 12:07:27,086 - root - INFO - # of epoches: 0
# ...
