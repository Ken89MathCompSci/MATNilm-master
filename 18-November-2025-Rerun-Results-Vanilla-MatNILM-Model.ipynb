# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/MATNilm-master/blob/master/18-November-2025-Rerun-Results-Vanilla-MatNILM-Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
cd MATNilm-master/
# Out:
# /content/MATNilm-master

# %%
# !python main.py --patience 20 --subName run25epochs
# Out:
# 2025-11-17 17:32:20,725 - root - INFO - Using computation device: cuda:0
# 2025-11-17 17:32:20,725 - root - INFO - Namespace(batch=32, lr=0.001, dropout=0.1, hidden=32, logname='root', subName='run25epochs', inputLength=864, outputLength=864, debug=False, dataAug=False, prob0=0.3, prob1=0.6, prob2=0.3, prob3=0.3, patience=20, resume=False, checkpoint='All_best_onoff.ckpt')
# 2025-11-17 17:32:20,725 - root - INFO - loading data
# 2025-11-17 17:32:20,762 - root - INFO - loading data finished
# 2025-11-17 17:32:20,766 - root - INFO - Training size: 27937.
# 2025-11-17 17:32:20,767 - root - INFO - Initialize model
# 2025-11-17 17:32:21,131 - root - INFO - Model MAT
# 2025-11-17 17:32:25,842 - root - INFO - Training start
# 2025-11-17 17:32:25,843 - root - INFO - # of epoches: 0
# ...
